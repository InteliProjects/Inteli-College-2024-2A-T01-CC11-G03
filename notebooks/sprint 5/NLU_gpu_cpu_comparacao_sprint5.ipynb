# %% [markdown]
# # Imports Iniciais

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python -m spacy download pt_core_news_sm
# !pip install googletrans==4.0.0-rc1
# !pip install enelvo
# Out:
# Collecting pt-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-3.7.0/pt_core_news_sm-3.7.0-py3-none-any.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 63.4 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from pt-core-news-sm==3.7.0) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (13.9.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.19.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.1.2)
# Installing collected packages: pt-core-news-sm
# Successfully installed pt-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Collecting googletrans==4.0.0-rc1
#   Downloading googletrans-4.0.0rc1.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans==4.0.0-rc1)
#   Downloading httpx-0.13.3-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.8.30)
# Collecting hstspreload (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hstspreload-2024.10.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting idna==2.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading idna-2.10-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading httpcore-0.9.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h11-0.9.0-py2.py3-none-any.whl.metadata (8.1 kB)
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h2-3.2.0-py2.py3-none-any.whl.metadata (32 kB)
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl.metadata (7.2 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl.metadata (7.0 kB)
# Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 5.6 MB/s eta 0:00:00
# Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 8.9 MB/s eta 0:00:00
# Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.2 MB/s eta 0:00:00
# Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.2 MB/s eta 0:00:00
# Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 6.0 MB/s eta 0:00:00
# Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Downloading hstspreload-2024.10.1-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 42.3 MB/s eta 0:00:00
# Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 1.1 MB/s eta 0:00:00
# Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17397 sha256=ed64249f8e42420136cf08d8ff1a035e34580f697538a8f219b5d047890f261b
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# Successfully installed chardet-3.0.4 googletrans-4.0.0rc1 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2024.10.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0
# Collecting enelvo
#   Downloading enelvo-0.15-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: editdistance>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from enelvo) (0.8.1)
# Collecting emoji==2.2.0 (from enelvo)
#   Downloading emoji-2.2.0.tar.gz (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.9/240.9 kB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gensim>=4.1.2 in /usr/local/lib/python3.10/dist-packages (from enelvo) (4.3.3)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from enelvo) (1.26.4)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from enelvo) (0.9.0)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim>=4.1.2->enelvo) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim>=4.1.2->enelvo) (7.0.4)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim>=4.1.2->enelvo) (1.16.0)
# Downloading enelvo-0.15-py3-none-any.whl (27.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 58.3 MB/s eta 0:00:00
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-2.2.0-py3-none-any.whl size=234910 sha256=a337726d97d2f93fe238b6473a82e4db3886f7e836cfbc5c3ee46de51f8ff5e0
#   Stored in directory: /root/.cache/pip/wheels/02/3d/88/51a592b9ad17e7899126563698b4e3961983ebe85747228ba6
# Successfully built emoji
# Installing collected packages: emoji, enelvo
# Successfully installed emoji-2.2.0 enelvo-0.15

# %%
from google.colab import drive
from googletrans import Translator
from enelvo.normaliser import Normaliser
from nltk.corpus import stopwords
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import SimpleRNN, Dense, Concatenate, Input, LSTM, Dropout, Bidirectional
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import f1_score, recall_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report
from unittest.mock import patch, MagicMock
import matplotlib.pyplot as plt
import tensorflow as tf
import re
import unittest
import numpy as np
import pandas as pd
import spacy
import nltk
import time

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# # Pré-processamento

# %% [markdown]
# ## 0) Base de Dados

# %%
norm = Normaliser(tokenizer='readable')
chats_clients = pd.read_csv('/content/drive/Shareddrives/grupo3moshi/SPRINT_5/data/reduced_augmented_data.csv')
chats_clients.head()
# Out:
#    No                Intencao  \
# 0   1     Transações e envios
# 1   2     Transações e envios
# 2   3  Consultas sobre prazos
# 3   4     Transações e envios
# 4   5     Transações e envios
#
#                                             Pergunta  \
# 0  Boa dia.tudo bem?eu gostaria de saber sobre aq...
# 1                     Como enviar dinheiro do Japão?
# 2  Quanto tempo levará para o beneficiário recebe...
# 3  Boa tarde Acabei de fazer a transferência de 2...
# 4  Poderia fazer a remessa de 22yenes para o BBB ...
#
#                                             Resposta
# 0  Bom dia! Sim, o sr pode utilizar o cartão de d...
# 1  Para se inscrever no serviço de remessa, por f...
# 2  Via de regra, as remessas serão pagas via PIX ...
# 3  iremos processar a sua solicitacao. Muito obri...
# 4  iremos processar a sua solicitacao. Muito obri...

# %%
chats_clients.fillna('erro ao processar a pergunta', inplace=True)

# %%
nlp_pt = spacy.load("pt_core_news_sm")

# %%
def correct_grammar(text):
  return norm.normalise(text)

# %% [markdown]
# ## 1) Word2Vec

# %% [markdown]
# O processo de Word2Vec é uma técnica de aprendizado de máquina com o objetivo de vetorizar palavras almejando preservar o contexto, convertendo o resultado para a forma numérica, para que os dados possam ser utilizados em modelos de aprendizado de máquina.
#
# O Word2Vec pode possuir 2 arquiteturas, sendo elas:
#
# - Skip-Gram: rede tenta prever as palavras de contexto ao redor de uma palavra central
# - CBOW: rede tenta prever a palavra central com base no contexto ao redor da palavra central.
#
# Para fins de comparação, ambas as técnicas serão abordadas no código a seguir:

# %% [markdown]
# ### 1.1) Skip-Gram

# %%
from gensim.models import Word2Vec
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize

# Tokenizando as colunas
chats_clients['Pergunta_tokens'] = chats_clients['Pergunta'].apply(lambda x: word_tokenize(x.lower()))
chats_clients['Resposta_tokens'] = chats_clients['Resposta'].apply(lambda x: word_tokenize(x.lower()))

# Unindo as listas de tokens de Pergunta e Resposta para o modelo processar a lista
sentences_skip = chats_clients['Pergunta_tokens'].tolist() + chats_clients['Resposta_tokens'].tolist()

# Utilizando o modelo Word2Vec
model = Word2Vec(sentences_skip, vector_size=100, window=5, min_count=1, sg=1)  #sg=1 para Skip-Gram
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ### 1.2) Resultados Obtidos

# %%
# Acessando o vetor de uma palavra
vector_dia_skip = model.wv['dia']
print(vector_dia_skip)
# Out:
# [-0.6618486   0.35790887  0.03992213  0.30783373 -0.21706787  0.04285166
#   0.11194819  0.21119559 -0.10280418 -0.03244362 -0.30648884  0.1727462
#   0.29044145  0.43958467 -0.5378019  -0.39716697  0.45571607 -0.06369048
#  -0.17877539 -0.15184547 -0.01374095  0.58620834  0.20461862 -0.5323012
#  -0.508149    0.51529896 -0.09739957  0.33869582 -0.27314258 -0.49326944
#   0.1736672   0.05637329  0.07715023  0.07685186 -0.10687603  0.711741
#   0.1842727  -0.66440594 -0.6165006   0.0084224   0.5369821  -0.18443242
#   0.08230907 -0.03883087 -0.09095397 -0.13870762 -0.6374108  -0.23181354
#   0.10424336 -0.57418424 -0.05543115 -0.6479341   0.14705084  0.6752551
#   0.05651654 -0.35664195  0.20620568 -0.4583212  -0.01045767 -0.15760969
#   0.08373488 -0.1963526   0.6197691  -0.1591413   0.04674498 -0.30153957
#  -0.10169534  0.5059606  -0.05549444  0.4275542  -0.37590423  0.06408846
#  -0.05400982  0.00379127  0.3413605   0.27968502 -0.27708817 -0.16171156
#  -0.01026877 -0.31610557 -0.5558759   0.11886701 -0.6615339   0.66302776
#  -0.4694965   0.24977785  0.04835567  0.00175302  0.04748203  0.36441022
#   0.17547762 -0.24041358 -0.30167192 -0.43584448  0.32588023  0.01664978
#   0.26642004  0.5024362  -0.08057946  0.06087706]

# %%
# Encontrando palavras similares
similar_words_dia_skip = model.wv.most_similar('dia')
print(similar_words_dia_skip)
# Out:
# [('bom', 0.6818026304244995), ('especial', 0.5821089148521423), ('plantão', 0.5680298209190369), ('jornada', 0.5615845322608948), ('thiago', 0.5394982099533081), ('#', 0.5321498513221741), ('5638010', 0.5215895175933838), ('3200326', 0.5157667398452759), ('6489058', 0.5053529739379883), ('processaremos', 0.5037411451339722)]

# %%
# Encontrando palavras similares
similar_words_bom_skip = model.wv.most_similar('bom')
print(similar_words_bom_skip)
# Out:
# [('dia', 0.6818027496337891), ('vantajoso', 0.6545056104660034), ('benéfico', 0.6364734768867493), ('3200326', 0.5640414357185364), ('especial', 0.5530169606208801), ('flavia', 0.5527412295341492), ('processaremos', 0.5494566559791565), ('concorde', 0.5481860637664795), ('25', 0.5375572443008423), ('jornada', 0.5368228554725647)]

# %%
# Encontrando palavras similares
similar_words_dinheiro_skip = model.wv.most_similar('dinheiro')
print(similar_words_dinheiro_skip)
# Out:
# [('numerário', 0.6385573744773865), ('cache', 0.6322228312492371), ('moeda', 0.6213396191596985), ('sul', 0.616341233253479), ('espécie', 0.615580141544342), ('coreia', 0.5935658812522888), ('cobre', 0.5908430218696594), ('rg', 0.586361825466156), ('massa', 0.5823532938957214), ('cunhada', 0.5711348652839661)]

# %%
# Encontrando palavras similares
similar_words_pix_skip = model.wv.most_similar('pix')
print(similar_words_pix_skip)
# Out:
# [('feitos', 0.8168717622756958), ('realizadas', 0.7951637506484985), ('autoestradas', 0.7861762642860413), ('estradas', 0.7749020457267761), ('via', 0.7747519612312317), ('pagos', 0.7742207646369934), ('pix.os', 0.7665918469429016), ('sã', 0.7638598084449768), ('estrada', 0.7579032182693481), ('sadio', 0.7558226585388184)]

# %% [markdown]
# ### 2.1) CBOW

# %%
# Unindo as listas de tokens de Pergunta e Resposta para o modelo processar a lista
sentences_CBOW = chats_clients['Pergunta_tokens'].tolist() + chats_clients['Resposta_tokens'].tolist()

# Utilizando o modelo Word2Vec
model_cbow = Word2Vec(sentences_CBOW, vector_size=100, window=5, min_count=1, sg=0)  #sg=0 para CBOW

# %% [markdown]
# ### 2.2) Resultados Obtidos

# %%
# Acessando o vetor de uma palavra
vector_dia_cbow = model_cbow.wv['dia']
print(vector_dia_cbow)
# Out:
# [-1.2238402   0.6766051   0.25868598  1.5188398  -1.4658635   0.22521006
#  -0.7902165   0.0117095  -0.7555544   0.45770064 -0.3283323   0.13878497
#   0.51086265  0.4365415  -0.33953944 -0.86121786 -0.606637   -0.3766912
#  -0.21727587 -0.24885587 -0.16630378  0.5860889   0.37110144  0.02323668
#  -0.45229486 -0.07342084 -0.51518226  0.72488195 -0.08501931 -1.7459389
#  -0.7752286   0.22976795  0.94818056  0.0907876   0.2107807   1.7902272
#   0.82404536 -1.1069428  -1.6659217   0.1847027   0.37024644  0.03830314
#  -0.3178464  -0.36404085  0.19948296 -0.10772586 -0.67232364 -1.4620245
#   0.08491392 -1.490597    0.32202113 -0.98856443  0.09367891  1.4034435
#   0.10515719 -0.03316477  0.29124725 -0.40846685  0.06255713  0.0820701
#   0.8010914  -0.01099022 -0.28914565 -0.27848524  0.7724255  -0.10726522
#  -0.91065466  0.56091964 -0.45904872  0.46039397 -0.9307213   0.14686066
#  -0.09275229  0.52914554  1.1813343   1.0043805  -0.4081118   0.14305513
#   0.3816887  -0.1195382  -0.10634445 -0.19997929 -0.46207988  1.3590584
#  -1.3784609  -0.2280339  -0.12767527 -0.5504465  -0.18523392  1.3686932
#  -0.47470048  0.39856902  0.01239916 -0.2501794  -0.0439952   0.9938047
#  -0.32350007  1.2158421   0.23296535  0.9887526 ]

# %%
# Encontrando palavras similares
similar_words_dia_cbow = model_cbow.wv.most_similar('dia')
print(similar_words_dia_cbow)
# Out:
# [('25mil', 0.5414363741874695), ('pelas', 0.5391759872436523), ('excepcional', 0.5343722701072693), ('plantão', 0.5270633697509766), ('thiago', 0.519219696521759), ('terezinha', 0.5136023163795471), ('lembre-se', 0.5093264579772949), ('especial', 0.5066626071929932), ('flavia', 0.5017634630203247), ('jornada', 0.4985436201095581)]

# %%
# Encontrando palavras similares
similar_words_bom_cbow = model_cbow.wv.most_similar('bom')
print(similar_words_bom_cbow)
# Out:
# [('vantajoso', 0.6123963594436646), ('benéfico', 0.5995203852653503), ('25', 0.5992198586463928), ('plantão', 0.5744826793670654), ('lantão', 0.5663740634918213), ('qie', 0.5586148500442505), ('especial', 0.5434421300888062), ('manutenção', 0.5314924716949463), ('450.000', 0.5299198627471924), ('saindo', 0.5273609161376953)]

# %%
# Encontrando palavras similares
similar_words_dinheiro_cbow = model_cbow.wv.most_similar('dinheiro')
print(similar_words_dinheiro_cbow)
# Out:
# [('moeda', 0.7224353551864624), ('urgente', 0.7217877507209778), ('nubank', 0.7056573629379272), ('poder', 0.6992083191871643), ('enviam', 0.6890468597412109), ('envia', 0.6872698664665222), ('japão', 0.6836842894554138), ('vcs', 0.673004150390625), ('remessar', 0.6678348779678345), ('faço', 0.6616794466972351)]

# %%
# Encontrando palavras similares
similar_words_pix_cbow = model_cbow.wv.most_similar('pix')
print(similar_words_pix_cbow)
# Out:
# [('sendo', 0.9465645551681519), ('feitos', 0.8925660252571106), ('realizadas', 0.8913923501968384), ('pagamentos', 0.8858925700187683), ('via', 0.884759247303009), ('estão', 0.8296645283699036), ('autoestradas', 0.8078092336654663), ('pagas', 0.7897928953170776), ('estrada', 0.7797988653182983), ('pagar', 0.7797921299934387)]

# %% [markdown]
# ### 3.1) Word Embedding

# %% [markdown]
# Dessa forma, é fundamental gerar os embedding das colunas para que futuros modelos de aprendizado de máquina possam compreender e utilizar os dados de cada frase. Para tal, será utilizado uma média dos vetores de cada frase, desenvolvido a seguir, utilizando a abordagem CBOW (padrão):

# %%
import numpy as np

# Função para gerar o embedding médio de uma frase
def get_sentence_embedding(tokens, model):
    word_vectors = [model.wv[token] for token in tokens if token in model.wv]
    if len(word_vectors) > 0:
        return np.mean(word_vectors, axis=0)
    else:
        return np.zeros(model.vector_size)

# %% [markdown]
# ### 3.2) Resultados Obtidos

# %%
# Aplicando a função para gerar os embeddings e salvando nas novas colunas
chats_clients['Pergunta_embedding'] = chats_clients['Pergunta_tokens'].apply(lambda tokens: get_sentence_embedding(tokens, model_cbow))
chats_clients['Resposta_embedding'] = chats_clients['Resposta_tokens'].apply(lambda tokens: get_sentence_embedding(tokens, model_cbow))

# %%
chats_clients['Pergunta_embedding'].head()
# Out:
# 0    [-0.62387526, -0.013753554, -0.113851205, -0.2...
# 1    [-0.98446876, -1.1387836, -0.32242826, -0.7253...
# 2    [-0.81429005, -0.6709541, -0.24981721, -0.3917...
# 3    [-0.5258677, 0.42466766, -0.65978044, -0.45810...
# 4    [-0.43677127, 0.28760827, -0.08478476, -0.2626...
# Name: Pergunta_embedding, dtype: object

# %%
chats_clients['Resposta_embedding'].head()
# Out:
# 0    [-0.21871227, 0.09722363, -0.067045845, -0.202...
# 1    [-0.86376905, -0.45004615, -0.30747676, -0.702...
# 2    [-0.08548761, 0.021886703, 0.5155782, -0.29745...
# 3    [0.10867635, 0.5803269, 0.35303545, 0.66656107...
# 4    [0.10867635, 0.5803269, 0.35303545, 0.66656107...
# Name: Resposta_embedding, dtype: object

# %% [markdown]
# ## 2) Base de Dados Final

# %%
chats_clients
# Out:
#         No                                Intencao  \
# 0        1                     Transações e envios
# 1        2                     Transações e envios
# 2        3                  Consultas sobre prazos
# 3        4                     Transações e envios
# 4        5                     Transações e envios
# ...    ...                                     ...
# 5631  1327            erro ao processar a pergunta
# 5632  1327            erro ao processar a pergunta
# 5633  1327            erro ao processar a pergunta
# 5634  1328  Gerenciamento de cadastro e documentos
# 5635  1328  Gerenciamento de cadastro e documentos
#
#                                                Pergunta  \
# 0     Boa dia.tudo bem?eu gostaria de saber sobre aq...
# 1                        Como enviar dinheiro do Japão?
# 2     Quanto tempo levará para o beneficiário recebe...
# 3     Boa tarde Acabei de fazer a transferência de 2...
# 4     Poderia fazer a remessa de 22yenes para o BBB ...
# ...                                                 ...
# 5631  ola Olá, posso ajudar? Aguardando o no meu app...
# 5632  ola Olá, como posso ajudar? o depósito no meu ...
# 5633  ola Olá, como posso ajudar? Aguardando o depós...
# 5634  Boa Vc pode me enviar prwcisa pra registra pes...
# 5635  Boa tarde Vc pode me enviar oque prwcisa pra r...
#
#                                                Resposta  \
# 0     Bom dia! Sim, o sr pode utilizar o cartão de d...
# 1     Para se inscrever no serviço de remessa, por f...
# 2     Via de regra, as remessas serão pagas via PIX ...
# 3     iremos processar a sua solicitacao. Muito obri...
# 4     iremos processar a sua solicitacao. Muito obri...
# ...                                                 ...
# 5631  O código de depósito vai estar no seu aplicati...
# 5632                     O valor já consta no seu saldo
# 5633                                         Igualmente
# 5634  Bom dia,  DADOS DO BENEFICIÁRIO  NOME COMPLETO...
# 5635  Bom dia Sim Precisamos de mais informações:  C...
#
#                                         Pergunta_tokens  \
# 0     [boa, dia.tudo, bem, ?, eu, gostaria, de, sabe...
# 1                [como, enviar, dinheiro, do, japão, ?]
# 2     [quanto, tempo, levará, para, o, beneficiário,...
# 3     [boa, tarde, acabei, de, fazer, a, transferênc...
# 4     [poderia, fazer, a, remessa, de, 22yenes, para...
# ...                                                 ...
# 5631  [ola, olá, ,, posso, ajudar, ?, aguardando, o,...
# 5632  [ola, olá, ,, como, posso, ajudar, ?, o, depós...
# 5633  [ola, olá, ,, como, posso, ajudar, ?, aguardan...
# 5634  [boa, vc, pode, me, enviar, prwcisa, pra, regi...
# 5635  [boa, tarde, vc, pode, me, enviar, oque, prwci...
#
#                                         Resposta_tokens  \
# 0     [bom, dia, !, sim, ,, o, sr, pode, utilizar, o...
# 1     [para, se, inscrever, no, serviço, de, remessa...
# 2     [via, de, regra, ,, as, remessas, serão, pagas...
# 3     [iremos, processar, a, sua, solicitacao, ., mu...
# 4     [iremos, processar, a, sua, solicitacao, ., mu...
# ...                                                 ...
# 5631  [o, código, de, depósito, vai, estar, no, seu,...
# 5632             [o, valor, já, consta, no, seu, saldo]
# 5633                                       [igualmente]
# 5634  [bom, dia, ,, dados, do, beneficiário, nome, c...
# 5635  [bom, dia, sim, precisamos, de, mais, informaç...
#
#                                      Pergunta_embedding  \
# 0     [-0.62387526, -0.013753554, -0.113851205, -0.2...
# 1     [-0.98446876, -1.1387836, -0.32242826, -0.7253...
# 2     [-0.81429005, -0.6709541, -0.24981721, -0.3917...
# 3     [-0.5258677, 0.42466766, -0.65978044, -0.45810...
# 4     [-0.43677127, 0.28760827, -0.08478476, -0.2626...
# ...                                                 ...
# 5631  [-0.340479, 0.25398564, 0.06927656, -0.3419014...
# 5632  [-0.3522052, 0.2410985, 0.041468382, -0.329004...
# 5633  [-0.3383431, 0.27118373, 0.06754842, -0.317753...
# 5634  [-0.38277766, -0.38577104, -0.33150324, -0.405...
# 5635  [-0.5830294, 0.4479711, 0.15139116, -0.2668771...
#
#                                      Resposta_embedding
# 0     [-0.21871227, 0.09722363, -0.067045845, -0.202...
# 1     [-0.86376905, -0.45004615, -0.30747676, -0.702...
# 2     [-0.08548761, 0.021886703, 0.5155782, -0.29745...
# 3     [0.10867635, 0.5803269, 0.35303545, 0.66656107...
# 4     [0.10867635, 0.5803269, 0.35303545, 0.66656107...
# ...                                                 ...
# 5631  [-0.09864209, 0.6743152, 0.04794146, -0.269526...
# 5632  [-0.6104869, -0.29716116, 0.102157466, -0.1922...
# 5633  [0.01709923, 0.07790981, -0.048589393, 0.04892...
# 5634  [-0.6880614, 0.6606267, 0.320108, -0.2721452, ...
# 5635  [-0.63789386, 0.010212612, -0.18352072, -0.218...
#
# [5636 rows x 8 columns]

# %% [markdown]
# ### Classificador de intenção

# %% [markdown]
# O classificador de intenção é um sistema que identifica a intenção por trás de uma mensagem de texto, neste caso, seria as mensagens (entradas do chatbot) enviadas pelos clientes. A intenção refere-se ao que o usuário deseja realizar, como transferir dinheiro, taxa de câmbio, etc.
# Nesta seção é abordado o treinamento do modelo com suas respectivas métricas (Acurácia, Recall, F1-Score).
#
# Abaixo há uma classe de callback que guarda as métricas de F1-Score e recall. A F1-score é uma métrica que leva em consideração a precisão e o recall, sendo definida pela seguinte fórmula:
# $$ F1-Score = 2 \cdot \frac{Precision \cdot Recall}{Precision + Recall}$$
#
# F1 é conhecido como a média harmônica da precisão e do recall. A pontuação F1 se torna 1 apenas se a precisão e recall são 1. Se a precisão e o recall são altos, logo o valor de F1 também é alta.
#
# a métrica Recall (sensibilidade) ajuda a avaliar a capacidade do modelo de identificar corretamente todos os exemplos positivos de uma classe. Por exemplo, se temos um problema onde devemos classificar com uma classificação "sim" ou "não" referente a spam de e-mails, o recall nesse caso nos dirá quantos e-mails de spam o modelo conseguiu identificar corretamente, dentre todos os e-mails que realmente eram spam.
#
# A fórmula do recall é a seguinte:
#
# $$ Recall = \frac{TP}{TP + FN}$$
#
# Já a acurácia é a proporção total de exemplos que o modelo classificou corretamente, ou seja, o quanto o modelo conseguiu acertar. Fórmula:
#
#
# $$ Recall = \frac{Previsões corretas}{Previsões incorretas}$$

# %%
class MetricsCallback(Callback):
    def __init__(self, validation_data):
        super().__init__()
        self.validation_data = validation_data

    def on_epoch_end(self, epoch, logs=None):
        val_data, val_labels = self.validation_data
        val_pred = np.argmax(self.model.predict(val_data), axis=1)
        val_f1 = f1_score(val_labels, val_pred, average='macro')
        recall = recall_score(val_labels, val_pred, average='macro', zero_division=1)
        print(f'Epoch {epoch + 1}: f1-score: {val_f1:.4f} - recall: {recall:.4f}')
        logs['f1_score'] = val_f1
        logs['recall'] = recall

# %% [markdown]
# #### Modelo Final

# %%
class IntentClassifier:
    def __init__(self, epochs=300, batch_size=16, test_size=0.3, validation_split=0.3, learning_rate=0.001):
        self.epochs = epochs
        self.batch_size = batch_size
        self.test_size = test_size
        self.validation_split = validation_split
        self.learning_rate = learning_rate
        self.model = None
        self.label_encoder = None

    def prepare_data(self, chats_clients):
        answer_embeddings = np.array(chats_clients['Pergunta_embedding'].tolist())

        self.label_encoder = LabelEncoder()
        self.labels = self.label_encoder.fit_transform(chats_clients['Intencao'])

        # Ajuste para garantir que a entrada seja 3D
        answer_embeddings = answer_embeddings.reshape((answer_embeddings.shape[0], 1, answer_embeddings.shape[1]))

        X_train, X_test, y_train, y_test = train_test_split(answer_embeddings, self.labels, test_size=self.test_size, random_state=42)

        return X_train, X_test, y_train, y_test

    def build_model(self, input_shape):
        self.model = Sequential()
        self.model.add(Bidirectional(LSTM(128, return_sequences=True), input_shape=input_shape))
        self.model.add(Dropout(0.4))
        self.model.add(LSTM(64))
        self.model.add(Dropout(0.4))
        self.model.add(Dense(64, activation='relu'))
        self.model.add(Dense(32, activation='relu'))
        self.model.add(Dense(len(np.unique(self.labels)), activation='softmax'))
        optimizer = Adam(learning_rate=self.learning_rate)
        self.model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
        self.model.summary()

    def train(self, X_train, X_test, y_train, y_test):
        model_checkpoint = ModelCheckpoint('best_model.keras', save_best_only=True, monitor='val_loss', mode='min')

        # Callback do F1-Score e recall
        metrics_callback = MetricsCallback(validation_data=(X_test, y_test))

        H = self.model.fit(X_train, y_train, epochs=self.epochs,
                       batch_size=self.batch_size,
                       validation_split=self.validation_split,
                       callbacks=[
                           model_checkpoint,
                           metrics_callback
                           ])

        loss, accuracy = self.model.evaluate(X_test, y_test)
        print(f"Test Loss: {loss}, Test Accuracy: {accuracy}")

        return H

    def predict(self, X_test):
        y_pred = self.model.predict(X_test)
        y_pred_classes = np.argmax(y_pred, axis=1)

        return y_pred_classes

    def generate_report(self, y_test, y_pred_classes):
      print(len(y_test))
      print(classification_report(y_test, y_pred_classes))

    def evaluate_model(self, H):
      # Obter métricas de precisão e perda do treinamento
      acc = H.history['accuracy']
      val_acc = H.history['val_accuracy']
      loss = H.history['loss']
      val_loss = H.history['val_loss']

      epochs = range(1, len(acc) + 1)

      # Plotar precisão do conjunto
      plt.subplot(2, 2, 3)
      plt.plot(epochs, acc, 'r', label='Precisão do Conjunto de Treino')
      plt.plot(epochs, val_acc, 'b', label='Precisão do Conjunto de Validação')
      plt.title('Precisão do Conjunto de Treino e Validação')
      plt.xlabel('Épocas')
      plt.ylabel('Precisão')
      plt.legend()

      # Plotar perda do conjunto
      plt.subplot(2, 2, 4)
      plt.plot(epochs, loss, 'r', label='Perda do Conjunto de Treino')
      plt.plot(epochs, val_loss, 'b', label='Perda do Conjunto de Validação')
      plt.title('Perda do Conjunto de Treino e Validação')
      plt.xlabel('Épocas')
      plt.ylabel('Perda')
      plt.legend()

      plt.tight_layout()
      plt.show()

# %% [markdown]
# #### Treino e Avaliação com CPU

# %% [markdown]
# Para rodar o modelo com a CPU basta alocar qualquer máquina do colab, rodar todas as células anteriores e rodar a célula abaixo.

# %%
classifier = IntentClassifier()
X_train, X_test, y_train, y_test = classifier.prepare_data(chats_clients)
classifier.build_model(input_shape=(X_train.shape[1], X_train.shape[2]))
with tf.device('/cpu:0'):
  # Calcula o tempo da cpu
  start_time = time.time()
  H = classifier.train(X_train, X_test, y_train, y_test)
  # Para o cronômetro e salva o tempo da cpu
  time_cpu = time.time() - start_time
  H
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)        │ (None, 1, 256)              │         234,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1, 256)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 64)                  │          82,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 8)                   │             264 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 323,176 (1.23 MB)
#  Trainable params: 323,176 (1.23 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Epoch 1: f1-score: 0.3103 - recall: 0.3259
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.3803 - loss: 1.7614 - val_accuracy: 0.5811 - val_loss: 1.2243 - f1_score: 0.3103 - recall: 0.3259
# Epoch 2/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 2: f1-score: 0.3272 - recall: 0.3542
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.5837 - loss: 1.2667 - val_accuracy: 0.6073 - val_loss: 1.0940 - f1_score: 0.3272 - recall: 0.3542
# Epoch 3/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 3: f1-score: 0.4216 - recall: 0.4156
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.6009 - loss: 1.1420 - val_accuracy: 0.6385 - val_loss: 1.0190 - f1_score: 0.4216 - recall: 0.4156
# Epoch 4/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 4: f1-score: 0.4860 - recall: 0.4963
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.6369 - loss: 1.0424 - val_accuracy: 0.6394 - val_loss: 0.9531 - f1_score: 0.4860 - recall: 0.4963
# Epoch 5/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 5: f1-score: 0.5373 - recall: 0.5286
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.6452 - loss: 1.0005 - val_accuracy: 0.6892 - val_loss: 0.8964 - f1_score: 0.5373 - recall: 0.5286
# Epoch 6/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 6: f1-score: 0.5511 - recall: 0.5270
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.6676 - loss: 0.9164 - val_accuracy: 0.6799 - val_loss: 0.8619 - f1_score: 0.5511 - recall: 0.5270
# Epoch 7/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 7: f1-score: 0.5394 - recall: 0.5349
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.6945 - loss: 0.8809 - val_accuracy: 0.6892 - val_loss: 0.8395 - f1_score: 0.5394 - recall: 0.5349
# Epoch 8/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 8: f1-score: 0.5584 - recall: 0.5486
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7034 - loss: 0.8347 - val_accuracy: 0.7078 - val_loss: 0.7825 - f1_score: 0.5584 - recall: 0.5486
# Epoch 9/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 9: f1-score: 0.5816 - recall: 0.5584
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.7217 - loss: 0.8074 - val_accuracy: 0.7078 - val_loss: 0.7727 - f1_score: 0.5816 - recall: 0.5584
# Epoch 10/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 10: f1-score: 0.5882 - recall: 0.5731
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7090 - loss: 0.7772 - val_accuracy: 0.7171 - val_loss: 0.7478 - f1_score: 0.5882 - recall: 0.5731
# Epoch 11/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 11: f1-score: 0.6127 - recall: 0.6010
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7153 - loss: 0.7650 - val_accuracy: 0.7280 - val_loss: 0.7084 - f1_score: 0.6127 - recall: 0.6010
# Epoch 12/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 12: f1-score: 0.5890 - recall: 0.5822
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.7253 - loss: 0.7511 - val_accuracy: 0.7348 - val_loss: 0.7109 - f1_score: 0.5890 - recall: 0.5822
# Epoch 13/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Epoch 13: f1-score: 0.6120 - recall: 0.5875
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.7438 - loss: 0.6997 - val_accuracy: 0.7365 - val_loss: 0.6973 - f1_score: 0.6120 - recall: 0.5875
# Epoch 14/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 14: f1-score: 0.6516 - recall: 0.6490
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.7589 - loss: 0.6616 - val_accuracy: 0.7652 - val_loss: 0.6521 - f1_score: 0.6516 - recall: 0.6490
# Epoch 15/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 15: f1-score: 0.6557 - recall: 0.6565
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.7673 - loss: 0.6546 - val_accuracy: 0.7441 - val_loss: 0.6275 - f1_score: 0.6557 - recall: 0.6565
# Epoch 16/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 16: f1-score: 0.6838 - recall: 0.6583
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7741 - loss: 0.6372 - val_accuracy: 0.7711 - val_loss: 0.6365 - f1_score: 0.6838 - recall: 0.6583
# Epoch 17/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 17: f1-score: 0.6854 - recall: 0.6740
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.7796 - loss: 0.6266 - val_accuracy: 0.7694 - val_loss: 0.6149 - f1_score: 0.6854 - recall: 0.6740
# Epoch 18/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 18: f1-score: 0.6768 - recall: 0.6805
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.7817 - loss: 0.6237 - val_accuracy: 0.7644 - val_loss: 0.6087 - f1_score: 0.6768 - recall: 0.6805
# Epoch 19/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 19: f1-score: 0.6921 - recall: 0.6876
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.7912 - loss: 0.5670 - val_accuracy: 0.7660 - val_loss: 0.6033 - f1_score: 0.6921 - recall: 0.6876
# Epoch 20/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 20: f1-score: 0.7009 - recall: 0.6949
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.7985 - loss: 0.5491 - val_accuracy: 0.7812 - val_loss: 0.5968 - f1_score: 0.7009 - recall: 0.6949
# Epoch 21/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 21: f1-score: 0.7138 - recall: 0.6962
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.7918 - loss: 0.5904 - val_accuracy: 0.7863 - val_loss: 0.5651 - f1_score: 0.7138 - recall: 0.6962
# Epoch 22/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 22: f1-score: 0.7145 - recall: 0.7017
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.8068 - loss: 0.5133 - val_accuracy: 0.7863 - val_loss: 0.5521 - f1_score: 0.7145 - recall: 0.7017
# Epoch 23/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 23: f1-score: 0.7268 - recall: 0.7252
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8108 - loss: 0.4988 - val_accuracy: 0.7872 - val_loss: 0.5491 - f1_score: 0.7268 - recall: 0.7252
# Epoch 24/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 24: f1-score: 0.7329 - recall: 0.7235
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8138 - loss: 0.5021 - val_accuracy: 0.7973 - val_loss: 0.5438 - f1_score: 0.7329 - recall: 0.7235
# Epoch 25/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 25: f1-score: 0.7446 - recall: 0.7385
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7956 - loss: 0.5528 - val_accuracy: 0.7914 - val_loss: 0.5391 - f1_score: 0.7446 - recall: 0.7385
# Epoch 26/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 26: f1-score: 0.7386 - recall: 0.7306
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.8223 - loss: 0.4857 - val_accuracy: 0.8015 - val_loss: 0.5244 - f1_score: 0.7386 - recall: 0.7306
# Epoch 27/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Epoch 27: f1-score: 0.7469 - recall: 0.7286
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.8315 - loss: 0.4590 - val_accuracy: 0.8015 - val_loss: 0.5075 - f1_score: 0.7469 - recall: 0.7286
# Epoch 28/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 28: f1-score: 0.7566 - recall: 0.7518
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.8265 - loss: 0.4722 - val_accuracy: 0.8057 - val_loss: 0.5154 - f1_score: 0.7566 - recall: 0.7518
# Epoch 29/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 29: f1-score: 0.7408 - recall: 0.7524
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8325 - loss: 0.4338 - val_accuracy: 0.8049 - val_loss: 0.5114 - f1_score: 0.7408 - recall: 0.7524
# Epoch 30/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 30: f1-score: 0.7452 - recall: 0.7427
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8392 - loss: 0.4416 - val_accuracy: 0.8015 - val_loss: 0.5106 - f1_score: 0.7452 - recall: 0.7427
# Epoch 31/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 31: f1-score: 0.7550 - recall: 0.7545
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.8349 - loss: 0.4457 - val_accuracy: 0.8133 - val_loss: 0.4825 - f1_score: 0.7550 - recall: 0.7545
# Epoch 32/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 32: f1-score: 0.7460 - recall: 0.7545
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8420 - loss: 0.4133 - val_accuracy: 0.7965 - val_loss: 0.5280 - f1_score: 0.7460 - recall: 0.7545
# Epoch 33/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 33: f1-score: 0.7775 - recall: 0.7606
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8449 - loss: 0.4012 - val_accuracy: 0.8150 - val_loss: 0.4663 - f1_score: 0.7775 - recall: 0.7606
# Epoch 34/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 34: f1-score: 0.7714 - recall: 0.7633
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.8311 - loss: 0.4329 - val_accuracy: 0.8209 - val_loss: 0.4598 - f1_score: 0.7714 - recall: 0.7633
# Epoch 35/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 35: f1-score: 0.7447 - recall: 0.7326
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - accuracy: 0.8510 - loss: 0.3959 - val_accuracy: 0.8100 - val_loss: 0.4832 - f1_score: 0.7447 - recall: 0.7326
# Epoch 36/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Epoch 36: f1-score: 0.7735 - recall: 0.7565
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8528 - loss: 0.3989 - val_accuracy: 0.8209 - val_loss: 0.4766 - f1_score: 0.7735 - recall: 0.7565
# Epoch 37/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 37: f1-score: 0.7837 - recall: 0.7699
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - accuracy: 0.8582 - loss: 0.3948 - val_accuracy: 0.8235 - val_loss: 0.4711 - f1_score: 0.7837 - recall: 0.7699
# Epoch 38/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Epoch 38: f1-score: 0.7742 - recall: 0.7675
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.8291 - loss: 0.4294 - val_accuracy: 0.8150 - val_loss: 0.4529 - f1_score: 0.7742 - recall: 0.7675
# Epoch 39/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 39: f1-score: 0.7818 - recall: 0.7732
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.8489 - loss: 0.3691 - val_accuracy: 0.8285 - val_loss: 0.4372 - f1_score: 0.7818 - recall: 0.7732
# Epoch 40/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 40: f1-score: 0.7858 - recall: 0.7718
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8570 - loss: 0.3804 - val_accuracy: 0.8184 - val_loss: 0.4736 - f1_score: 0.7858 - recall: 0.7718
# Epoch 41/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 41: f1-score: 0.7872 - recall: 0.7817
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8600 - loss: 0.3635 - val_accuracy: 0.8302 - val_loss: 0.4442 - f1_score: 0.7872 - recall: 0.7817
# Epoch 42/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Epoch 42: f1-score: 0.7890 - recall: 0.7954
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8600 - loss: 0.3630 - val_accuracy: 0.8209 - val_loss: 0.4636 - f1_score: 0.7890 - recall: 0.7954
# Epoch 43/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 43: f1-score: 0.8038 - recall: 0.7862
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.8540 - loss: 0.3842 - val_accuracy: 0.8294 - val_loss: 0.4432 - f1_score: 0.8038 - recall: 0.7862
# Epoch 44/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 44: f1-score: 0.7919 - recall: 0.7796
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8699 - loss: 0.3433 - val_accuracy: 0.8361 - val_loss: 0.4330 - f1_score: 0.7919 - recall: 0.7796
# Epoch 45/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 45: f1-score: 0.7963 - recall: 0.7858
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.8553 - loss: 0.3729 - val_accuracy: 0.8421 - val_loss: 0.4303 - f1_score: 0.7963 - recall: 0.7858
# Epoch 46/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 46: f1-score: 0.7965 - recall: 0.7937
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.8535 - loss: 0.3571 - val_accuracy: 0.8421 - val_loss: 0.4097 - f1_score: 0.7965 - recall: 0.7937
# Epoch 47/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 47: f1-score: 0.8117 - recall: 0.8158
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8701 - loss: 0.3385 - val_accuracy: 0.8421 - val_loss: 0.4039 - f1_score: 0.8117 - recall: 0.8158
# Epoch 48/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 48: f1-score: 0.8014 - recall: 0.7952
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.8689 - loss: 0.3279 - val_accuracy: 0.8438 - val_loss: 0.4087 - f1_score: 0.8014 - recall: 0.7952
# Epoch 49/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 49: f1-score: 0.8042 - recall: 0.7957
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8736 - loss: 0.3304 - val_accuracy: 0.8454 - val_loss: 0.4396 - f1_score: 0.8042 - recall: 0.7957
# Epoch 50/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 50: f1-score: 0.8082 - recall: 0.8109
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8560 - loss: 0.3526 - val_accuracy: 0.8463 - val_loss: 0.4103 - f1_score: 0.8082 - recall: 0.8109
# Epoch 51/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 51: f1-score: 0.7906 - recall: 0.8047
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8718 - loss: 0.3339 - val_accuracy: 0.8429 - val_loss: 0.4270 - f1_score: 0.7906 - recall: 0.8047
# Epoch 52/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch 52: f1-score: 0.8091 - recall: 0.8052
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.8609 - loss: 0.3577 - val_accuracy: 0.8522 - val_loss: 0.4100 - f1_score: 0.8091 - recall: 0.8052
# Epoch 53/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 53: f1-score: 0.8075 - recall: 0.8107
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.8630 - loss: 0.3301 - val_accuracy: 0.8438 - val_loss: 0.4229 - f1_score: 0.8075 - recall: 0.8107
# Epoch 54/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 54: f1-score: 0.8127 - recall: 0.8154
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8727 - loss: 0.3017 - val_accuracy: 0.8514 - val_loss: 0.4011 - f1_score: 0.8127 - recall: 0.8154
# Epoch 55/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 55: f1-score: 0.8075 - recall: 0.8119
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8761 - loss: 0.3135 - val_accuracy: 0.8429 - val_loss: 0.4062 - f1_score: 0.8075 - recall: 0.8119
# Epoch 56/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch 56: f1-score: 0.8145 - recall: 0.8123
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.8647 - loss: 0.3070 - val_accuracy: 0.8438 - val_loss: 0.4078 - f1_score: 0.8145 - recall: 0.8123
# Epoch 57/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 57: f1-score: 0.8184 - recall: 0.8285
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.8686 - loss: 0.3150 - val_accuracy: 0.8446 - val_loss: 0.4186 - f1_score: 0.8184 - recall: 0.8285
# Epoch 58/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 58: f1-score: 0.8041 - recall: 0.7969
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8664 - loss: 0.3210 - val_accuracy: 0.8446 - val_loss: 0.4032 - f1_score: 0.8041 - recall: 0.7969
# Epoch 59/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch 59: f1-score: 0.8235 - recall: 0.8200
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.8836 - loss: 0.2894 - val_accuracy: 0.8463 - val_loss: 0.4146 - f1_score: 0.8235 - recall: 0.8200
# Epoch 60/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 60: f1-score: 0.7985 - recall: 0.8033
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.8733 - loss: 0.3024 - val_accuracy: 0.8454 - val_loss: 0.4235 - f1_score: 0.7985 - recall: 0.8033
# Epoch 61/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 61: f1-score: 0.8121 - recall: 0.8147
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8845 - loss: 0.2786 - val_accuracy: 0.8438 - val_loss: 0.4177 - f1_score: 0.8121 - recall: 0.8147
# Epoch 62/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 62: f1-score: 0.8131 - recall: 0.8067
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8810 - loss: 0.2867 - val_accuracy: 0.8564 - val_loss: 0.4039 - f1_score: 0.8131 - recall: 0.8067
# Epoch 63/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch 63: f1-score: 0.8147 - recall: 0.8130
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.8770 - loss: 0.2793 - val_accuracy: 0.8522 - val_loss: 0.4101 - f1_score: 0.8147 - recall: 0.8130
# Epoch 64/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 64: f1-score: 0.8238 - recall: 0.8227
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8851 - loss: 0.2831 - val_accuracy: 0.8429 - val_loss: 0.4336 - f1_score: 0.8238 - recall: 0.8227
# Epoch 65/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 65: f1-score: 0.8223 - recall: 0.8193
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8848 - loss: 0.2988 - val_accuracy: 0.8471 - val_loss: 0.4195 - f1_score: 0.8223 - recall: 0.8193
# Epoch 66/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch 66: f1-score: 0.8161 - recall: 0.8106
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.8872 - loss: 0.2846 - val_accuracy: 0.8573 - val_loss: 0.4074 - f1_score: 0.8161 - recall: 0.8106
# Epoch 67/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 67: f1-score: 0.8109 - recall: 0.8223
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.8988 - loss: 0.2545 - val_accuracy: 0.8471 - val_loss: 0.4016 - f1_score: 0.8109 - recall: 0.8223
# Epoch 68/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 68: f1-score: 0.8198 - recall: 0.8014
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9080 - loss: 0.2433 - val_accuracy: 0.8530 - val_loss: 0.4163 - f1_score: 0.8198 - recall: 0.8014
# Epoch 69/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Epoch 69: f1-score: 0.8226 - recall: 0.8220
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.8831 - loss: 0.2695 - val_accuracy: 0.8497 - val_loss: 0.4219 - f1_score: 0.8226 - recall: 0.8220
# Epoch 70/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 70: f1-score: 0.8238 - recall: 0.8255
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.8854 - loss: 0.2786 - val_accuracy: 0.8530 - val_loss: 0.4134 - f1_score: 0.8238 - recall: 0.8255
# Epoch 71/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 71: f1-score: 0.8275 - recall: 0.8242
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8933 - loss: 0.2591 - val_accuracy: 0.8606 - val_loss: 0.4093 - f1_score: 0.8275 - recall: 0.8242
# Epoch 72/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 72: f1-score: 0.8151 - recall: 0.8161
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8846 - loss: 0.2710 - val_accuracy: 0.8615 - val_loss: 0.3975 - f1_score: 0.8151 - recall: 0.8161
# Epoch 73/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 73: f1-score: 0.8216 - recall: 0.8208
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8838 - loss: 0.2664 - val_accuracy: 0.8539 - val_loss: 0.4176 - f1_score: 0.8216 - recall: 0.8208
# Epoch 74/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 74: f1-score: 0.8246 - recall: 0.8302
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8863 - loss: 0.2677 - val_accuracy: 0.8530 - val_loss: 0.4170 - f1_score: 0.8246 - recall: 0.8302
# Epoch 75/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 75: f1-score: 0.8290 - recall: 0.8346
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8999 - loss: 0.2450 - val_accuracy: 0.8573 - val_loss: 0.3866 - f1_score: 0.8290 - recall: 0.8346
# Epoch 76/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 76: f1-score: 0.8318 - recall: 0.8356
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.9022 - loss: 0.2370 - val_accuracy: 0.8598 - val_loss: 0.3982 - f1_score: 0.8318 - recall: 0.8356
# Epoch 77/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 77: f1-score: 0.8400 - recall: 0.8286
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.8956 - loss: 0.2790 - val_accuracy: 0.8649 - val_loss: 0.3737 - f1_score: 0.8400 - recall: 0.8286
# Epoch 78/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch 78: f1-score: 0.8307 - recall: 0.8310
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.9028 - loss: 0.2510 - val_accuracy: 0.8564 - val_loss: 0.3999 - f1_score: 0.8307 - recall: 0.8310
# Epoch 79/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 79: f1-score: 0.8284 - recall: 0.8314
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.8912 - loss: 0.2516 - val_accuracy: 0.8539 - val_loss: 0.4090 - f1_score: 0.8284 - recall: 0.8314
# Epoch 80/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 80: f1-score: 0.8212 - recall: 0.8134
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9012 - loss: 0.2331 - val_accuracy: 0.8632 - val_loss: 0.4056 - f1_score: 0.8212 - recall: 0.8134
# Epoch 81/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 81: f1-score: 0.8291 - recall: 0.8227
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9083 - loss: 0.2321 - val_accuracy: 0.8539 - val_loss: 0.4007 - f1_score: 0.8291 - recall: 0.8227
# Epoch 82/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 82: f1-score: 0.8228 - recall: 0.8238
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.8999 - loss: 0.2463 - val_accuracy: 0.8547 - val_loss: 0.4054 - f1_score: 0.8228 - recall: 0.8238
# Epoch 83/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 83: f1-score: 0.8333 - recall: 0.8290
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9009 - loss: 0.2484 - val_accuracy: 0.8615 - val_loss: 0.4135 - f1_score: 0.8333 - recall: 0.8290
# Epoch 84/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 84: f1-score: 0.8335 - recall: 0.8285
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8949 - loss: 0.2362 - val_accuracy: 0.8556 - val_loss: 0.4079 - f1_score: 0.8335 - recall: 0.8285
# Epoch 85/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 85: f1-score: 0.8263 - recall: 0.8249
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step - accuracy: 0.8985 - loss: 0.2316 - val_accuracy: 0.8581 - val_loss: 0.4075 - f1_score: 0.8263 - recall: 0.8249
# Epoch 86/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 86: f1-score: 0.8168 - recall: 0.8114
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9050 - loss: 0.2275 - val_accuracy: 0.8598 - val_loss: 0.4117 - f1_score: 0.8168 - recall: 0.8114
# Epoch 87/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 87: f1-score: 0.8241 - recall: 0.8104
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8886 - loss: 0.2564 - val_accuracy: 0.8598 - val_loss: 0.4182 - f1_score: 0.8241 - recall: 0.8104
# Epoch 88/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Epoch 88: f1-score: 0.8207 - recall: 0.8135
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.9033 - loss: 0.2375 - val_accuracy: 0.8666 - val_loss: 0.4011 - f1_score: 0.8207 - recall: 0.8135
# Epoch 89/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 89: f1-score: 0.8173 - recall: 0.8139
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9111 - loss: 0.2270 - val_accuracy: 0.8547 - val_loss: 0.4013 - f1_score: 0.8173 - recall: 0.8139
# Epoch 90/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 90: f1-score: 0.8210 - recall: 0.8146
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9149 - loss: 0.2153 - val_accuracy: 0.8623 - val_loss: 0.4214 - f1_score: 0.8210 - recall: 0.8146
# Epoch 91/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 91: f1-score: 0.8210 - recall: 0.8165
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9080 - loss: 0.2315 - val_accuracy: 0.8581 - val_loss: 0.4122 - f1_score: 0.8210 - recall: 0.8165
# Epoch 92/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 92: f1-score: 0.8212 - recall: 0.8267
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9027 - loss: 0.2125 - val_accuracy: 0.8573 - val_loss: 0.4002 - f1_score: 0.8212 - recall: 0.8267
# Epoch 93/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 93: f1-score: 0.8247 - recall: 0.8205
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8946 - loss: 0.2547 - val_accuracy: 0.8471 - val_loss: 0.4276 - f1_score: 0.8247 - recall: 0.8205
# Epoch 94/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 94: f1-score: 0.8385 - recall: 0.8370
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.8936 - loss: 0.2489 - val_accuracy: 0.8632 - val_loss: 0.3744 - f1_score: 0.8385 - recall: 0.8370
# Epoch 95/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 95: f1-score: 0.8299 - recall: 0.8330
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9004 - loss: 0.2286 - val_accuracy: 0.8547 - val_loss: 0.3853 - f1_score: 0.8299 - recall: 0.8330
# Epoch 96/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 96: f1-score: 0.8197 - recall: 0.8184
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9009 - loss: 0.2368 - val_accuracy: 0.8539 - val_loss: 0.4013 - f1_score: 0.8197 - recall: 0.8184
# Epoch 97/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch 97: f1-score: 0.8371 - recall: 0.8344
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.8928 - loss: 0.2548 - val_accuracy: 0.8564 - val_loss: 0.4256 - f1_score: 0.8371 - recall: 0.8344
# Epoch 98/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 98: f1-score: 0.8256 - recall: 0.8289
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9259 - loss: 0.1889 - val_accuracy: 0.8573 - val_loss: 0.4181 - f1_score: 0.8256 - recall: 0.8289
# Epoch 99/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 99: f1-score: 0.8280 - recall: 0.8377
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9107 - loss: 0.2190 - val_accuracy: 0.8598 - val_loss: 0.4219 - f1_score: 0.8280 - recall: 0.8377
# Epoch 100/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch 100: f1-score: 0.8343 - recall: 0.8275
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9010 - loss: 0.2119 - val_accuracy: 0.8598 - val_loss: 0.4172 - f1_score: 0.8343 - recall: 0.8275
# Epoch 101/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 101: f1-score: 0.8317 - recall: 0.8255
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9002 - loss: 0.2317 - val_accuracy: 0.8606 - val_loss: 0.4551 - f1_score: 0.8317 - recall: 0.8255
# Epoch 102/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 102: f1-score: 0.8260 - recall: 0.8325
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9145 - loss: 0.2088 - val_accuracy: 0.8556 - val_loss: 0.4314 - f1_score: 0.8260 - recall: 0.8325
# Epoch 103/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Epoch 103: f1-score: 0.8279 - recall: 0.8378
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.9157 - loss: 0.2171 - val_accuracy: 0.8623 - val_loss: 0.4119 - f1_score: 0.8279 - recall: 0.8378
# Epoch 104/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 104: f1-score: 0.8417 - recall: 0.8455
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9152 - loss: 0.2181 - val_accuracy: 0.8674 - val_loss: 0.4182 - f1_score: 0.8417 - recall: 0.8455
# Epoch 105/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 105: f1-score: 0.8243 - recall: 0.8266
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8964 - loss: 0.2385 - val_accuracy: 0.8556 - val_loss: 0.4434 - f1_score: 0.8243 - recall: 0.8266
# Epoch 106/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 106: f1-score: 0.8293 - recall: 0.8245
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9083 - loss: 0.2025 - val_accuracy: 0.8640 - val_loss: 0.4308 - f1_score: 0.8293 - recall: 0.8245
# Epoch 107/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 107: f1-score: 0.8354 - recall: 0.8407
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9021 - loss: 0.2126 - val_accuracy: 0.8632 - val_loss: 0.4206 - f1_score: 0.8354 - recall: 0.8407
# Epoch 108/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 108: f1-score: 0.8259 - recall: 0.8253
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9166 - loss: 0.1995 - val_accuracy: 0.8682 - val_loss: 0.3842 - f1_score: 0.8259 - recall: 0.8253
# Epoch 109/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Epoch 109: f1-score: 0.8289 - recall: 0.8332
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - accuracy: 0.9149 - loss: 0.2065 - val_accuracy: 0.8649 - val_loss: 0.4084 - f1_score: 0.8289 - recall: 0.8332
# Epoch 110/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 110: f1-score: 0.8281 - recall: 0.8367
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9052 - loss: 0.2205 - val_accuracy: 0.8623 - val_loss: 0.4190 - f1_score: 0.8281 - recall: 0.8367
# Epoch 111/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 111: f1-score: 0.8321 - recall: 0.8387
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9128 - loss: 0.2134 - val_accuracy: 0.8666 - val_loss: 0.4090 - f1_score: 0.8321 - recall: 0.8387
# Epoch 112/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 112: f1-score: 0.8290 - recall: 0.8282
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8979 - loss: 0.2255 - val_accuracy: 0.8623 - val_loss: 0.4105 - f1_score: 0.8290 - recall: 0.8282
# Epoch 113/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 113: f1-score: 0.8364 - recall: 0.8365
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9037 - loss: 0.2220 - val_accuracy: 0.8598 - val_loss: 0.4239 - f1_score: 0.8364 - recall: 0.8365
# Epoch 114/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 114: f1-score: 0.8381 - recall: 0.8398
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.8957 - loss: 0.2413 - val_accuracy: 0.8666 - val_loss: 0.4148 - f1_score: 0.8381 - recall: 0.8398
# Epoch 115/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 115: f1-score: 0.8314 - recall: 0.8295
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.9012 - loss: 0.2199 - val_accuracy: 0.8649 - val_loss: 0.4116 - f1_score: 0.8314 - recall: 0.8295
# Epoch 116/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 116: f1-score: 0.8327 - recall: 0.8280
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9058 - loss: 0.2163 - val_accuracy: 0.8564 - val_loss: 0.4054 - f1_score: 0.8327 - recall: 0.8280
# Epoch 117/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 117: f1-score: 0.8297 - recall: 0.8393
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9155 - loss: 0.1967 - val_accuracy: 0.8623 - val_loss: 0.4536 - f1_score: 0.8297 - recall: 0.8393
# Epoch 118/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 118: f1-score: 0.8375 - recall: 0.8460
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9161 - loss: 0.2044 - val_accuracy: 0.8666 - val_loss: 0.3993 - f1_score: 0.8375 - recall: 0.8460
# Epoch 119/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch 119: f1-score: 0.8449 - recall: 0.8487
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9186 - loss: 0.1902 - val_accuracy: 0.8691 - val_loss: 0.4473 - f1_score: 0.8449 - recall: 0.8487
# Epoch 120/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 120: f1-score: 0.8246 - recall: 0.8216
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9128 - loss: 0.2176 - val_accuracy: 0.8657 - val_loss: 0.4104 - f1_score: 0.8246 - recall: 0.8216
# Epoch 121/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 121: f1-score: 0.8259 - recall: 0.8382
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9014 - loss: 0.2045 - val_accuracy: 0.8615 - val_loss: 0.4432 - f1_score: 0.8259 - recall: 0.8382
# Epoch 122/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 122: f1-score: 0.8409 - recall: 0.8366
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9040 - loss: 0.2206 - val_accuracy: 0.8590 - val_loss: 0.4085 - f1_score: 0.8409 - recall: 0.8366
# Epoch 123/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 123: f1-score: 0.8368 - recall: 0.8335
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8982 - loss: 0.2147 - val_accuracy: 0.8606 - val_loss: 0.4195 - f1_score: 0.8368 - recall: 0.8335
# Epoch 124/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 124: f1-score: 0.8313 - recall: 0.8436
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9024 - loss: 0.2107 - val_accuracy: 0.8657 - val_loss: 0.4253 - f1_score: 0.8313 - recall: 0.8436
# Epoch 125/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 125: f1-score: 0.8351 - recall: 0.8310
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9007 - loss: 0.2160 - val_accuracy: 0.8657 - val_loss: 0.4229 - f1_score: 0.8351 - recall: 0.8310
# Epoch 126/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch 126: f1-score: 0.8289 - recall: 0.8278
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.9047 - loss: 0.2050 - val_accuracy: 0.8623 - val_loss: 0.4093 - f1_score: 0.8289 - recall: 0.8278
# Epoch 127/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 127: f1-score: 0.8286 - recall: 0.8376
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9108 - loss: 0.2048 - val_accuracy: 0.8682 - val_loss: 0.4239 - f1_score: 0.8286 - recall: 0.8376
# Epoch 128/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 128: f1-score: 0.8274 - recall: 0.8346
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9061 - loss: 0.2101 - val_accuracy: 0.8632 - val_loss: 0.4372 - f1_score: 0.8274 - recall: 0.8346
# Epoch 129/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 129: f1-score: 0.8318 - recall: 0.8247
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9168 - loss: 0.1907 - val_accuracy: 0.8640 - val_loss: 0.4077 - f1_score: 0.8318 - recall: 0.8247
# Epoch 130/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 130: f1-score: 0.8320 - recall: 0.8323
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9105 - loss: 0.2189 - val_accuracy: 0.8649 - val_loss: 0.3812 - f1_score: 0.8320 - recall: 0.8323
# Epoch 131/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 131: f1-score: 0.8342 - recall: 0.8305
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9142 - loss: 0.2020 - val_accuracy: 0.8657 - val_loss: 0.4202 - f1_score: 0.8342 - recall: 0.8305
# Epoch 132/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 132: f1-score: 0.8273 - recall: 0.8233
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9181 - loss: 0.1972 - val_accuracy: 0.8606 - val_loss: 0.4192 - f1_score: 0.8273 - recall: 0.8233
# Epoch 133/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 133: f1-score: 0.8389 - recall: 0.8508
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.9189 - loss: 0.1918 - val_accuracy: 0.8573 - val_loss: 0.4492 - f1_score: 0.8389 - recall: 0.8508
# Epoch 134/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 134: f1-score: 0.8394 - recall: 0.8349
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.9209 - loss: 0.1941 - val_accuracy: 0.8682 - val_loss: 0.4148 - f1_score: 0.8394 - recall: 0.8349
# Epoch 135/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 135: f1-score: 0.8283 - recall: 0.8237
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9136 - loss: 0.2101 - val_accuracy: 0.8725 - val_loss: 0.4035 - f1_score: 0.8283 - recall: 0.8237
# Epoch 136/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 136: f1-score: 0.8321 - recall: 0.8287
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8969 - loss: 0.2239 - val_accuracy: 0.8716 - val_loss: 0.4115 - f1_score: 0.8321 - recall: 0.8287
# Epoch 137/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Epoch 137: f1-score: 0.8260 - recall: 0.8313
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9063 - loss: 0.2026 - val_accuracy: 0.8682 - val_loss: 0.4487 - f1_score: 0.8260 - recall: 0.8313
# Epoch 138/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 138: f1-score: 0.8330 - recall: 0.8224
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.9111 - loss: 0.1889 - val_accuracy: 0.8649 - val_loss: 0.4597 - f1_score: 0.8330 - recall: 0.8224
# Epoch 139/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 139: f1-score: 0.8387 - recall: 0.8432
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9204 - loss: 0.1848 - val_accuracy: 0.8598 - val_loss: 0.4184 - f1_score: 0.8387 - recall: 0.8432
# Epoch 140/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 140: f1-score: 0.8369 - recall: 0.8292
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9206 - loss: 0.1883 - val_accuracy: 0.8691 - val_loss: 0.4262 - f1_score: 0.8369 - recall: 0.8292
# Epoch 141/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 141: f1-score: 0.8338 - recall: 0.8316
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.9199 - loss: 0.1883 - val_accuracy: 0.8573 - val_loss: 0.4471 - f1_score: 0.8338 - recall: 0.8316
# Epoch 142/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 142: f1-score: 0.8305 - recall: 0.8357
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9099 - loss: 0.2004 - val_accuracy: 0.8640 - val_loss: 0.4749 - f1_score: 0.8305 - recall: 0.8357
# Epoch 143/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 143: f1-score: 0.8411 - recall: 0.8466
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9197 - loss: 0.1890 - val_accuracy: 0.8632 - val_loss: 0.4282 - f1_score: 0.8411 - recall: 0.8466
# Epoch 144/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 144: f1-score: 0.8364 - recall: 0.8227
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - accuracy: 0.9038 - loss: 0.2096 - val_accuracy: 0.8691 - val_loss: 0.4680 - f1_score: 0.8364 - recall: 0.8227
# Epoch 145/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 145: f1-score: 0.8234 - recall: 0.8155
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9179 - loss: 0.1838 - val_accuracy: 0.8640 - val_loss: 0.4533 - f1_score: 0.8234 - recall: 0.8155
# Epoch 146/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Epoch 146: f1-score: 0.8338 - recall: 0.8342
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9238 - loss: 0.1683 - val_accuracy: 0.8632 - val_loss: 0.4337 - f1_score: 0.8338 - recall: 0.8342
# Epoch 147/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 147: f1-score: 0.8324 - recall: 0.8379
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.9172 - loss: 0.1932 - val_accuracy: 0.8556 - val_loss: 0.4596 - f1_score: 0.8324 - recall: 0.8379
# Epoch 148/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 148: f1-score: 0.8268 - recall: 0.8292
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.9164 - loss: 0.2085 - val_accuracy: 0.8699 - val_loss: 0.4240 - f1_score: 0.8268 - recall: 0.8292
# Epoch 149/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 149: f1-score: 0.8305 - recall: 0.8306
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9241 - loss: 0.1788 - val_accuracy: 0.8640 - val_loss: 0.4514 - f1_score: 0.8305 - recall: 0.8306
# Epoch 150/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 150: f1-score: 0.8252 - recall: 0.8192
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9198 - loss: 0.1848 - val_accuracy: 0.8632 - val_loss: 0.4174 - f1_score: 0.8252 - recall: 0.8192
# Epoch 151/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch 151: f1-score: 0.8347 - recall: 0.8261
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.9098 - loss: 0.2010 - val_accuracy: 0.8640 - val_loss: 0.4617 - f1_score: 0.8347 - recall: 0.8261
# Epoch 152/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 152: f1-score: 0.8336 - recall: 0.8431
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9162 - loss: 0.1931 - val_accuracy: 0.8640 - val_loss: 0.4304 - f1_score: 0.8336 - recall: 0.8431
# Epoch 153/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 153: f1-score: 0.8387 - recall: 0.8372
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9099 - loss: 0.1934 - val_accuracy: 0.8657 - val_loss: 0.4549 - f1_score: 0.8387 - recall: 0.8372
# Epoch 154/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Epoch 154: f1-score: 0.8400 - recall: 0.8456
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9102 - loss: 0.2220 - val_accuracy: 0.8623 - val_loss: 0.4416 - f1_score: 0.8400 - recall: 0.8456
# Epoch 155/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 155: f1-score: 0.8318 - recall: 0.8301
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9281 - loss: 0.1808 - val_accuracy: 0.8615 - val_loss: 0.4750 - f1_score: 0.8318 - recall: 0.8301
# Epoch 156/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 156: f1-score: 0.8297 - recall: 0.8246
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9153 - loss: 0.1912 - val_accuracy: 0.8632 - val_loss: 0.4672 - f1_score: 0.8297 - recall: 0.8246
# Epoch 157/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch 157: f1-score: 0.8332 - recall: 0.8362
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.9276 - loss: 0.1859 - val_accuracy: 0.8708 - val_loss: 0.4314 - f1_score: 0.8332 - recall: 0.8362
# Epoch 158/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 158: f1-score: 0.8262 - recall: 0.8268
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.9176 - loss: 0.1857 - val_accuracy: 0.8632 - val_loss: 0.4227 - f1_score: 0.8262 - recall: 0.8268
# Epoch 159/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 159: f1-score: 0.8307 - recall: 0.8218
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9118 - loss: 0.1973 - val_accuracy: 0.8716 - val_loss: 0.4547 - f1_score: 0.8307 - recall: 0.8218
# Epoch 160/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Epoch 160: f1-score: 0.8396 - recall: 0.8299
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9297 - loss: 0.1659 - val_accuracy: 0.8750 - val_loss: 0.4634 - f1_score: 0.8396 - recall: 0.8299
# Epoch 161/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 161: f1-score: 0.8334 - recall: 0.8395
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.9199 - loss: 0.1856 - val_accuracy: 0.8682 - val_loss: 0.4581 - f1_score: 0.8334 - recall: 0.8395
# Epoch 162/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 162: f1-score: 0.8361 - recall: 0.8413
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - accuracy: 0.9066 - loss: 0.1981 - val_accuracy: 0.8649 - val_loss: 0.4748 - f1_score: 0.8361 - recall: 0.8413
# Epoch 163/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 163: f1-score: 0.8294 - recall: 0.8303
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9236 - loss: 0.1697 - val_accuracy: 0.8623 - val_loss: 0.4569 - f1_score: 0.8294 - recall: 0.8303
# Epoch 164/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 164: f1-score: 0.8300 - recall: 0.8278
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - accuracy: 0.9176 - loss: 0.1749 - val_accuracy: 0.8657 - val_loss: 0.4706 - f1_score: 0.8300 - recall: 0.8278
# Epoch 165/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 165: f1-score: 0.8261 - recall: 0.8260
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.9159 - loss: 0.1815 - val_accuracy: 0.8750 - val_loss: 0.4590 - f1_score: 0.8261 - recall: 0.8260
# Epoch 166/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 166: f1-score: 0.8410 - recall: 0.8389
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9090 - loss: 0.1996 - val_accuracy: 0.8716 - val_loss: 0.4184 - f1_score: 0.8410 - recall: 0.8389
# Epoch 167/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 167: f1-score: 0.8260 - recall: 0.8307
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9262 - loss: 0.1799 - val_accuracy: 0.8674 - val_loss: 0.4412 - f1_score: 0.8260 - recall: 0.8307
# Epoch 168/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 168: f1-score: 0.8355 - recall: 0.8417
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9173 - loss: 0.1773 - val_accuracy: 0.8666 - val_loss: 0.4393 - f1_score: 0.8355 - recall: 0.8417
# Epoch 169/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Epoch 169: f1-score: 0.8299 - recall: 0.8253
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9205 - loss: 0.1670 - val_accuracy: 0.8725 - val_loss: 0.4435 - f1_score: 0.8299 - recall: 0.8253
# Epoch 170/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 170: f1-score: 0.8343 - recall: 0.8279
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9117 - loss: 0.1789 - val_accuracy: 0.8666 - val_loss: 0.4436 - f1_score: 0.8343 - recall: 0.8279
# Epoch 171/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 171: f1-score: 0.8389 - recall: 0.8438
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9138 - loss: 0.1942 - val_accuracy: 0.8674 - val_loss: 0.4385 - f1_score: 0.8389 - recall: 0.8438
# Epoch 172/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 172: f1-score: 0.8300 - recall: 0.8277
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9278 - loss: 0.1674 - val_accuracy: 0.8691 - val_loss: 0.4538 - f1_score: 0.8300 - recall: 0.8277
# Epoch 173/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 173: f1-score: 0.8295 - recall: 0.8311
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9102 - loss: 0.1892 - val_accuracy: 0.8674 - val_loss: 0.4591 - f1_score: 0.8295 - recall: 0.8311
# Epoch 174/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 174: f1-score: 0.8347 - recall: 0.8247
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9134 - loss: 0.1928 - val_accuracy: 0.8649 - val_loss: 0.4538 - f1_score: 0.8347 - recall: 0.8247
# Epoch 175/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 175: f1-score: 0.8313 - recall: 0.8282
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - accuracy: 0.9216 - loss: 0.1639 - val_accuracy: 0.8649 - val_loss: 0.4345 - f1_score: 0.8313 - recall: 0.8282
# Epoch 176/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch 176: f1-score: 0.8300 - recall: 0.8333
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.9154 - loss: 0.1756 - val_accuracy: 0.8640 - val_loss: 0.4778 - f1_score: 0.8300 - recall: 0.8333
# Epoch 177/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 177: f1-score: 0.8320 - recall: 0.8293
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.9082 - loss: 0.1815 - val_accuracy: 0.8606 - val_loss: 0.4633 - f1_score: 0.8320 - recall: 0.8293
# Epoch 178/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 178: f1-score: 0.8268 - recall: 0.8241
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9057 - loss: 0.2149 - val_accuracy: 0.8649 - val_loss: 0.4737 - f1_score: 0.8268 - recall: 0.8241
# Epoch 179/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 179: f1-score: 0.8451 - recall: 0.8472
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9215 - loss: 0.1669 - val_accuracy: 0.8682 - val_loss: 0.4738 - f1_score: 0.8451 - recall: 0.8472
# Epoch 180/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 180: f1-score: 0.8414 - recall: 0.8436
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.9090 - loss: 0.2010 - val_accuracy: 0.8666 - val_loss: 0.4461 - f1_score: 0.8414 - recall: 0.8436
# Epoch 181/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 181: f1-score: 0.8292 - recall: 0.8234
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9108 - loss: 0.1957 - val_accuracy: 0.8674 - val_loss: 0.4551 - f1_score: 0.8292 - recall: 0.8234
# Epoch 182/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 182: f1-score: 0.8309 - recall: 0.8321
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9158 - loss: 0.1932 - val_accuracy: 0.8674 - val_loss: 0.4564 - f1_score: 0.8309 - recall: 0.8321
# Epoch 183/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 183: f1-score: 0.8414 - recall: 0.8561
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.9320 - loss: 0.1577 - val_accuracy: 0.8657 - val_loss: 0.4744 - f1_score: 0.8414 - recall: 0.8561
# Epoch 184/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 184: f1-score: 0.8342 - recall: 0.8334
# ...
# Epoch 238: f1-score: 0.8384 - recall: 0.8327
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.9171 - loss: 0.1878 - val_accuracy: 0.8767 - val_loss: 0.4505 - f1_score: 0.8384 - recall: 0.8327
# Epoch 239/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 239: f1-score: 0.8446 - recall: 0.8418
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.9182 - loss: 0.1657 - val_accuracy: 0.8657 - val_loss: 0.4687 - f1_score: 0.8446 - recall: 0.8418
# Epoch 240/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 240: f1-score: 0.8258 - recall: 0.8249
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.9160 - loss: 0.1711 - val_accuracy: 0.8699 - val_loss: 0.4671 - f1_score: 0.8258 - recall: 0.8249
# Epoch 241/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Epoch 241: f1-score: 0.8418 - recall: 0.8539
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.9277 - loss: 0.1658 - val_accuracy: 0.8615 - val_loss: 0.4788 - f1_score: 0.8418 - recall: 0.8539
# Epoch 242/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 242: f1-score: 0.8387 - recall: 0.8336
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9286 - loss: 0.1576 - val_accuracy: 0.8691 - val_loss: 0.4877 - f1_score: 0.8387 - recall: 0.8336
# Epoch 243/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Epoch 243: f1-score: 0.8321 - recall: 0.8284
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9189 - loss: 0.1655 - val_accuracy: 0.8699 - val_loss: 0.4889 - f1_score: 0.8321 - recall: 0.8284
# Epoch 244/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 244: f1-score: 0.8330 - recall: 0.8306
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9149 - loss: 0.1731 - val_accuracy: 0.8682 - val_loss: 0.4788 - f1_score: 0.8330 - recall: 0.8306
# Epoch 245/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 245: f1-score: 0.8265 - recall: 0.8199
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.9261 - loss: 0.1590 - val_accuracy: 0.8682 - val_loss: 0.4922 - f1_score: 0.8265 - recall: 0.8199
# Epoch 246/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 246: f1-score: 0.8453 - recall: 0.8456
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.9227 - loss: 0.1651 - val_accuracy: 0.8682 - val_loss: 0.4904 - f1_score: 0.8453 - recall: 0.8456
# Epoch 247/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 247: f1-score: 0.8368 - recall: 0.8313
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9296 - loss: 0.1499 - val_accuracy: 0.8716 - val_loss: 0.4992 - f1_score: 0.8368 - recall: 0.8313
# Epoch 248/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 248: f1-score: 0.8251 - recall: 0.8173
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9243 - loss: 0.1520 - val_accuracy: 0.8657 - val_loss: 0.4591 - f1_score: 0.8251 - recall: 0.8173
# Epoch 249/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Epoch 249: f1-score: 0.8262 - recall: 0.8181
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.9261 - loss: 0.1704 - val_accuracy: 0.8674 - val_loss: 0.4781 - f1_score: 0.8262 - recall: 0.8181
# Epoch 250/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Epoch 250: f1-score: 0.8394 - recall: 0.8394
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.9170 - loss: 0.1661 - val_accuracy: 0.8691 - val_loss: 0.4654 - f1_score: 0.8394 - recall: 0.8394
# Epoch 251/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 251: f1-score: 0.8422 - recall: 0.8464
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9293 - loss: 0.1587 - val_accuracy: 0.8640 - val_loss: 0.4588 - f1_score: 0.8422 - recall: 0.8464
# Epoch 252/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Epoch 252: f1-score: 0.8385 - recall: 0.8368
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.9305 - loss: 0.1474 - val_accuracy: 0.8682 - val_loss: 0.4815 - f1_score: 0.8385 - recall: 0.8368
# Epoch 253/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 253: f1-score: 0.8405 - recall: 0.8347
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.9252 - loss: 0.1698 - val_accuracy: 0.8691 - val_loss: 0.4752 - f1_score: 0.8405 - recall: 0.8347
# Epoch 254/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 254: f1-score: 0.8399 - recall: 0.8393
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9225 - loss: 0.1641 - val_accuracy: 0.8699 - val_loss: 0.4485 - f1_score: 0.8399 - recall: 0.8393
# Epoch 255/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 255: f1-score: 0.8329 - recall: 0.8235
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9257 - loss: 0.1613 - val_accuracy: 0.8758 - val_loss: 0.4663 - f1_score: 0.8329 - recall: 0.8235
# Epoch 256/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch 256: f1-score: 0.8394 - recall: 0.8409
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.9319 - loss: 0.1608 - val_accuracy: 0.8682 - val_loss: 0.4903 - f1_score: 0.8394 - recall: 0.8409
# Epoch 257/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 257: f1-score: 0.8315 - recall: 0.8162
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.9253 - loss: 0.1530 - val_accuracy: 0.8801 - val_loss: 0.4696 - f1_score: 0.8315 - recall: 0.8162
# Epoch 258/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 258: f1-score: 0.8335 - recall: 0.8421
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9266 - loss: 0.1705 - val_accuracy: 0.8666 - val_loss: 0.4842 - f1_score: 0.8335 - recall: 0.8421
# Epoch 259/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Epoch 259: f1-score: 0.8283 - recall: 0.8199
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.9334 - loss: 0.1456 - val_accuracy: 0.8691 - val_loss: 0.4557 - f1_score: 0.8283 - recall: 0.8199
# Epoch 260/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 260: f1-score: 0.8441 - recall: 0.8382
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9225 - loss: 0.1696 - val_accuracy: 0.8716 - val_loss: 0.4713 - f1_score: 0.8441 - recall: 0.8382
# Epoch 261/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 261: f1-score: 0.8407 - recall: 0.8373
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9258 - loss: 0.1467 - val_accuracy: 0.8708 - val_loss: 0.4869 - f1_score: 0.8407 - recall: 0.8373
# Epoch 262/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Epoch 262: f1-score: 0.8426 - recall: 0.8447
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.9308 - loss: 0.1660 - val_accuracy: 0.8725 - val_loss: 0.4662 - f1_score: 0.8426 - recall: 0.8447
# Epoch 263/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Epoch 263: f1-score: 0.8415 - recall: 0.8374
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.9274 - loss: 0.1528 - val_accuracy: 0.8733 - val_loss: 0.4762 - f1_score: 0.8415 - recall: 0.8374
# Epoch 264/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 264: f1-score: 0.8431 - recall: 0.8530
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9211 - loss: 0.1495 - val_accuracy: 0.8682 - val_loss: 0.5357 - f1_score: 0.8431 - recall: 0.8530
# Epoch 265/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Epoch 265: f1-score: 0.8298 - recall: 0.8211
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9254 - loss: 0.1713 - val_accuracy: 0.8691 - val_loss: 0.5185 - f1_score: 0.8298 - recall: 0.8211
# Epoch 266/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 266: f1-score: 0.8384 - recall: 0.8435
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9239 - loss: 0.1601 - val_accuracy: 0.8716 - val_loss: 0.5031 - f1_score: 0.8384 - recall: 0.8435
# Epoch 267/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Epoch 267: f1-score: 0.8450 - recall: 0.8431
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.9308 - loss: 0.1538 - val_accuracy: 0.8742 - val_loss: 0.4613 - f1_score: 0.8450 - recall: 0.8431
# Epoch 268/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 268: f1-score: 0.8417 - recall: 0.8425
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.9302 - loss: 0.1482 - val_accuracy: 0.8733 - val_loss: 0.5228 - f1_score: 0.8417 - recall: 0.8425
# Epoch 269/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 269: f1-score: 0.8471 - recall: 0.8492
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9251 - loss: 0.1702 - val_accuracy: 0.8725 - val_loss: 0.4812 - f1_score: 0.8471 - recall: 0.8492
# Epoch 270/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch 270: f1-score: 0.8513 - recall: 0.8419
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9187 - loss: 0.1852 - val_accuracy: 0.8691 - val_loss: 0.4864 - f1_score: 0.8513 - recall: 0.8419
# Epoch 271/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 271: f1-score: 0.8474 - recall: 0.8434
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.9340 - loss: 0.1421 - val_accuracy: 0.8716 - val_loss: 0.4756 - f1_score: 0.8474 - recall: 0.8434
# Epoch 272/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 272: f1-score: 0.8322 - recall: 0.8181
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9204 - loss: 0.1595 - val_accuracy: 0.8775 - val_loss: 0.4837 - f1_score: 0.8322 - recall: 0.8181
# Epoch 273/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 273: f1-score: 0.8518 - recall: 0.8521
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9252 - loss: 0.1746 - val_accuracy: 0.8750 - val_loss: 0.4942 - f1_score: 0.8518 - recall: 0.8521
# Epoch 274/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 274: f1-score: 0.8437 - recall: 0.8382
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9278 - loss: 0.1664 - val_accuracy: 0.8682 - val_loss: 0.4949 - f1_score: 0.8437 - recall: 0.8382
# Epoch 275/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 275: f1-score: 0.8412 - recall: 0.8314
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9384 - loss: 0.1393 - val_accuracy: 0.8733 - val_loss: 0.5279 - f1_score: 0.8412 - recall: 0.8314
# Epoch 276/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 276: f1-score: 0.8361 - recall: 0.8271
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9238 - loss: 0.1735 - val_accuracy: 0.8716 - val_loss: 0.4937 - f1_score: 0.8361 - recall: 0.8271
# Epoch 277/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Epoch 277: f1-score: 0.8371 - recall: 0.8292
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9192 - loss: 0.1748 - val_accuracy: 0.8716 - val_loss: 0.4978 - f1_score: 0.8371 - recall: 0.8292
# Epoch 278/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Epoch 278: f1-score: 0.8269 - recall: 0.8193
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.9356 - loss: 0.1420 - val_accuracy: 0.8691 - val_loss: 0.5260 - f1_score: 0.8269 - recall: 0.8193
# Epoch 279/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 279: f1-score: 0.8255 - recall: 0.8245
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.9245 - loss: 0.1773 - val_accuracy: 0.8682 - val_loss: 0.5074 - f1_score: 0.8255 - recall: 0.8245
# Epoch 280/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 280: f1-score: 0.8370 - recall: 0.8246
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9205 - loss: 0.1716 - val_accuracy: 0.8742 - val_loss: 0.4928 - f1_score: 0.8370 - recall: 0.8246
# Epoch 281/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 281: f1-score: 0.8363 - recall: 0.8247
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.9329 - loss: 0.1528 - val_accuracy: 0.8733 - val_loss: 0.5035 - f1_score: 0.8363 - recall: 0.8247
# Epoch 282/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 282: f1-score: 0.8405 - recall: 0.8383
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9190 - loss: 0.1605 - val_accuracy: 0.8699 - val_loss: 0.5159 - f1_score: 0.8405 - recall: 0.8383
# Epoch 283/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 283: f1-score: 0.8436 - recall: 0.8455
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.9315 - loss: 0.1474 - val_accuracy: 0.8733 - val_loss: 0.5075 - f1_score: 0.8436 - recall: 0.8455
# Epoch 284/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 284: f1-score: 0.8344 - recall: 0.8319
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9330 - loss: 0.1491 - val_accuracy: 0.8758 - val_loss: 0.5199 - f1_score: 0.8344 - recall: 0.8319
# Epoch 285/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 285: f1-score: 0.8476 - recall: 0.8462
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9332 - loss: 0.1529 - val_accuracy: 0.8708 - val_loss: 0.5257 - f1_score: 0.8476 - recall: 0.8462
# Epoch 286/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 286: f1-score: 0.8384 - recall: 0.8427
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9342 - loss: 0.1465 - val_accuracy: 0.8716 - val_loss: 0.5425 - f1_score: 0.8384 - recall: 0.8427
# Epoch 287/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 287: f1-score: 0.8385 - recall: 0.8396
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9195 - loss: 0.1653 - val_accuracy: 0.8716 - val_loss: 0.5407 - f1_score: 0.8385 - recall: 0.8396
# Epoch 288/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Epoch 288: f1-score: 0.8404 - recall: 0.8416
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.9323 - loss: 0.1517 - val_accuracy: 0.8674 - val_loss: 0.5741 - f1_score: 0.8404 - recall: 0.8416
# Epoch 289/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Epoch 289: f1-score: 0.8412 - recall: 0.8466
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.9298 - loss: 0.1607 - val_accuracy: 0.8666 - val_loss: 0.5287 - f1_score: 0.8412 - recall: 0.8466
# Epoch 290/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 290: f1-score: 0.8379 - recall: 0.8309
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.9222 - loss: 0.1571 - val_accuracy: 0.8733 - val_loss: 0.5301 - f1_score: 0.8379 - recall: 0.8309
# Epoch 291/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Epoch 291: f1-score: 0.8434 - recall: 0.8322
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.9163 - loss: 0.1819 - val_accuracy: 0.8818 - val_loss: 0.4893 - f1_score: 0.8434 - recall: 0.8322
# Epoch 292/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 292: f1-score: 0.8438 - recall: 0.8418
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.9209 - loss: 0.1708 - val_accuracy: 0.8742 - val_loss: 0.5071 - f1_score: 0.8438 - recall: 0.8418
# Epoch 293/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 293: f1-score: 0.8235 - recall: 0.8148
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.9221 - loss: 0.1538 - val_accuracy: 0.8784 - val_loss: 0.5046 - f1_score: 0.8235 - recall: 0.8148
# Epoch 294/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Epoch 294: f1-score: 0.8402 - recall: 0.8405
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9264 - loss: 0.1455 - val_accuracy: 0.8640 - val_loss: 0.5468 - f1_score: 0.8402 - recall: 0.8405
# Epoch 295/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Epoch 295: f1-score: 0.8343 - recall: 0.8219
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9304 - loss: 0.1486 - val_accuracy: 0.8801 - val_loss: 0.5412 - f1_score: 0.8343 - recall: 0.8219
# Epoch 296/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 296: f1-score: 0.8433 - recall: 0.8474
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9325 - loss: 0.1505 - val_accuracy: 0.8691 - val_loss: 0.5407 - f1_score: 0.8433 - recall: 0.8474
# Epoch 297/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 297: f1-score: 0.8496 - recall: 0.8528
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9231 - loss: 0.1677 - val_accuracy: 0.8708 - val_loss: 0.5167 - f1_score: 0.8496 - recall: 0.8528
# Epoch 298/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Epoch 298: f1-score: 0.8375 - recall: 0.8249
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.9277 - loss: 0.1501 - val_accuracy: 0.8742 - val_loss: 0.5283 - f1_score: 0.8375 - recall: 0.8249
# Epoch 299/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 299: f1-score: 0.8315 - recall: 0.8287
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9321 - loss: 0.1437 - val_accuracy: 0.8699 - val_loss: 0.5616 - f1_score: 0.8315 - recall: 0.8287
# Epoch 300/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Epoch 300: f1-score: 0.8425 - recall: 0.8584
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.9362 - loss: 0.1543 - val_accuracy: 0.8666 - val_loss: 0.5361 - f1_score: 0.8425 - recall: 0.8584
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8712 - loss: 0.5103
# Test Loss: 0.5166121125221252, Test Accuracy: 0.871673583984375

# %%
classifier.evaluate_model(H)

# %%
y_pred_classes = classifier.predict(X_test)
classifier.generate_report(y_test, y_pred_classes)
# Out:
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1691
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.84        63
#            1       0.95      0.98      0.97       649
#            2       0.93      0.91      0.92       160
#            3       0.75      0.82      0.79       131
#            4       0.60      0.72      0.65        68
#            5       1.00      1.00      1.00        53
#            6       0.87      0.92      0.89       255
#            7       0.77      0.61      0.68       312
#
#     accuracy                           0.87      1691
#    macro avg       0.83      0.86      0.84      1691
# weighted avg       0.87      0.87      0.87      1691

# %%
# Calcula a matriz de confusão
labels = np.unique(y_test)
cm = confusion_matrix(y_test, y_pred_classes, labels=labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(cmap=plt.cm.Blues)
plt.show()

# %% [markdown]
# #### Treino e Avaliação com GPU

# %% [markdown]
# Para rodar o modelo com a GPU é necessário alocar uma máquina com GPU, por exemplo a T4 GPU, rodar todas as células anteriores (exceto a de treino com CPU que não é necessária) , e rodar a célula abaixo.

# %%
classifier = IntentClassifier()
X_train, X_test, y_train, y_test = classifier.prepare_data(chats_clients)
classifier.build_model(input_shape=(X_train.shape[1], X_train.shape[2]))
with tf.device('/gpu:0'):
  # Calcula o tempo da cpu
  start_time = time.time()
  history = classifier.train(X_train, X_test, y_train, y_test)
  # Para o cronômetro e salva o tempo da cpu
  time_gpu = time.time() - start_time
  history
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ bidirectional_1 (Bidirectional)      │ (None, 1, 256)              │         234,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 1, 256)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 64)                  │          82,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 8)                   │             264 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 323,176 (1.23 MB)
#  Trainable params: 323,176 (1.23 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Epoch 1: f1-score: 0.3021 - recall: 0.3235
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.3630 - loss: 1.7876 - val_accuracy: 0.5684 - val_loss: 1.2476 - f1_score: 0.3021 - recall: 0.3235
# Epoch 2/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 2: f1-score: 0.3281 - recall: 0.3640
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5688 - loss: 1.2837 - val_accuracy: 0.5904 - val_loss: 1.1492 - f1_score: 0.3281 - recall: 0.3640
# Epoch 3/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 3: f1-score: 0.3625 - recall: 0.3762
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.5887 - loss: 1.1784 - val_accuracy: 0.6073 - val_loss: 1.0617 - f1_score: 0.3625 - recall: 0.3762
# Epoch 4/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 4: f1-score: 0.3981 - recall: 0.4159
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6131 - loss: 1.0973 - val_accuracy: 0.6098 - val_loss: 1.0322 - f1_score: 0.3981 - recall: 0.4159
# Epoch 5/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 5: f1-score: 0.5073 - recall: 0.5078
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6338 - loss: 1.0107 - val_accuracy: 0.6698 - val_loss: 0.9203 - f1_score: 0.5073 - recall: 0.5078
# Epoch 6/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 6: f1-score: 0.5391 - recall: 0.5359
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6722 - loss: 0.9382 - val_accuracy: 0.6833 - val_loss: 0.8713 - f1_score: 0.5391 - recall: 0.5359
# Epoch 7/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 7: f1-score: 0.5256 - recall: 0.5389
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6723 - loss: 0.9100 - val_accuracy: 0.6757 - val_loss: 0.8770 - f1_score: 0.5256 - recall: 0.5389
# Epoch 8/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 8: f1-score: 0.5547 - recall: 0.5511
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6938 - loss: 0.8612 - val_accuracy: 0.7061 - val_loss: 0.8113 - f1_score: 0.5547 - recall: 0.5511
# Epoch 9/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 9: f1-score: 0.5559 - recall: 0.5476
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7065 - loss: 0.8175 - val_accuracy: 0.7095 - val_loss: 0.7972 - f1_score: 0.5559 - recall: 0.5476
# Epoch 10/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 10: f1-score: 0.5641 - recall: 0.5605
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7151 - loss: 0.8295 - val_accuracy: 0.7069 - val_loss: 0.7655 - f1_score: 0.5641 - recall: 0.5605
# Epoch 11/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 11: f1-score: 0.5941 - recall: 0.5855
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7242 - loss: 0.7695 - val_accuracy: 0.7162 - val_loss: 0.7449 - f1_score: 0.5941 - recall: 0.5855
# Epoch 12/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 12: f1-score: 0.5557 - recall: 0.5922
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7423 - loss: 0.7420 - val_accuracy: 0.7095 - val_loss: 0.7467 - f1_score: 0.5557 - recall: 0.5922
# Epoch 13/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 13: f1-score: 0.5882 - recall: 0.5797
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7049 - loss: 0.7671 - val_accuracy: 0.7171 - val_loss: 0.7291 - f1_score: 0.5882 - recall: 0.5797
# Epoch 14/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 14: f1-score: 0.6041 - recall: 0.5877
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.7497 - loss: 0.6856 - val_accuracy: 0.7280 - val_loss: 0.6991 - f1_score: 0.6041 - recall: 0.5877
# Epoch 15/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 15: f1-score: 0.6297 - recall: 0.6119
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7532 - loss: 0.6744 - val_accuracy: 0.7551 - val_loss: 0.6696 - f1_score: 0.6297 - recall: 0.6119
# Epoch 16/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 16: f1-score: 0.6362 - recall: 0.6282
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.7586 - loss: 0.6644 - val_accuracy: 0.7576 - val_loss: 0.6600 - f1_score: 0.6362 - recall: 0.6282
# Epoch 17/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 17: f1-score: 0.6619 - recall: 0.6584
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7585 - loss: 0.6324 - val_accuracy: 0.7559 - val_loss: 0.6443 - f1_score: 0.6619 - recall: 0.6584
# Epoch 18/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 18: f1-score: 0.6710 - recall: 0.6595
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7863 - loss: 0.6022 - val_accuracy: 0.7787 - val_loss: 0.6101 - f1_score: 0.6710 - recall: 0.6595
# Epoch 19/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 19: f1-score: 0.6968 - recall: 0.6793
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7806 - loss: 0.6345 - val_accuracy: 0.7711 - val_loss: 0.6092 - f1_score: 0.6968 - recall: 0.6793
# Epoch 20/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 20: f1-score: 0.6654 - recall: 0.6639
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7840 - loss: 0.5750 - val_accuracy: 0.7694 - val_loss: 0.5932 - f1_score: 0.6654 - recall: 0.6639
# Epoch 21/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 21: f1-score: 0.7077 - recall: 0.7051
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7888 - loss: 0.5712 - val_accuracy: 0.7762 - val_loss: 0.5792 - f1_score: 0.7077 - recall: 0.7051
# Epoch 22/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 22: f1-score: 0.6774 - recall: 0.6701
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8104 - loss: 0.5513 - val_accuracy: 0.7736 - val_loss: 0.5796 - f1_score: 0.6774 - recall: 0.6701
# Epoch 23/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 23: f1-score: 0.7059 - recall: 0.6916
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7968 - loss: 0.5307 - val_accuracy: 0.7838 - val_loss: 0.5636 - f1_score: 0.7059 - recall: 0.6916
# Epoch 24/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 24: f1-score: 0.7077 - recall: 0.7002
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8023 - loss: 0.5378 - val_accuracy: 0.7796 - val_loss: 0.5470 - f1_score: 0.7077 - recall: 0.7002
# Epoch 25/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 25: f1-score: 0.7312 - recall: 0.7142
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8157 - loss: 0.5005 - val_accuracy: 0.8007 - val_loss: 0.5200 - f1_score: 0.7312 - recall: 0.7142
# Epoch 26/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 26: f1-score: 0.7269 - recall: 0.7138
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8014 - loss: 0.5181 - val_accuracy: 0.8117 - val_loss: 0.5162 - f1_score: 0.7269 - recall: 0.7138
# Epoch 27/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 27: f1-score: 0.7174 - recall: 0.6931
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8051 - loss: 0.4768 - val_accuracy: 0.8007 - val_loss: 0.5401 - f1_score: 0.7174 - recall: 0.6931
# Epoch 28/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 28: f1-score: 0.7434 - recall: 0.7175
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8070 - loss: 0.5152 - val_accuracy: 0.8007 - val_loss: 0.5259 - f1_score: 0.7434 - recall: 0.7175
# Epoch 29/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 29: f1-score: 0.7522 - recall: 0.7182
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8258 - loss: 0.4614 - val_accuracy: 0.8108 - val_loss: 0.5147 - f1_score: 0.7522 - recall: 0.7182
# Epoch 30/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 30: f1-score: 0.7396 - recall: 0.7318
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8348 - loss: 0.4303 - val_accuracy: 0.7939 - val_loss: 0.4981 - f1_score: 0.7396 - recall: 0.7318
# Epoch 31/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 31: f1-score: 0.7666 - recall: 0.7445
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8428 - loss: 0.4078 - val_accuracy: 0.8167 - val_loss: 0.5020 - f1_score: 0.7666 - recall: 0.7445
# Epoch 32/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 32: f1-score: 0.7720 - recall: 0.7563
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8208 - loss: 0.4533 - val_accuracy: 0.8150 - val_loss: 0.4923 - f1_score: 0.7720 - recall: 0.7563
# Epoch 33/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 33: f1-score: 0.7573 - recall: 0.7345
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8396 - loss: 0.4118 - val_accuracy: 0.8100 - val_loss: 0.4849 - f1_score: 0.7573 - recall: 0.7345
# Epoch 34/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 34: f1-score: 0.7736 - recall: 0.7549
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8333 - loss: 0.4174 - val_accuracy: 0.8201 - val_loss: 0.4766 - f1_score: 0.7736 - recall: 0.7549
# Epoch 35/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 35: f1-score: 0.7493 - recall: 0.7391
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8484 - loss: 0.3958 - val_accuracy: 0.8142 - val_loss: 0.4746 - f1_score: 0.7493 - recall: 0.7391
# Epoch 36/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 36: f1-score: 0.7668 - recall: 0.7503
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8429 - loss: 0.4096 - val_accuracy: 0.8243 - val_loss: 0.4654 - f1_score: 0.7668 - recall: 0.7503
# Epoch 37/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 37: f1-score: 0.7599 - recall: 0.7413
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8446 - loss: 0.3946 - val_accuracy: 0.8193 - val_loss: 0.4541 - f1_score: 0.7599 - recall: 0.7413
# Epoch 38/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 38: f1-score: 0.7600 - recall: 0.7525
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8579 - loss: 0.3500 - val_accuracy: 0.8176 - val_loss: 0.4666 - f1_score: 0.7600 - recall: 0.7525
# Epoch 39/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 39: f1-score: 0.7767 - recall: 0.7536
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8403 - loss: 0.4038 - val_accuracy: 0.8209 - val_loss: 0.4693 - f1_score: 0.7767 - recall: 0.7536
# Epoch 40/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 40: f1-score: 0.7683 - recall: 0.7399
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8417 - loss: 0.3902 - val_accuracy: 0.8252 - val_loss: 0.4456 - f1_score: 0.7683 - recall: 0.7399
# Epoch 41/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 41: f1-score: 0.7875 - recall: 0.7764
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8341 - loss: 0.3949 - val_accuracy: 0.8395 - val_loss: 0.4497 - f1_score: 0.7875 - recall: 0.7764
# Epoch 42/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 42: f1-score: 0.7845 - recall: 0.7742
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8529 - loss: 0.3592 - val_accuracy: 0.8117 - val_loss: 0.4909 - f1_score: 0.7845 - recall: 0.7742
# Epoch 43/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 43: f1-score: 0.7908 - recall: 0.7874
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8579 - loss: 0.3605 - val_accuracy: 0.8319 - val_loss: 0.4467 - f1_score: 0.7908 - recall: 0.7874
# Epoch 44/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 44: f1-score: 0.8001 - recall: 0.7947
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8612 - loss: 0.3377 - val_accuracy: 0.8421 - val_loss: 0.4431 - f1_score: 0.8001 - recall: 0.7947
# Epoch 45/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 45: f1-score: 0.8102 - recall: 0.8154
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8522 - loss: 0.3551 - val_accuracy: 0.8488 - val_loss: 0.4316 - f1_score: 0.8102 - recall: 0.8154
# Epoch 46/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 46: f1-score: 0.7990 - recall: 0.7907
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8584 - loss: 0.3475 - val_accuracy: 0.8404 - val_loss: 0.4436 - f1_score: 0.7990 - recall: 0.7907
# Epoch 47/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 47: f1-score: 0.7906 - recall: 0.7777
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8660 - loss: 0.3201 - val_accuracy: 0.8345 - val_loss: 0.4589 - f1_score: 0.7906 - recall: 0.7777
# Epoch 48/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 48: f1-score: 0.8025 - recall: 0.8239
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8500 - loss: 0.3695 - val_accuracy: 0.8294 - val_loss: 0.4430 - f1_score: 0.8025 - recall: 0.8239
# Epoch 49/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 49: f1-score: 0.7995 - recall: 0.7910
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8703 - loss: 0.3146 - val_accuracy: 0.8480 - val_loss: 0.4490 - f1_score: 0.7995 - recall: 0.7910
# Epoch 50/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 50: f1-score: 0.8000 - recall: 0.7789
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8502 - loss: 0.3565 - val_accuracy: 0.8412 - val_loss: 0.4469 - f1_score: 0.8000 - recall: 0.7789
# Epoch 51/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 51: f1-score: 0.8002 - recall: 0.7954
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8710 - loss: 0.3156 - val_accuracy: 0.8404 - val_loss: 0.4377 - f1_score: 0.8002 - recall: 0.7954
# Epoch 52/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 52: f1-score: 0.8042 - recall: 0.8045
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8671 - loss: 0.3311 - val_accuracy: 0.8446 - val_loss: 0.4291 - f1_score: 0.8042 - recall: 0.8045
# Epoch 53/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 53: f1-score: 0.8146 - recall: 0.8112
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8553 - loss: 0.3417 - val_accuracy: 0.8463 - val_loss: 0.4130 - f1_score: 0.8146 - recall: 0.8112
# Epoch 54/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 54: f1-score: 0.8137 - recall: 0.8195
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8661 - loss: 0.3255 - val_accuracy: 0.8336 - val_loss: 0.4253 - f1_score: 0.8137 - recall: 0.8195
# Epoch 55/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 55: f1-score: 0.7958 - recall: 0.7921
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8788 - loss: 0.2939 - val_accuracy: 0.8590 - val_loss: 0.4069 - f1_score: 0.7958 - recall: 0.7921
# Epoch 56/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 56: f1-score: 0.8133 - recall: 0.8109
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8788 - loss: 0.3169 - val_accuracy: 0.8429 - val_loss: 0.4260 - f1_score: 0.8133 - recall: 0.8109
# Epoch 57/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 57: f1-score: 0.8190 - recall: 0.8070
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8752 - loss: 0.3076 - val_accuracy: 0.8564 - val_loss: 0.4094 - f1_score: 0.8190 - recall: 0.8070
# Epoch 58/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 58: f1-score: 0.8116 - recall: 0.8074
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8652 - loss: 0.3288 - val_accuracy: 0.8530 - val_loss: 0.4123 - f1_score: 0.8116 - recall: 0.8074
# Epoch 59/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 59: f1-score: 0.8169 - recall: 0.8140
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8768 - loss: 0.2910 - val_accuracy: 0.8556 - val_loss: 0.4261 - f1_score: 0.8169 - recall: 0.8140
# Epoch 60/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 60: f1-score: 0.8126 - recall: 0.8154
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8909 - loss: 0.2900 - val_accuracy: 0.8547 - val_loss: 0.4199 - f1_score: 0.8126 - recall: 0.8154
# Epoch 61/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 61: f1-score: 0.8285 - recall: 0.8214
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8884 - loss: 0.2855 - val_accuracy: 0.8480 - val_loss: 0.4173 - f1_score: 0.8285 - recall: 0.8214
# Epoch 62/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 62: f1-score: 0.8191 - recall: 0.8116
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8780 - loss: 0.2892 - val_accuracy: 0.8556 - val_loss: 0.4116 - f1_score: 0.8191 - recall: 0.8116
# Epoch 63/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 63: f1-score: 0.8206 - recall: 0.8186
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8797 - loss: 0.2851 - val_accuracy: 0.8505 - val_loss: 0.4206 - f1_score: 0.8206 - recall: 0.8186
# Epoch 64/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 64: f1-score: 0.8081 - recall: 0.8088
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8896 - loss: 0.2771 - val_accuracy: 0.8446 - val_loss: 0.4569 - f1_score: 0.8081 - recall: 0.8088
# Epoch 65/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 65: f1-score: 0.8153 - recall: 0.8121
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8856 - loss: 0.2657 - val_accuracy: 0.8471 - val_loss: 0.4367 - f1_score: 0.8153 - recall: 0.8121
# Epoch 66/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 66: f1-score: 0.8137 - recall: 0.8202
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8886 - loss: 0.2711 - val_accuracy: 0.8505 - val_loss: 0.4273 - f1_score: 0.8137 - recall: 0.8202
# Epoch 67/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 67: f1-score: 0.8267 - recall: 0.8293
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8875 - loss: 0.2781 - val_accuracy: 0.8547 - val_loss: 0.4112 - f1_score: 0.8267 - recall: 0.8293
# Epoch 68/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 68: f1-score: 0.8174 - recall: 0.8108
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8919 - loss: 0.2675 - val_accuracy: 0.8564 - val_loss: 0.4106 - f1_score: 0.8174 - recall: 0.8108
# Epoch 69/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 69: f1-score: 0.8179 - recall: 0.8307
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8847 - loss: 0.2662 - val_accuracy: 0.8463 - val_loss: 0.4289 - f1_score: 0.8179 - recall: 0.8307
# Epoch 70/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 70: f1-score: 0.8095 - recall: 0.8024
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8992 - loss: 0.2500 - val_accuracy: 0.8699 - val_loss: 0.4347 - f1_score: 0.8095 - recall: 0.8024
# Epoch 71/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 71: f1-score: 0.8181 - recall: 0.8246
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8868 - loss: 0.2781 - val_accuracy: 0.8497 - val_loss: 0.4223 - f1_score: 0.8181 - recall: 0.8246
# Epoch 72/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 72: f1-score: 0.8163 - recall: 0.8187
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8953 - loss: 0.2593 - val_accuracy: 0.8674 - val_loss: 0.3888 - f1_score: 0.8163 - recall: 0.8187
# Epoch 73/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 73: f1-score: 0.8177 - recall: 0.8155
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8914 - loss: 0.2493 - val_accuracy: 0.8716 - val_loss: 0.4031 - f1_score: 0.8177 - recall: 0.8155
# Epoch 74/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 74: f1-score: 0.8164 - recall: 0.8136
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8964 - loss: 0.2670 - val_accuracy: 0.8623 - val_loss: 0.3976 - f1_score: 0.8164 - recall: 0.8136
# Epoch 75/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 75: f1-score: 0.8217 - recall: 0.8230
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8860 - loss: 0.2743 - val_accuracy: 0.8522 - val_loss: 0.4023 - f1_score: 0.8217 - recall: 0.8230
# Epoch 76/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 76: f1-score: 0.8121 - recall: 0.8111
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8996 - loss: 0.2408 - val_accuracy: 0.8547 - val_loss: 0.4188 - f1_score: 0.8121 - recall: 0.8111
# Epoch 77/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 77: f1-score: 0.8188 - recall: 0.8192
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9025 - loss: 0.2513 - val_accuracy: 0.8539 - val_loss: 0.4267 - f1_score: 0.8188 - recall: 0.8192
# Epoch 78/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 78: f1-score: 0.8259 - recall: 0.8252
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8980 - loss: 0.2484 - val_accuracy: 0.8649 - val_loss: 0.3888 - f1_score: 0.8259 - recall: 0.8252
# Epoch 79/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 79: f1-score: 0.8168 - recall: 0.8175
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9042 - loss: 0.2420 - val_accuracy: 0.8598 - val_loss: 0.4016 - f1_score: 0.8168 - recall: 0.8175
# Epoch 80/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 80: f1-score: 0.8291 - recall: 0.8257
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8797 - loss: 0.2761 - val_accuracy: 0.8632 - val_loss: 0.4033 - f1_score: 0.8291 - recall: 0.8257
# Epoch 81/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 81: f1-score: 0.8250 - recall: 0.8306
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8886 - loss: 0.2684 - val_accuracy: 0.8632 - val_loss: 0.4045 - f1_score: 0.8250 - recall: 0.8306
# Epoch 82/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 82: f1-score: 0.8277 - recall: 0.8245
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9041 - loss: 0.2367 - val_accuracy: 0.8682 - val_loss: 0.4118 - f1_score: 0.8277 - recall: 0.8245
# Epoch 83/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 83: f1-score: 0.8242 - recall: 0.8095
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8947 - loss: 0.2366 - val_accuracy: 0.8716 - val_loss: 0.4059 - f1_score: 0.8242 - recall: 0.8095
# Epoch 84/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 84: f1-score: 0.8198 - recall: 0.8219
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8982 - loss: 0.2475 - val_accuracy: 0.8606 - val_loss: 0.4507 - f1_score: 0.8198 - recall: 0.8219
# Epoch 85/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 85: f1-score: 0.8167 - recall: 0.8188
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8933 - loss: 0.2561 - val_accuracy: 0.8590 - val_loss: 0.4178 - f1_score: 0.8167 - recall: 0.8188
# Epoch 86/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 86: f1-score: 0.8229 - recall: 0.8229
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8797 - loss: 0.2761 - val_accuracy: 0.8514 - val_loss: 0.4024 - f1_score: 0.8229 - recall: 0.8229
# Epoch 87/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 87: f1-score: 0.8227 - recall: 0.8193
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8913 - loss: 0.2398 - val_accuracy: 0.8657 - val_loss: 0.4137 - f1_score: 0.8227 - recall: 0.8193
# Epoch 88/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 88: f1-score: 0.8252 - recall: 0.8171
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8895 - loss: 0.2488 - val_accuracy: 0.8649 - val_loss: 0.4175 - f1_score: 0.8252 - recall: 0.8171
# Epoch 89/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 89: f1-score: 0.8185 - recall: 0.8276
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8928 - loss: 0.2374 - val_accuracy: 0.8556 - val_loss: 0.4205 - f1_score: 0.8185 - recall: 0.8276
# Epoch 90/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 90: f1-score: 0.8282 - recall: 0.8340
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9085 - loss: 0.2111 - val_accuracy: 0.8649 - val_loss: 0.4105 - f1_score: 0.8282 - recall: 0.8340
# Epoch 91/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 91: f1-score: 0.8182 - recall: 0.8209
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9175 - loss: 0.2095 - val_accuracy: 0.8649 - val_loss: 0.4366 - f1_score: 0.8182 - recall: 0.8209
# Epoch 92/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 92: f1-score: 0.8237 - recall: 0.8146
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9033 - loss: 0.2249 - val_accuracy: 0.8699 - val_loss: 0.4034 - f1_score: 0.8237 - recall: 0.8146
# Epoch 93/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 93: f1-score: 0.8249 - recall: 0.8188
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8987 - loss: 0.2318 - val_accuracy: 0.8674 - val_loss: 0.4246 - f1_score: 0.8249 - recall: 0.8188
# Epoch 94/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 94: f1-score: 0.8238 - recall: 0.8244
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8949 - loss: 0.2385 - val_accuracy: 0.8632 - val_loss: 0.4012 - f1_score: 0.8238 - recall: 0.8244
# Epoch 95/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 95: f1-score: 0.8143 - recall: 0.8159
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9042 - loss: 0.2345 - val_accuracy: 0.8649 - val_loss: 0.4231 - f1_score: 0.8143 - recall: 0.8159
# Epoch 96/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 96: f1-score: 0.8236 - recall: 0.8259
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9007 - loss: 0.2356 - val_accuracy: 0.8623 - val_loss: 0.4339 - f1_score: 0.8236 - recall: 0.8259
# Epoch 97/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 97: f1-score: 0.8221 - recall: 0.8194
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8922 - loss: 0.2589 - val_accuracy: 0.8640 - val_loss: 0.4390 - f1_score: 0.8221 - recall: 0.8194
# Epoch 98/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 98: f1-score: 0.8235 - recall: 0.8178
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8978 - loss: 0.2300 - val_accuracy: 0.8615 - val_loss: 0.4010 - f1_score: 0.8235 - recall: 0.8178
# Epoch 99/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 99: f1-score: 0.8257 - recall: 0.8305
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9021 - loss: 0.2281 - val_accuracy: 0.8573 - val_loss: 0.4189 - f1_score: 0.8257 - recall: 0.8305
# Epoch 100/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 100: f1-score: 0.8196 - recall: 0.8319
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9053 - loss: 0.2254 - val_accuracy: 0.8522 - val_loss: 0.4459 - f1_score: 0.8196 - recall: 0.8319
# Epoch 101/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 101: f1-score: 0.8211 - recall: 0.8137
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8967 - loss: 0.2308 - val_accuracy: 0.8674 - val_loss: 0.4358 - f1_score: 0.8211 - recall: 0.8137
# Epoch 102/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 102: f1-score: 0.8246 - recall: 0.8309
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9067 - loss: 0.2317 - val_accuracy: 0.8699 - val_loss: 0.4320 - f1_score: 0.8246 - recall: 0.8309
# Epoch 103/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 103: f1-score: 0.8174 - recall: 0.8221
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9065 - loss: 0.2078 - val_accuracy: 0.8606 - val_loss: 0.4320 - f1_score: 0.8174 - recall: 0.8221
# Epoch 104/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 104: f1-score: 0.8125 - recall: 0.8114
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8984 - loss: 0.2181 - val_accuracy: 0.8640 - val_loss: 0.4456 - f1_score: 0.8125 - recall: 0.8114
# Epoch 105/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 105: f1-score: 0.8177 - recall: 0.8178
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9190 - loss: 0.2105 - val_accuracy: 0.8691 - val_loss: 0.4123 - f1_score: 0.8177 - recall: 0.8178
# Epoch 106/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 106: f1-score: 0.8256 - recall: 0.8322
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9045 - loss: 0.2235 - val_accuracy: 0.8632 - val_loss: 0.4271 - f1_score: 0.8256 - recall: 0.8322
# Epoch 107/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 107: f1-score: 0.8219 - recall: 0.8242
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9024 - loss: 0.2361 - val_accuracy: 0.8606 - val_loss: 0.4432 - f1_score: 0.8219 - recall: 0.8242
# Epoch 108/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 108: f1-score: 0.8237 - recall: 0.8183
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8972 - loss: 0.2331 - val_accuracy: 0.8725 - val_loss: 0.4374 - f1_score: 0.8237 - recall: 0.8183
# Epoch 109/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 109: f1-score: 0.8263 - recall: 0.8290
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9102 - loss: 0.1955 - val_accuracy: 0.8649 - val_loss: 0.4227 - f1_score: 0.8263 - recall: 0.8290
# Epoch 110/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 110: f1-score: 0.8252 - recall: 0.8199
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8965 - loss: 0.2215 - val_accuracy: 0.8615 - val_loss: 0.4208 - f1_score: 0.8252 - recall: 0.8199
# Epoch 111/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 111: f1-score: 0.8244 - recall: 0.8296
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8982 - loss: 0.2147 - val_accuracy: 0.8691 - val_loss: 0.4156 - f1_score: 0.8244 - recall: 0.8296
# Epoch 112/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 112: f1-score: 0.8287 - recall: 0.8309
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9277 - loss: 0.1810 - val_accuracy: 0.8699 - val_loss: 0.4293 - f1_score: 0.8287 - recall: 0.8309
# Epoch 113/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 113: f1-score: 0.8332 - recall: 0.8511
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9002 - loss: 0.2169 - val_accuracy: 0.8606 - val_loss: 0.4469 - f1_score: 0.8332 - recall: 0.8511
# Epoch 114/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 114: f1-score: 0.8251 - recall: 0.8290
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9068 - loss: 0.2117 - val_accuracy: 0.8682 - val_loss: 0.4122 - f1_score: 0.8251 - recall: 0.8290
# Epoch 115/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 115: f1-score: 0.8346 - recall: 0.8336
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9034 - loss: 0.2198 - val_accuracy: 0.8657 - val_loss: 0.4073 - f1_score: 0.8346 - recall: 0.8336
# Epoch 116/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 116: f1-score: 0.8399 - recall: 0.8473
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9133 - loss: 0.2099 - val_accuracy: 0.8708 - val_loss: 0.4267 - f1_score: 0.8399 - recall: 0.8473
# Epoch 117/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 117: f1-score: 0.8304 - recall: 0.8323
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9011 - loss: 0.2306 - val_accuracy: 0.8716 - val_loss: 0.4360 - f1_score: 0.8304 - recall: 0.8323
# Epoch 118/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 118: f1-score: 0.8329 - recall: 0.8467
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9252 - loss: 0.1910 - val_accuracy: 0.8708 - val_loss: 0.4149 - f1_score: 0.8329 - recall: 0.8467
# Epoch 119/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 119: f1-score: 0.7960 - recall: 0.8085
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9116 - loss: 0.2097 - val_accuracy: 0.8640 - val_loss: 0.4388 - f1_score: 0.7960 - recall: 0.8085
# Epoch 120/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 120: f1-score: 0.8257 - recall: 0.8394
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8962 - loss: 0.2569 - val_accuracy: 0.8573 - val_loss: 0.4571 - f1_score: 0.8257 - recall: 0.8394
# Epoch 121/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 121: f1-score: 0.8277 - recall: 0.8353
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9090 - loss: 0.2075 - val_accuracy: 0.8649 - val_loss: 0.4415 - f1_score: 0.8277 - recall: 0.8353
# Epoch 122/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 122: f1-score: 0.8314 - recall: 0.8331
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9005 - loss: 0.2146 - val_accuracy: 0.8573 - val_loss: 0.4282 - f1_score: 0.8314 - recall: 0.8331
# Epoch 123/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 123: f1-score: 0.8321 - recall: 0.8187
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9107 - loss: 0.1905 - val_accuracy: 0.8708 - val_loss: 0.4287 - f1_score: 0.8321 - recall: 0.8187
# Epoch 124/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 124: f1-score: 0.8357 - recall: 0.8362
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9102 - loss: 0.2033 - val_accuracy: 0.8674 - val_loss: 0.4245 - f1_score: 0.8357 - recall: 0.8362
# Epoch 125/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 125: f1-score: 0.8342 - recall: 0.8334
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9162 - loss: 0.2079 - val_accuracy: 0.8640 - val_loss: 0.4097 - f1_score: 0.8342 - recall: 0.8334
# Epoch 126/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 126: f1-score: 0.8248 - recall: 0.8260
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9163 - loss: 0.1887 - val_accuracy: 0.8657 - val_loss: 0.4273 - f1_score: 0.8248 - recall: 0.8260
# Epoch 127/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 127: f1-score: 0.8347 - recall: 0.8452
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9137 - loss: 0.2059 - val_accuracy: 0.8598 - val_loss: 0.4474 - f1_score: 0.8347 - recall: 0.8452
# Epoch 128/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 128: f1-score: 0.8262 - recall: 0.8289
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9066 - loss: 0.2113 - val_accuracy: 0.8691 - val_loss: 0.4363 - f1_score: 0.8262 - recall: 0.8289
# Epoch 129/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 129: f1-score: 0.8305 - recall: 0.8286
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9107 - loss: 0.1846 - val_accuracy: 0.8623 - val_loss: 0.4338 - f1_score: 0.8305 - recall: 0.8286
# Epoch 130/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 130: f1-score: 0.8263 - recall: 0.8267
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9205 - loss: 0.1860 - val_accuracy: 0.8615 - val_loss: 0.4543 - f1_score: 0.8263 - recall: 0.8267
# Epoch 131/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 131: f1-score: 0.8354 - recall: 0.8444
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9113 - loss: 0.1991 - val_accuracy: 0.8573 - val_loss: 0.4627 - f1_score: 0.8354 - recall: 0.8444
# Epoch 132/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 132: f1-score: 0.8367 - recall: 0.8401
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9040 - loss: 0.2227 - val_accuracy: 0.8682 - val_loss: 0.4276 - f1_score: 0.8367 - recall: 0.8401
# Epoch 133/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 133: f1-score: 0.8347 - recall: 0.8337
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9193 - loss: 0.1881 - val_accuracy: 0.8733 - val_loss: 0.4360 - f1_score: 0.8347 - recall: 0.8337
# Epoch 134/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 134: f1-score: 0.8272 - recall: 0.8251
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9070 - loss: 0.2083 - val_accuracy: 0.8682 - val_loss: 0.4529 - f1_score: 0.8272 - recall: 0.8251
# Epoch 135/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 135: f1-score: 0.8274 - recall: 0.8257
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9051 - loss: 0.2120 - val_accuracy: 0.8674 - val_loss: 0.4451 - f1_score: 0.8274 - recall: 0.8257
# Epoch 136/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 136: f1-score: 0.8354 - recall: 0.8356
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9146 - loss: 0.2056 - val_accuracy: 0.8674 - val_loss: 0.4545 - f1_score: 0.8354 - recall: 0.8356
# Epoch 137/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 137: f1-score: 0.8334 - recall: 0.8303
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9103 - loss: 0.2006 - val_accuracy: 0.8708 - val_loss: 0.4346 - f1_score: 0.8334 - recall: 0.8303
# Epoch 138/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 138: f1-score: 0.8337 - recall: 0.8245
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9114 - loss: 0.1993 - val_accuracy: 0.8733 - val_loss: 0.4371 - f1_score: 0.8337 - recall: 0.8245
# Epoch 139/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 139: f1-score: 0.8353 - recall: 0.8309
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9147 - loss: 0.2097 - val_accuracy: 0.8581 - val_loss: 0.4498 - f1_score: 0.8353 - recall: 0.8309
# Epoch 140/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 140: f1-score: 0.8323 - recall: 0.8328
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9071 - loss: 0.2018 - val_accuracy: 0.8615 - val_loss: 0.4455 - f1_score: 0.8323 - recall: 0.8328
# Epoch 141/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 141: f1-score: 0.8349 - recall: 0.8269
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9165 - loss: 0.1899 - val_accuracy: 0.8708 - val_loss: 0.4305 - f1_score: 0.8349 - recall: 0.8269
# Epoch 142/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 142: f1-score: 0.8266 - recall: 0.8217
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9005 - loss: 0.2204 - val_accuracy: 0.8674 - val_loss: 0.4326 - f1_score: 0.8266 - recall: 0.8217
# Epoch 143/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 143: f1-score: 0.8316 - recall: 0.8472
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9118 - loss: 0.1928 - val_accuracy: 0.8623 - val_loss: 0.4448 - f1_score: 0.8316 - recall: 0.8472
# Epoch 144/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 144: f1-score: 0.8340 - recall: 0.8376
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9083 - loss: 0.2069 - val_accuracy: 0.8649 - val_loss: 0.4442 - f1_score: 0.8340 - recall: 0.8376
# Epoch 145/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 145: f1-score: 0.8335 - recall: 0.8312
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9106 - loss: 0.2039 - val_accuracy: 0.8640 - val_loss: 0.4435 - f1_score: 0.8335 - recall: 0.8312
# Epoch 146/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 146: f1-score: 0.8395 - recall: 0.8560
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9072 - loss: 0.1968 - val_accuracy: 0.8640 - val_loss: 0.4527 - f1_score: 0.8395 - recall: 0.8560
# Epoch 147/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 147: f1-score: 0.8310 - recall: 0.8286
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9044 - loss: 0.2080 - val_accuracy: 0.8640 - val_loss: 0.4534 - f1_score: 0.8310 - recall: 0.8286
# Epoch 148/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 148: f1-score: 0.8204 - recall: 0.8138
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9098 - loss: 0.1852 - val_accuracy: 0.8708 - val_loss: 0.4424 - f1_score: 0.8204 - recall: 0.8138
# Epoch 149/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 149: f1-score: 0.8309 - recall: 0.8255
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9230 - loss: 0.1882 - val_accuracy: 0.8682 - val_loss: 0.4403 - f1_score: 0.8309 - recall: 0.8255
# Epoch 150/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 150: f1-score: 0.8268 - recall: 0.8354
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9146 - loss: 0.1817 - val_accuracy: 0.8615 - val_loss: 0.4723 - f1_score: 0.8268 - recall: 0.8354
# Epoch 151/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 151: f1-score: 0.8326 - recall: 0.8281
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9178 - loss: 0.1776 - val_accuracy: 0.8682 - val_loss: 0.4610 - f1_score: 0.8326 - recall: 0.8281
# Epoch 152/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 152: f1-score: 0.8336 - recall: 0.8368
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9185 - loss: 0.1848 - val_accuracy: 0.8598 - val_loss: 0.4595 - f1_score: 0.8336 - recall: 0.8368
# Epoch 153/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 153: f1-score: 0.8344 - recall: 0.8325
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9185 - loss: 0.1830 - val_accuracy: 0.8640 - val_loss: 0.4618 - f1_score: 0.8344 - recall: 0.8325
# Epoch 154/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 154: f1-score: 0.8313 - recall: 0.8264
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9200 - loss: 0.1854 - val_accuracy: 0.8716 - val_loss: 0.4579 - f1_score: 0.8313 - recall: 0.8264
# Epoch 155/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 155: f1-score: 0.8296 - recall: 0.8318
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9117 - loss: 0.1910 - val_accuracy: 0.8623 - val_loss: 0.4512 - f1_score: 0.8296 - recall: 0.8318
# Epoch 156/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 156: f1-score: 0.8313 - recall: 0.8344
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9009 - loss: 0.1941 - val_accuracy: 0.8632 - val_loss: 0.4577 - f1_score: 0.8313 - recall: 0.8344
# Epoch 157/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 157: f1-score: 0.8432 - recall: 0.8586
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9018 - loss: 0.2087 - val_accuracy: 0.8598 - val_loss: 0.4741 - f1_score: 0.8432 - recall: 0.8586
# Epoch 158/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 158: f1-score: 0.8321 - recall: 0.8318
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9220 - loss: 0.1839 - val_accuracy: 0.8632 - val_loss: 0.4661 - f1_score: 0.8321 - recall: 0.8318
# Epoch 159/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 159: f1-score: 0.8373 - recall: 0.8355
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9146 - loss: 0.1850 - val_accuracy: 0.8666 - val_loss: 0.4440 - f1_score: 0.8373 - recall: 0.8355
# Epoch 160/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 160: f1-score: 0.8327 - recall: 0.8328
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9127 - loss: 0.1832 - val_accuracy: 0.8691 - val_loss: 0.4526 - f1_score: 0.8327 - recall: 0.8328
# Epoch 161/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 161: f1-score: 0.8317 - recall: 0.8299
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9121 - loss: 0.1889 - val_accuracy: 0.8657 - val_loss: 0.4619 - f1_score: 0.8317 - recall: 0.8299
# Epoch 162/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 162: f1-score: 0.8349 - recall: 0.8325
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9163 - loss: 0.1867 - val_accuracy: 0.8699 - val_loss: 0.4481 - f1_score: 0.8349 - recall: 0.8325
# Epoch 163/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 163: f1-score: 0.8206 - recall: 0.8218
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9155 - loss: 0.1846 - val_accuracy: 0.8666 - val_loss: 0.4720 - f1_score: 0.8206 - recall: 0.8218
# Epoch 164/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 164: f1-score: 0.8315 - recall: 0.8366
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9163 - loss: 0.1889 - val_accuracy: 0.8682 - val_loss: 0.4491 - f1_score: 0.8315 - recall: 0.8366
# Epoch 165/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 165: f1-score: 0.8338 - recall: 0.8233
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9114 - loss: 0.2036 - val_accuracy: 0.8649 - val_loss: 0.4618 - f1_score: 0.8338 - recall: 0.8233
# Epoch 166/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 166: f1-score: 0.8398 - recall: 0.8453
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9204 - loss: 0.1910 - val_accuracy: 0.8623 - val_loss: 0.4612 - f1_score: 0.8398 - recall: 0.8453
# Epoch 167/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 167: f1-score: 0.8442 - recall: 0.8518
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9175 - loss: 0.1837 - val_accuracy: 0.8682 - val_loss: 0.4544 - f1_score: 0.8442 - recall: 0.8518
# Epoch 168/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 168: f1-score: 0.8413 - recall: 0.8446
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9280 - loss: 0.1743 - val_accuracy: 0.8640 - val_loss: 0.4582 - f1_score: 0.8413 - recall: 0.8446
# Epoch 169/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 169: f1-score: 0.8324 - recall: 0.8261
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9200 - loss: 0.1813 - val_accuracy: 0.8666 - val_loss: 0.4690 - f1_score: 0.8324 - recall: 0.8261
# Epoch 170/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 170: f1-score: 0.8391 - recall: 0.8401
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9160 - loss: 0.1808 - val_accuracy: 0.8682 - val_loss: 0.4641 - f1_score: 0.8391 - recall: 0.8401
# Epoch 171/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 171: f1-score: 0.8334 - recall: 0.8287
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9123 - loss: 0.1966 - val_accuracy: 0.8649 - val_loss: 0.4657 - f1_score: 0.8334 - recall: 0.8287
# Epoch 172/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 172: f1-score: 0.8406 - recall: 0.8427
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9165 - loss: 0.1736 - val_accuracy: 0.8623 - val_loss: 0.4721 - f1_score: 0.8406 - recall: 0.8427
# Epoch 173/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 173: f1-score: 0.8311 - recall: 0.8351
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9151 - loss: 0.1998 - val_accuracy: 0.8682 - val_loss: 0.4506 - f1_score: 0.8311 - recall: 0.8351
# Epoch 174/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 174: f1-score: 0.8421 - recall: 0.8536
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9243 - loss: 0.1675 - val_accuracy: 0.8640 - val_loss: 0.4639 - f1_score: 0.8421 - recall: 0.8536
# Epoch 175/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 175: f1-score: 0.8353 - recall: 0.8417
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9188 - loss: 0.1916 - val_accuracy: 0.8649 - val_loss: 0.4649 - f1_score: 0.8353 - recall: 0.8417
# Epoch 176/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 176: f1-score: 0.8321 - recall: 0.8403
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9204 - loss: 0.1786 - val_accuracy: 0.8615 - val_loss: 0.4526 - f1_score: 0.8321 - recall: 0.8403
# Epoch 177/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 177: f1-score: 0.8330 - recall: 0.8359
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9212 - loss: 0.1751 - val_accuracy: 0.8666 - val_loss: 0.4772 - f1_score: 0.8330 - recall: 0.8359
# Epoch 178/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 178: f1-score: 0.8338 - recall: 0.8203
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9264 - loss: 0.1709 - val_accuracy: 0.8699 - val_loss: 0.4871 - f1_score: 0.8338 - recall: 0.8203
# Epoch 179/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 179: f1-score: 0.8311 - recall: 0.8329
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9194 - loss: 0.1949 - val_accuracy: 0.8649 - val_loss: 0.4616 - f1_score: 0.8311 - recall: 0.8329
# Epoch 180/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 180: f1-score: 0.8345 - recall: 0.8352
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9182 - loss: 0.1861 - val_accuracy: 0.8657 - val_loss: 0.4348 - f1_score: 0.8345 - recall: 0.8352
# Epoch 181/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 181: f1-score: 0.8293 - recall: 0.8304
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9167 - loss: 0.1780 - val_accuracy: 0.8742 - val_loss: 0.4264 - f1_score: 0.8293 - recall: 0.8304
# Epoch 182/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 182: f1-score: 0.8264 - recall: 0.8146
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9188 - loss: 0.1702 - val_accuracy: 0.8682 - val_loss: 0.4516 - f1_score: 0.8264 - recall: 0.8146
# Epoch 183/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 183: f1-score: 0.8353 - recall: 0.8355
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9219 - loss: 0.1837 - val_accuracy: 0.8590 - val_loss: 0.4809 - f1_score: 0.8353 - recall: 0.8355
# Epoch 184/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 184: f1-score: 0.8358 - recall: 0.8359
# ...
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 238: f1-score: 0.8342 - recall: 0.8349
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9215 - loss: 0.1679 - val_accuracy: 0.8649 - val_loss: 0.4976 - f1_score: 0.8342 - recall: 0.8349
# Epoch 239/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 239: f1-score: 0.8276 - recall: 0.8259
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9217 - loss: 0.1695 - val_accuracy: 0.8699 - val_loss: 0.4836 - f1_score: 0.8276 - recall: 0.8259
# Epoch 240/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 240: f1-score: 0.8249 - recall: 0.8193
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9254 - loss: 0.1517 - val_accuracy: 0.8657 - val_loss: 0.4611 - f1_score: 0.8249 - recall: 0.8193
# Epoch 241/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 241: f1-score: 0.8292 - recall: 0.8198
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9262 - loss: 0.1671 - val_accuracy: 0.8666 - val_loss: 0.4983 - f1_score: 0.8292 - recall: 0.8198
# Epoch 242/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 242: f1-score: 0.8278 - recall: 0.8258
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9228 - loss: 0.1633 - val_accuracy: 0.8674 - val_loss: 0.5149 - f1_score: 0.8278 - recall: 0.8258
# Epoch 243/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 243: f1-score: 0.8242 - recall: 0.8132
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9201 - loss: 0.1847 - val_accuracy: 0.8699 - val_loss: 0.4774 - f1_score: 0.8242 - recall: 0.8132
# Epoch 244/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 244: f1-score: 0.8363 - recall: 0.8415
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9334 - loss: 0.1577 - val_accuracy: 0.8716 - val_loss: 0.5195 - f1_score: 0.8363 - recall: 0.8415
# Epoch 245/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 245: f1-score: 0.8274 - recall: 0.8211
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9328 - loss: 0.1446 - val_accuracy: 0.8674 - val_loss: 0.4768 - f1_score: 0.8274 - recall: 0.8211
# Epoch 246/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 246: f1-score: 0.8317 - recall: 0.8305
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9213 - loss: 0.1752 - val_accuracy: 0.8691 - val_loss: 0.4974 - f1_score: 0.8317 - recall: 0.8305
# Epoch 247/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 247: f1-score: 0.8337 - recall: 0.8334
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9252 - loss: 0.1612 - val_accuracy: 0.8699 - val_loss: 0.5162 - f1_score: 0.8337 - recall: 0.8334
# Epoch 248/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 248: f1-score: 0.8354 - recall: 0.8315
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9342 - loss: 0.1480 - val_accuracy: 0.8606 - val_loss: 0.4966 - f1_score: 0.8354 - recall: 0.8315
# Epoch 249/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 249: f1-score: 0.8333 - recall: 0.8309
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9246 - loss: 0.1578 - val_accuracy: 0.8657 - val_loss: 0.5060 - f1_score: 0.8333 - recall: 0.8309
# Epoch 250/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 250: f1-score: 0.8318 - recall: 0.8240
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9324 - loss: 0.1549 - val_accuracy: 0.8716 - val_loss: 0.4892 - f1_score: 0.8318 - recall: 0.8240
# Epoch 251/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 251: f1-score: 0.8309 - recall: 0.8305
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9206 - loss: 0.1807 - val_accuracy: 0.8716 - val_loss: 0.4966 - f1_score: 0.8309 - recall: 0.8305
# Epoch 252/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 252: f1-score: 0.8443 - recall: 0.8619
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9360 - loss: 0.1544 - val_accuracy: 0.8682 - val_loss: 0.5118 - f1_score: 0.8443 - recall: 0.8619
# Epoch 253/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 253: f1-score: 0.8368 - recall: 0.8352
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9244 - loss: 0.1751 - val_accuracy: 0.8725 - val_loss: 0.4938 - f1_score: 0.8368 - recall: 0.8352
# Epoch 254/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 254: f1-score: 0.8294 - recall: 0.8328
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9208 - loss: 0.1637 - val_accuracy: 0.8674 - val_loss: 0.5052 - f1_score: 0.8294 - recall: 0.8328
# Epoch 255/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 255: f1-score: 0.8300 - recall: 0.8280
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9152 - loss: 0.1760 - val_accuracy: 0.8725 - val_loss: 0.5047 - f1_score: 0.8300 - recall: 0.8280
# Epoch 256/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 256: f1-score: 0.8303 - recall: 0.8274
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9220 - loss: 0.1648 - val_accuracy: 0.8742 - val_loss: 0.5093 - f1_score: 0.8303 - recall: 0.8274
# Epoch 257/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 257: f1-score: 0.8394 - recall: 0.8487
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9327 - loss: 0.1461 - val_accuracy: 0.8699 - val_loss: 0.5197 - f1_score: 0.8394 - recall: 0.8487
# Epoch 258/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 258: f1-score: 0.8375 - recall: 0.8454
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9220 - loss: 0.1732 - val_accuracy: 0.8674 - val_loss: 0.4838 - f1_score: 0.8375 - recall: 0.8454
# Epoch 259/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 259: f1-score: 0.8427 - recall: 0.8482
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9301 - loss: 0.1572 - val_accuracy: 0.8716 - val_loss: 0.5145 - f1_score: 0.8427 - recall: 0.8482
# Epoch 260/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 260: f1-score: 0.8391 - recall: 0.8287
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9302 - loss: 0.1628 - val_accuracy: 0.8750 - val_loss: 0.4894 - f1_score: 0.8391 - recall: 0.8287
# Epoch 261/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 261: f1-score: 0.8397 - recall: 0.8337
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9276 - loss: 0.1561 - val_accuracy: 0.8733 - val_loss: 0.5097 - f1_score: 0.8397 - recall: 0.8337
# Epoch 262/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 262: f1-score: 0.8301 - recall: 0.8403
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9260 - loss: 0.1586 - val_accuracy: 0.8750 - val_loss: 0.4796 - f1_score: 0.8301 - recall: 0.8403
# Epoch 263/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 263: f1-score: 0.8368 - recall: 0.8270
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9243 - loss: 0.1767 - val_accuracy: 0.8699 - val_loss: 0.4965 - f1_score: 0.8368 - recall: 0.8270
# Epoch 264/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 264: f1-score: 0.8352 - recall: 0.8298
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9255 - loss: 0.1545 - val_accuracy: 0.8699 - val_loss: 0.5170 - f1_score: 0.8352 - recall: 0.8298
# Epoch 265/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 265: f1-score: 0.8383 - recall: 0.8366
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9242 - loss: 0.1774 - val_accuracy: 0.8682 - val_loss: 0.4904 - f1_score: 0.8383 - recall: 0.8366
# Epoch 266/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 266: f1-score: 0.8370 - recall: 0.8224
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9189 - loss: 0.1658 - val_accuracy: 0.8725 - val_loss: 0.5053 - f1_score: 0.8370 - recall: 0.8224
# Epoch 267/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 267: f1-score: 0.8416 - recall: 0.8413
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9269 - loss: 0.1454 - val_accuracy: 0.8725 - val_loss: 0.5041 - f1_score: 0.8416 - recall: 0.8413
# Epoch 268/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 268: f1-score: 0.8309 - recall: 0.8333
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9344 - loss: 0.1457 - val_accuracy: 0.8758 - val_loss: 0.4733 - f1_score: 0.8309 - recall: 0.8333
# Epoch 269/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 269: f1-score: 0.8418 - recall: 0.8580
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9294 - loss: 0.1536 - val_accuracy: 0.8682 - val_loss: 0.5184 - f1_score: 0.8418 - recall: 0.8580
# Epoch 270/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 270: f1-score: 0.8370 - recall: 0.8507
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9314 - loss: 0.1493 - val_accuracy: 0.8674 - val_loss: 0.5033 - f1_score: 0.8370 - recall: 0.8507
# Epoch 271/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 271: f1-score: 0.8351 - recall: 0.8457
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9268 - loss: 0.1665 - val_accuracy: 0.8682 - val_loss: 0.4977 - f1_score: 0.8351 - recall: 0.8457
# Epoch 272/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 272: f1-score: 0.8359 - recall: 0.8287
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9213 - loss: 0.1594 - val_accuracy: 0.8657 - val_loss: 0.5358 - f1_score: 0.8359 - recall: 0.8287
# Epoch 273/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 273: f1-score: 0.8329 - recall: 0.8422
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9342 - loss: 0.1482 - val_accuracy: 0.8666 - val_loss: 0.5140 - f1_score: 0.8329 - recall: 0.8422
# Epoch 274/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 274: f1-score: 0.8308 - recall: 0.8295
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9322 - loss: 0.1638 - val_accuracy: 0.8666 - val_loss: 0.4889 - f1_score: 0.8308 - recall: 0.8295
# Epoch 275/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 275: f1-score: 0.8368 - recall: 0.8332
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9267 - loss: 0.1587 - val_accuracy: 0.8708 - val_loss: 0.5145 - f1_score: 0.8368 - recall: 0.8332
# Epoch 276/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 276: f1-score: 0.8296 - recall: 0.8325
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9282 - loss: 0.1545 - val_accuracy: 0.8733 - val_loss: 0.5308 - f1_score: 0.8296 - recall: 0.8325
# Epoch 277/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 277: f1-score: 0.8399 - recall: 0.8428
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9311 - loss: 0.1527 - val_accuracy: 0.8733 - val_loss: 0.5736 - f1_score: 0.8399 - recall: 0.8428
# Epoch 278/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 278: f1-score: 0.8386 - recall: 0.8405
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9256 - loss: 0.1712 - val_accuracy: 0.8725 - val_loss: 0.5404 - f1_score: 0.8386 - recall: 0.8405
# Epoch 279/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 279: f1-score: 0.8375 - recall: 0.8475
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9410 - loss: 0.1348 - val_accuracy: 0.8725 - val_loss: 0.5161 - f1_score: 0.8375 - recall: 0.8475
# Epoch 280/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 280: f1-score: 0.8352 - recall: 0.8349
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9298 - loss: 0.1686 - val_accuracy: 0.8708 - val_loss: 0.5274 - f1_score: 0.8352 - recall: 0.8349
# Epoch 281/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 281: f1-score: 0.8414 - recall: 0.8455
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9216 - loss: 0.1643 - val_accuracy: 0.8682 - val_loss: 0.4905 - f1_score: 0.8414 - recall: 0.8455
# Epoch 282/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 282: f1-score: 0.8420 - recall: 0.8551
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9341 - loss: 0.1497 - val_accuracy: 0.8716 - val_loss: 0.5052 - f1_score: 0.8420 - recall: 0.8551
# Epoch 283/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 283: f1-score: 0.8396 - recall: 0.8416
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9306 - loss: 0.1376 - val_accuracy: 0.8708 - val_loss: 0.5307 - f1_score: 0.8396 - recall: 0.8416
# Epoch 284/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 284: f1-score: 0.8467 - recall: 0.8532
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9392 - loss: 0.1461 - val_accuracy: 0.8674 - val_loss: 0.5335 - f1_score: 0.8467 - recall: 0.8532
# Epoch 285/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 285: f1-score: 0.8350 - recall: 0.8289
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9281 - loss: 0.1474 - val_accuracy: 0.8733 - val_loss: 0.5525 - f1_score: 0.8350 - recall: 0.8289
# Epoch 286/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 286: f1-score: 0.8302 - recall: 0.8231
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9377 - loss: 0.1407 - val_accuracy: 0.8809 - val_loss: 0.5359 - f1_score: 0.8302 - recall: 0.8231
# Epoch 287/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 287: f1-score: 0.8342 - recall: 0.8236
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9133 - loss: 0.1707 - val_accuracy: 0.8767 - val_loss: 0.5318 - f1_score: 0.8342 - recall: 0.8236
# Epoch 288/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 288: f1-score: 0.8403 - recall: 0.8483
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9246 - loss: 0.1606 - val_accuracy: 0.8691 - val_loss: 0.5145 - f1_score: 0.8403 - recall: 0.8483
# Epoch 289/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 289: f1-score: 0.8380 - recall: 0.8337
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9226 - loss: 0.1615 - val_accuracy: 0.8699 - val_loss: 0.5334 - f1_score: 0.8380 - recall: 0.8337
# Epoch 290/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 290: f1-score: 0.8305 - recall: 0.8391
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9306 - loss: 0.1389 - val_accuracy: 0.8725 - val_loss: 0.5226 - f1_score: 0.8305 - recall: 0.8391
# Epoch 291/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 291: f1-score: 0.8406 - recall: 0.8480
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9353 - loss: 0.1402 - val_accuracy: 0.8657 - val_loss: 0.5061 - f1_score: 0.8406 - recall: 0.8480
# Epoch 292/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 292: f1-score: 0.8335 - recall: 0.8236
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9252 - loss: 0.1594 - val_accuracy: 0.8674 - val_loss: 0.4992 - f1_score: 0.8335 - recall: 0.8236
# Epoch 293/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 293: f1-score: 0.8366 - recall: 0.8400
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9356 - loss: 0.1504 - val_accuracy: 0.8742 - val_loss: 0.4852 - f1_score: 0.8366 - recall: 0.8400
# Epoch 294/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 294: f1-score: 0.8504 - recall: 0.8608
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9301 - loss: 0.1541 - val_accuracy: 0.8649 - val_loss: 0.5249 - f1_score: 0.8504 - recall: 0.8608
# Epoch 295/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 295: f1-score: 0.8387 - recall: 0.8432
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9309 - loss: 0.1494 - val_accuracy: 0.8682 - val_loss: 0.5122 - f1_score: 0.8387 - recall: 0.8432
# Epoch 296/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 296: f1-score: 0.8364 - recall: 0.8297
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9194 - loss: 0.1604 - val_accuracy: 0.8691 - val_loss: 0.5179 - f1_score: 0.8364 - recall: 0.8297
# Epoch 297/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 297: f1-score: 0.8422 - recall: 0.8559
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9185 - loss: 0.1757 - val_accuracy: 0.8699 - val_loss: 0.5473 - f1_score: 0.8422 - recall: 0.8559
# Epoch 298/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 298: f1-score: 0.8447 - recall: 0.8499
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9283 - loss: 0.1526 - val_accuracy: 0.8699 - val_loss: 0.5459 - f1_score: 0.8447 - recall: 0.8499
# Epoch 299/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 299: f1-score: 0.8300 - recall: 0.8238
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9325 - loss: 0.1512 - val_accuracy: 0.8725 - val_loss: 0.5021 - f1_score: 0.8300 - recall: 0.8238
# Epoch 300/300
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 300: f1-score: 0.8480 - recall: 0.8616
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9247 - loss: 0.1648 - val_accuracy: 0.8632 - val_loss: 0.5251 - f1_score: 0.8480 - recall: 0.8616
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8771 - loss: 0.4901
# Test Loss: 0.5171012878417969, Test Accuracy: 0.8704908490180969

# %%
classifier.evaluate_model(history)

# %%
y_pred_classes = classifier.predict(X_test)
classifier.generate_report(y_test, y_pred_classes)
# Out:
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1691
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.86        63
#            1       0.96      0.97      0.96       649
#            2       0.94      0.91      0.92       160
#            3       0.77      0.80      0.79       131
#            4       0.60      0.76      0.68        68
#            5       1.00      1.00      1.00        53
#            6       0.88      0.89      0.89       255
#            7       0.74      0.65      0.69       312
#
#     accuracy                           0.87      1691
#    macro avg       0.84      0.86      0.85      1691
# weighted avg       0.87      0.87      0.87      1691

# %%
# Calcula a matriz de confusão
labels = np.unique(y_test)
cm = confusion_matrix(y_test, y_pred_classes, labels=labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(cmap=plt.cm.Blues)
plt.show()

# %% [markdown]
# #### Análise entre CPU e GPU

# %% [markdown]
# Para rodar esta análise é preciso rodar o modelo com a CPU e a GPU.
#
# Podemos ver que a GPU foi ligeiramente mais rápida, aproximadamente 421 segundos, ou aproximadamente 11%.

# %%
print(f'Tempo de treinamento com CPU: {time_cpu}')
print(f'Tempo de treinamento com GPU: {time_gpu}')
# Out:
# Tempo de treinamento com CPU: 1407.9579319953918
# Tempo de treinamento com GPU: 773.8021640777588

# %%
# Plotando o tempo de treinamento e inferência da CPU e GPU
plt.subplot(1, 2, 2)
plt.bar(['GPU Time'], [time_gpu], color=['blue'])
plt.bar(['CPU Time'], [time_cpu], color=['red'])
plt.ylabel('Time (seconds)')
plt.title('Training and Inference Time')

plt.show()

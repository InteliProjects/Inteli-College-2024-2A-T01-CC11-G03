# %%
# !python -m spacy download pt_core_news_sm
# !pip install googletrans==4.0.0-rc1
# !pip install enelvo
# Out:
# Collecting pt-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-3.7.0/pt_core_news_sm-3.7.0-py3-none-any.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 106.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from pt-core-news-sm==3.7.0) (3.7.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (13.8.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.16.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.1.2)
# Installing collected packages: pt-core-news-sm
# Successfully installed pt-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Collecting googletrans==4.0.0-rc1
#   Downloading googletrans-4.0.0rc1.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans==4.0.0-rc1)
#   Downloading httpx-0.13.3-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.7.4)
# Collecting hstspreload (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hstspreload-2024.8.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting idna==2.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading idna-2.10-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading httpcore-0.9.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h11-0.9.0-py2.py3-none-any.whl.metadata (8.1 kB)
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h2-3.2.0-py2.py3-none-any.whl.metadata (32 kB)
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl.metadata (7.2 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl.metadata (7.0 kB)
# Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 5.1 MB/s eta 0:00:00
# Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 8.0 MB/s eta 0:00:00
# Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.7 MB/s eta 0:00:00
# Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.6 MB/s eta 0:00:00
# Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 6.5 MB/s eta 0:00:00
# Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Downloading hstspreload-2024.8.1-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 44.9 MB/s eta 0:00:00
# Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 5.2 MB/s eta 0:00:00
# Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17397 sha256=d43726f0aae0a47d97ca08bf63f6bb51e4946fe4d0e016f1a52d09b3a62aa9e3
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.8
#     Uninstalling idna-3.8:
#       Successfully uninstalled idna-3.8
# Successfully installed chardet-3.0.4 googletrans-4.0.0rc1 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2024.8.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0
# Collecting enelvo
#   Downloading enelvo-0.15-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: editdistance>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from enelvo) (0.8.1)
# Collecting emoji==2.2.0 (from enelvo)
#   Downloading emoji-2.2.0.tar.gz (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.9/240.9 kB 6.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gensim>=4.1.2 in /usr/local/lib/python3.10/dist-packages (from enelvo) (4.3.3)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from enelvo) (1.26.4)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from enelvo) (0.9.0)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim>=4.1.2->enelvo) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim>=4.1.2->enelvo) (7.0.4)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim>=4.1.2->enelvo) (1.16.0)
# Downloading enelvo-0.15-py3-none-any.whl (27.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 76.0 MB/s eta 0:00:00
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-2.2.0-py3-none-any.whl size=234910 sha256=7bf571a4c77144f6a03b0aefc7e5dab5a4f26ce1192c70f56234a49da66bac9a
#   Stored in directory: /root/.cache/pip/wheels/02/3d/88/51a592b9ad17e7899126563698b4e3961983ebe85747228ba6
# Successfully built emoji
# Installing collected packages: emoji, enelvo
# Successfully installed emoji-2.2.0 enelvo-0.15

# %%
from google.colab import drive
from googletrans import Translator
from enelvo.normaliser import Normaliser
from nltk.corpus import stopwords
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import SimpleRNN, Dense, Concatenate, Input, LSTM, Dropout, Bidirectional
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import f1_score, recall_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report
from unittest.mock import patch, MagicMock
import matplotlib.pyplot as plt
import tensorflow as tf
import re
import unittest
import numpy as np
import pandas as pd
import spacy
import nltk

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Pré-processamento

# %% [markdown]
# ## 0) Base de Dados

# %%
norm = Normaliser(tokenizer='readable')
chats_clients = pd.read_csv('/content/drive/Shareddrives/grupo3moshi/augmented_data.csv')
chats_clients.head()
# Out:
#    No                              Intencao  \
# 0   1                        Como depositar
# 1   2                    Como fazer remessa
# 2   3                      Tempo de remessa
# 3   4  Pedido de envio via metodo "ByPhone"
# 4   5  Pedido de envio via metodo "ByPhone"
#
#                                             Pergunta  \
# 0  Boa dia.tudo bem?eu gostaria de saber sobre aq...
# 1                     Como enviar dinheiro do Japão?
# 2  Quanto tempo levará para o beneficiário recebe...
# 3  Boa tarde\nAcabei de fazer a transferência de ...
# 4  Poderia fazer a remessa de 22yenes para o BBB ...
#
#                                             Resposta
# 0  Bom dia! Sim, o sr pode utilizar o cartão de d...
# 1  Para se inscrever no serviço de remessa, por f...
# 2  Via de regra, as remessas serão pagas via PIX ...
# 3  iremos processar a sua solicitacao.\nMuito obr...
# 4  iremos processar a sua solicitacao.\nMuito obr...

# %%
chats_clients.fillna('erro ao processar a pergunta', inplace=True)

# %%
nlp_pt = spacy.load("pt_core_news_sm")

# %%
def correct_grammar(text):
  return norm.normalise(text)

# %% [markdown]
# ## 1) Word2Vec

# %% [markdown]
# O processo de Word2Vec é uma técnica de aprendizado de máquina com o objetivo de vetorizar palavras almejando preservar o contexto, convertendo o resultado para a forma numérica, para que os dados possam ser utilizados em modelos de aprendizado de máquina.
#
# O Word2Vec pode possuir 2 arquiteturas, sendo elas:
#
# - Skip-Gram: rede tenta prever as palavras de contexto ao redor de uma palavra central
# - CBOW: rede tenta prever a palavra central com base no contexto ao redor da palavra central.
#
# Para fins de comparação, ambas as técnicas serão abordadas no código a seguir:

# %% [markdown]
# ### 1.1) Skip-Gram

# %%
from gensim.models import Word2Vec
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize

# Tokenizando as colunas
chats_clients['Pergunta_tokens'] = chats_clients['Pergunta'].apply(lambda x: word_tokenize(x.lower()))
chats_clients['Resposta_tokens'] = chats_clients['Resposta'].apply(lambda x: word_tokenize(x.lower()))

# Unindo as listas de tokens de Pergunta e Resposta para o modelo processar a lista
sentences_skip = chats_clients['Pergunta_tokens'].tolist() + chats_clients['Resposta_tokens'].tolist()

# Utilizando o modelo Word2Vec
model = Word2Vec(sentences_skip, vector_size=100, window=5, min_count=1, sg=1)  #sg=1 para Skip-Gram
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ### 1.2) Resultados Obtidos

# %%
# Acessando o vetor de uma palavra
vector_dia_skip = model.wv['dia']
print(vector_dia_skip)
# Out:
# [-0.26775223  0.57817674  0.06501746 -0.13198577 -0.0162866  -0.32053125
#   0.68438333  0.02528406  0.15984471 -0.32278043  0.32283416 -0.5931242
#   0.06256542 -0.15231565 -0.2381931   0.09556933  0.24559233 -0.1132349
#   0.04261449 -0.1440163   0.17213431  0.03537409  0.17124328 -0.21593758
#  -0.29399896  0.12060051 -0.13703685 -0.22065623  0.0543394  -0.22999065
#   0.06246226  0.06420431  0.108389   -0.14155447 -0.07793944  0.1400825
#   0.1490279  -0.24472725 -0.19108564 -0.09812341  0.07075102 -0.23465297
#   0.08284451 -0.01925384  0.22655074  0.16606456 -0.0963831  -0.2707253
#   0.04866063  0.16221946  0.27889755 -0.09459215  0.11571394 -0.03533408
#  -0.35641074  0.06761176  0.31410757  0.25331837 -0.2050648   0.06803828
#  -0.06043484 -0.19163443 -0.08034967  0.06921001 -0.09022131 -0.14438403
#  -0.00162768  0.20808731 -0.08048407  0.13784875 -0.22473896 -0.00135946
#   0.49609652  0.3445016   0.11022658  0.1330405   0.11327435 -0.3005817
#  -0.02235943  0.12610886 -0.3561463  -0.0026406  -0.21103595 -0.00135248
#   0.3183347  -0.35855708  0.36561847  0.316787   -0.19672835  0.01628331
#   0.18421738  0.01741344  0.03953682  0.22520247  0.30390623  0.32620043
#   0.06519818 -0.09535664  0.15949892  0.38781205]

# %%
# Encontrando palavras similares
similar_words_dia_skip = model.wv.most_similar('dia')
print(similar_words_dia_skip)
# Out:
# [('plantão', 0.7513531446456909), ('bom', 0.7505833506584167), ('especial', 0.7449821829795837), ('defense', 0.7284111976623535), ('intelligence', 0.714687168598175), ('processaremos', 0.707280158996582), ('agency', 0.6925069689750671), ('!', 0.6921923756599426), ('895', 0.6828874945640564), ('sobreminhs', 0.680862307548523)]

# %%
# Encontrando palavras similares
similar_words_bom_skip = model.wv.most_similar('bom')
print(similar_words_bom_skip)
# Out:
# [('!', 0.8151847124099731), ('dia', 0.750583291053772), ('processaremos', 0.7479262351989746), ('defense', 0.7417274713516235), ('intelligence', 0.740342915058136), ('conforme', 0.7381069660186768), ('agency', 0.7281288504600525), ('plantão', 0.7169572114944458), ('895', 0.7113294005393982), ('mais', 0.706836462020874)]

# %%
# Encontrando palavras similares
similar_words_dinheiro_skip = model.wv.most_similar('dinheiro')
print(similar_words_dinheiro_skip)
# Out:
# [('enviam', 0.8854102492332458), ('japão', 0.8706771731376648), ('poder', 0.8378614783287048), ('mary', 0.8298928141593933), ('st.', 0.8277102708816528), ('lá', 0.8219535946846008), ('pro', 0.815409779548645), ('bethlehem', 0.8146581053733826), ('tempo', 0.8084879517555237), ('cair', 0.8064796328544617)]

# %%
# Encontrando palavras similares
similar_words_pix_skip = model.wv.most_similar('pix')
print(similar_words_pix_skip)
# Out:
# [('sendo', 0.9741376638412476), ('via', 0.9667537808418274), ('realizadas', 0.9615600109100342), ('feitos', 0.9533548355102539), ('pagamentos', 0.9445545077323914), ('maioria', 0.9413060545921326), ('estão', 0.9315557479858398), ('pagas', 0.9166324734687805), ('são', 0.89717698097229), ('chegam', 0.8955625295639038)]

# %% [markdown]
# ### 2.1) CBOW

# %%
# Unindo as listas de tokens de Pergunta e Resposta para o modelo processar a lista
sentences_CBOW = chats_clients['Pergunta_tokens'].tolist() + chats_clients['Resposta_tokens'].tolist()

# Utilizando o modelo Word2Vec
model_cbow = Word2Vec(sentences_CBOW, vector_size=100, window=5, min_count=1, sg=0)  #sg=0 para CBOW

# %% [markdown]
# ### 2.2) Resultados Obtidos

# %%
# Acessando o vetor de uma palavra
vector_dia_cbow = model_cbow.wv['dia']
print(vector_dia_cbow)
# Out:
# [-6.06847167e-01  8.28706473e-02 -4.76075299e-02  8.57109651e-02
#   2.46681094e-01 -4.91685450e-01  3.66922945e-01  6.53879762e-01
#  -1.28465310e-01 -5.82987487e-01  2.34569222e-01 -1.01703560e+00
#  -9.88721251e-02 -6.12462461e-02 -2.02412814e-01  1.89447358e-01
#  -1.10763066e-01 -5.42182028e-01 -1.81206465e-02  9.14154872e-02
#   6.41412616e-01  3.74433510e-02  3.30986500e-01 -1.53992087e-01
#  -5.50062060e-01  2.86232442e-01 -3.57604623e-01  2.80812860e-01
#  -1.44874021e-01 -2.84434617e-01  4.90425318e-01  1.20669223e-01
#  -3.41862917e-01 -2.02008769e-01 -1.96157604e-01  2.79749066e-01
#   1.15625568e-01 -6.57579482e-01 -2.15973154e-01 -4.45302576e-01
#   5.97900823e-02 -1.95173174e-01 -9.58427861e-02 -2.62548655e-01
#   2.60905921e-01  2.56988794e-01 -4.96952921e-01 -3.15416664e-01
#   2.37095088e-01  8.64323881e-03  6.81344807e-01 -4.98351008e-01
#   3.84730667e-01 -2.36044541e-01 -5.67693226e-02 -1.62179634e-01
#   7.28925526e-01  3.40993345e-01 -4.64369595e-01 -3.51146832e-02
#  -2.86561430e-01  6.06000945e-02  1.37396991e-01  4.96192165e-02
#  -6.20236814e-01  2.15869218e-01  1.56588107e-01  5.44513285e-01
#  -5.70183039e-01  2.81048983e-01 -3.68544698e-01 -6.49095029e-02
#   7.16249168e-01  6.45706058e-02  6.05822146e-01  2.15104283e-05
#   3.53195310e-01 -1.44531801e-01 -3.18937689e-01 -3.79000127e-01
#  -6.63052857e-01 -1.28525011e-02 -6.08223617e-01  6.38582826e-01
#  -1.85255203e-02 -5.81458628e-01  4.23683196e-01  2.43142977e-01
#  -2.49760494e-01 -3.23574394e-01  4.08345073e-01  5.26799262e-01
#   1.34150103e-01  3.11589271e-01  8.57089698e-01  4.07100797e-01
#  -1.19867161e-01  2.02692717e-01  6.18630171e-01  5.02158105e-01]

# %%
# Encontrando palavras similares
similar_words_dia_cbow = model_cbow.wv.most_similar('dia')
print(similar_words_dia_cbow)
# Out:
# [('bom', 0.9715335965156555), ('!', 0.9601024389266968), ('olá', 0.9576049447059631), ('noite', 0.9485138058662415), ('tarde', 0.9427953958511353), ('informar', 0.9411637783050537), ('feather', 0.9396428465843201), ('boa', 0.9349060654640198), ('uma', 0.9270160794258118), ('fiz', 0.9264461398124695)]

# %%
# Encontrando palavras similares
similar_words_bom_cbow = model_cbow.wv.most_similar('bom')
print(similar_words_bom_cbow)
# Out:
# [('dia', 0.9715335369110107), ('!', 0.9632455110549927), ('feather', 0.9556039571762085), ('olá', 0.9552845358848572), ('informar', 0.9525298476219177), ('noite', 0.9522715210914612), ('tarde', 0.9466104507446289), ('boa', 0.9453170299530029), ('uma', 0.9405238628387451), ('td', 0.9348506927490234)]

# %%
# Encontrando palavras similares
similar_words_dinheiro_cbow = model_cbow.wv.most_similar('dinheiro')
print(similar_words_dinheiro_cbow)
# Out:
# [('japão', 0.9941738247871399), ('enviar', 0.983680784702301), ('?', 0.9768919348716736), ('tempo', 0.9711207151412964), ('8', 0.96629798412323), ('exatamente', 0.9651689529418945), ('lado', 0.9641366004943848), ('levará', 0.9629144668579102), ('verso', 0.9608359336853027), ('fotos', 0.9599601030349731)]

# %%
# Encontrando palavras similares
similar_words_pix_cbow = model_cbow.wv.most_similar('pix')
print(similar_words_pix_cbow)
# Out:
# [('via', 0.9911543130874634), ('pagamentos', 0.9672412276268005), ('feitos', 0.9600024819374084), ('sendo', 0.9509522914886475), ('realizadas', 0.9395662546157837), ('estão', 0.9393516182899475), ('pagas', 0.8824478387832642), ('apta', 0.8639152646064758), ('chegam', 0.8555289506912231), ('maioria', 0.8426751494407654)]

# %% [markdown]
# ### 3.1) Word Embedding

# %% [markdown]
# Dessa forma, é fundamental gerar os embedding das colunas para que futuros modelos de aprendizado de máquina possam compreender e utilizar os dados de cada frase. Para tal, será utilizado uma média dos vetores de cada frase, desenvolvido a seguir, utilizando a abordagem CBOW (padrão):

# %%
import numpy as np

# Função para gerar o embedding médio de uma frase
def get_sentence_embedding(tokens, model):
    word_vectors = [model.wv[token] for token in tokens if token in model.wv]
    if len(word_vectors) > 0:
        return np.mean(word_vectors, axis=0)
    else:
        return np.zeros(model.vector_size)

# %% [markdown]
# ### 3.2) Resultados Obtidos

# %%
# Aplicando a função para gerar os embeddings e salvando nas novas colunas
chats_clients['Pergunta_embedding'] = chats_clients['Pergunta_tokens'].apply(lambda tokens: get_sentence_embedding(tokens, model_cbow))
chats_clients['Resposta_embedding'] = chats_clients['Resposta_tokens'].apply(lambda tokens: get_sentence_embedding(tokens, model_cbow))

# %%
chats_clients['Pergunta_embedding'].head()
# Out:
# 0    [-0.5339272, 0.09688279, -0.10819608, 0.036006...
# 1    [-0.90104055, 0.0896402, -0.17322218, 0.082651...
# 2    [-0.7726842, 0.11069913, -0.2013543, 0.0921977...
# 3    [-0.5158322, 0.045972086, -0.11637107, 0.04882...
# 4    [-0.47279325, 0.2090434, -0.16846703, 0.066044...
# Name: Pergunta_embedding, dtype: object

# %%
chats_clients['Resposta_embedding'].head()
# Out:
# 0    [-0.49377516, 0.0997112, -0.11359496, 0.042352...
# 1    [-0.39972177, 0.700471, -0.4117935, 0.19998248...
# 2    [-0.47853816, 0.21461147, -0.09644883, 0.11503...
# 3    [-0.50345904, 0.26137555, -0.16315313, 0.00219...
# 4    [-0.50345904, 0.26137555, -0.16315313, 0.00219...
# Name: Resposta_embedding, dtype: object

# %% [markdown]
# ## 2) Base de Dados Final

# %%
chats_clients
# Out:
#        No                              Intencao  \
# 0       1                        Como depositar
# 1       2                    Como fazer remessa
# 2       3                      Tempo de remessa
# 3       4  Pedido de envio via metodo "ByPhone"
# 4       5  Pedido de envio via metodo "ByPhone"
# ...   ...                                   ...
# 1510  501       Atualizacao de dados cadastrais
# 1511  502            Tempo de entrega do cartao
# 1512  503                          Cancelamento
# 1513  504                             Reembolso
# 1514  505                  Problemas de remessa
#
#                                                Pergunta  \
# 0     Boa dia.tudo bem?eu gostaria de saber sobre aq...
# 1                        Como enviar dinheiro do Japão?
# 2     Quanto tempo levará para o beneficiário recebe...
# 3     Boa tarde\nAcabei de fazer a transferência de ...
# 4     Poderia fazer a remessa de 22yenes para o BBB ...
# ...                                                 ...
# 1510  feather boa tarde como faço para fazer ampere ...
# 1511  Bom dia Consegui fazer depósito sem o cartão q...
# 1512  Boa noite,a beneficiária me avisou que a conta...
# 1513  boa noite Eu fiz um depósito errado, era pra d...
# 1514  Ola, recebi uma ligação da central de vocês em...
#
#                                                Resposta  \
# 0     Bom dia! Sim, o sr pode utilizar o cartão de d...
# 1     Para se inscrever no serviço de remessa, por f...
# 2     Via de regra, as remessas serão pagas via PIX ...
# 3     iremos processar a sua solicitacao.\nMuito obr...
# 4     iremos processar a sua solicitacao.\nMuito obr...
# ...                                                 ...
# 1510  antiophthalmic factor senhora pode trocar pelo...
# 1511  Boa noite group O sr solicitou dia 28. Será en...
# 1512  Sim, podemos cancelar o valor voltará No seu s...
# 1513  É possível solicitar o reembolso diretamente d...
# 1514  Enviamos a correção ao nosso correspondente do...
#
#                                         Pergunta_tokens  \
# 0     [boa, dia.tudo, bem, ?, eu, gostaria, de, sabe...
# 1                [como, enviar, dinheiro, do, japão, ?]
# 2     [quanto, tempo, levará, para, o, beneficiário,...
# 3     [boa, tarde, acabei, de, fazer, a, transferênc...
# 4     [poderia, fazer, a, remessa, de, 22yenes, para...
# ...                                                 ...
# 1510  [feather, boa, tarde, como, faço, para, fazer,...
# 1511  [bom, dia, consegui, fazer, depósito, sem, o, ...
# 1512  [boa, noite, ,, a, beneficiária, me, avisou, q...
# 1513  [boa, noite, eu, fiz, um, depósito, errado, ,,...
# 1514  [ola, ,, recebi, uma, ligação, da, central, de...
#
#                                         Resposta_tokens  \
# 0     [bom, dia, !, sim, ,, o, sr, pode, utilizar, o...
# 1     [para, se, inscrever, no, serviço, de, remessa...
# 2     [via, de, regra, ,, as, remessas, serão, pagas...
# 3     [iremos, processar, a, sua, solicitacao, ., mu...
# 4     [iremos, processar, a, sua, solicitacao, ., mu...
# ...                                                 ...
# 1510  [antiophthalmic, factor, senhora, pode, trocar...
# 1511  [boa, noite, group, o, sr, solicitou, dia, 28....
# 1512  [sim, ,, podemos, cancelar, o, valor, voltará,...
# 1513  [é, possível, solicitar, o, reembolso, diretam...
# 1514  [enviamos, a, correção, ao, nosso, corresponde...
#
#                                      Pergunta_embedding  \
# 0     [-0.5339272, 0.09688279, -0.10819608, 0.036006...
# 1     [-0.90104055, 0.0896402, -0.17322218, 0.082651...
# 2     [-0.7726842, 0.11069913, -0.2013543, 0.0921977...
# 3     [-0.5158322, 0.045972086, -0.11637107, 0.04882...
# 4     [-0.47279325, 0.2090434, -0.16846703, 0.066044...
# ...                                                 ...
# 1510  [-0.5804344, 0.06237927, -0.13470794, 0.057049...
# 1511  [-0.5630415, 0.08684154, -0.1317246, 0.0167596...
# 1512  [-0.5315998, 0.17506938, -0.13843985, 0.057225...
# 1513  [-0.68798053, 0.090044096, -0.1304638, 0.00468...
# 1514  [-0.5485785, 0.08894577, -0.10883406, 0.019364...
#
#                                      Resposta_embedding
# 0     [-0.49377516, 0.0997112, -0.11359496, 0.042352...
# 1     [-0.39972177, 0.700471, -0.4117935, 0.19998248...
# 2     [-0.47853816, 0.21461147, -0.09644883, 0.11503...
# 3     [-0.50345904, 0.26137555, -0.16315313, 0.00219...
# 4     [-0.50345904, 0.26137555, -0.16315313, 0.00219...
# ...                                                 ...
# 1510  [-0.8606049, 0.14268234, -0.04298023, -0.25235...
# 1511  [-0.53960323, 0.048282325, -0.07961207, -0.024...
# 1512  [-0.54635626, 0.17236519, -0.16412811, 0.09573...
# 1513  [-0.6921064, 0.15981163, -0.113951534, -0.0557...
# 1514  [-0.58178264, 0.25554153, -0.1434283, 0.041905...
#
# [1515 rows x 8 columns]

# %% [markdown]
# ### Classificador de intenção

# %% [markdown]
# O classificador de intenção é um sistema que identifica a intenção por trás de uma mensagem de texto, neste caso, seria as mensagens (entradas do chatbot) enviadas pelos clientes. A intenção refere-se ao que o usuário deseja realizar, como transferir dinheiro, taxa de câmbio, etc.
# Nesta seção é abordado o treinamento do modelo com suas respectivas métricas (Acurácia, Recall, F1-Score).
#
# Abaixo há uma classe de callback que guarda as métricas de F1-Score e recall. A F1-score é uma métrica que leva em consideração a precisão e o recall, sendo definida pela seguinte fórmula:
# $$ F1-Score = 2 \cdot \frac{Precision \cdot Recall}{Precision + Recall}$$
#
# F1 é conhecido como a média harmônica da precisão e do recall. A pontuação F1 se torna 1 apenas se a precisão e recall são 1. Se a precisão e o recall são altos, logo o valor de F1 também é alta.
#
# a métrica Recall (sensibilidade) ajuda a avaliar a capacidade do modelo de identificar corretamente todos os exemplos positivos de uma classe. Por exemplo, se temos um problema onde devemos classificar com uma classificação "sim" ou "não" referente a spam de e-mails, o recall nesse caso nos dirá quantos e-mails de spam o modelo conseguiu identificar corretamente, dentre todos os e-mails que realmente eram spam.
#
# A fórmula do recall é a seguinte:
#
# $$ Recall = \frac{TP}{TP + FN}$$
#
# Já a acurácia é a proporção total de exemplos que o modelo classificou corretamente, ou seja, o quanto o modelo conseguiu acertar. Fórmula:
#
#
# $$ Recall = \frac{Previsões corretas}{Previsões incorretas}$$

# %%
class MetricsCallback(Callback):
    def __init__(self, validation_data):
        super().__init__()
        self.validation_data = validation_data

    def on_epoch_end(self, epoch, logs=None):
        val_data, val_labels = self.validation_data
        val_pred = np.argmax(self.model.predict(val_data), axis=1)
        val_f1 = f1_score(val_labels, val_pred, average='macro')
        recall = recall_score(val_labels, val_pred, average='macro', zero_division=1)
        print(f'Epoch {epoch + 1}: f1-score: {val_f1:.4f} - recall: {recall:.4f}')
        logs['f1_score'] = val_f1
        logs['recall'] = recall

# %%
class IntentClassifier:
    def __init__(self, epochs=180, batch_size=16, test_size=0.4, validation_split=0.4, learning_rate=0.001):
        self.epochs = epochs
        self.batch_size = batch_size
        self.test_size = test_size
        self.validation_split = validation_split
        self.learning_rate = learning_rate
        self.model = None
        self.label_encoder = None

    def prepare_data(self, chats_clients):
        answer_embeddings = np.array(chats_clients['Pergunta_embedding'].tolist())
        response_embeddings = np.array(chats_clients['Resposta_embedding'].tolist())

        self.label_encoder = LabelEncoder()
        self.labels = self.label_encoder.fit_transform(chats_clients['Intencao'])

        combined_embeddings = np.stack((answer_embeddings, response_embeddings), axis=1)
        X_train, X_test, y_train, y_test = train_test_split(combined_embeddings, self.labels, test_size=self.test_size, random_state=42)

        return X_train, X_test, y_train, y_test

    def build_model(self, input_shape):
        self.model = Sequential()
        self.model.add(Bidirectional(LSTM(128, return_sequences=True), input_shape=input_shape))
        self.model.add(Dropout(0.5))
        self.model.add(LSTM(64))
        self.model.add(Dropout(0.5))
        self.model.add(Dense(64, activation='relu'))
        self.model.add(Dense(32, activation='relu'))
        self.model.add(Dense(len(np.unique(self.labels)), activation='softmax'))
        optimizer = Adam(learning_rate=self.learning_rate)
        self.model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
        self.model.summary()

    def train(self, X_train, X_test, y_train, y_test):
        model_checkpoint = ModelCheckpoint('best_model.keras', save_best_only=True, monitor='val_loss', mode='min')

        # Callback do F1-Score e recall
        metrics_callback = MetricsCallback(validation_data=(X_test, y_test))

        history = self.model.fit(X_train, y_train, epochs=self.epochs,
                       batch_size=self.batch_size,
                       validation_split=self.validation_split,
                       callbacks=[
                           model_checkpoint,
                           metrics_callback
                           ])

        loss, accuracy = self.model.evaluate(X_test, y_test)
        print(f"Test Loss: {loss}, Test Accuracy: {accuracy}")

        return history

    def predict(self, X_test):
        y_pred = self.model.predict(X_test)
        y_pred_classes = np.argmax(y_pred, axis=1)

        return y_pred_classes

    def generate_report(self, y_test, y_pred_classes):
      print(len(y_test))
      print(classification_report(y_test, y_pred_classes))

# %%
classifier = IntentClassifier()
X_train, X_test, y_train, y_test = classifier.prepare_data(chats_clients)
classifier.build_model(input_shape=(X_train.shape[1], X_train.shape[2]))
classifier.train(X_train, X_test, y_train, y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)        │ (None, 2, 256)              │         234,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 2, 256)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 64)                  │          82,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 18)                  │             594 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 323,506 (1.23 MB)
#  Trainable params: 323,506 (1.23 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Epoch 1: f1-score: 0.0772 - recall: 0.1084
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.2258 - loss: 2.7907 - val_accuracy: 0.3159 - val_loss: 2.4887 - f1_score: 0.0772 - recall: 0.1084
# Epoch 2/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 2: f1-score: 0.1107 - recall: 0.1623
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3463 - loss: 2.3857 - val_accuracy: 0.4505 - val_loss: 1.9801 - f1_score: 0.1107 - recall: 0.1623
# Epoch 3/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 3: f1-score: 0.1230 - recall: 0.1659
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4731 - loss: 1.9890 - val_accuracy: 0.4478 - val_loss: 1.8515 - f1_score: 0.1230 - recall: 0.1659
# Epoch 4/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 4: f1-score: 0.1135 - recall: 0.1671
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4592 - loss: 1.9131 - val_accuracy: 0.4643 - val_loss: 1.7742 - f1_score: 0.1135 - recall: 0.1671
# Epoch 5/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 5: f1-score: 0.1348 - recall: 0.1803
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4655 - loss: 1.8250 - val_accuracy: 0.4780 - val_loss: 1.6993 - f1_score: 0.1348 - recall: 0.1803
# Epoch 6/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 6: f1-score: 0.1455 - recall: 0.1777
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4474 - loss: 1.7881 - val_accuracy: 0.4643 - val_loss: 1.6922 - f1_score: 0.1455 - recall: 0.1777
# Epoch 7/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 7: f1-score: 0.1838 - recall: 0.2230
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4625 - loss: 1.7826 - val_accuracy: 0.5275 - val_loss: 1.5973 - f1_score: 0.1838 - recall: 0.2230
# Epoch 8/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 8: f1-score: 0.1967 - recall: 0.2424
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4836 - loss: 1.7421 - val_accuracy: 0.5330 - val_loss: 1.5751 - f1_score: 0.1967 - recall: 0.2424
# Epoch 9/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 9: f1-score: 0.2107 - recall: 0.2621
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5162 - loss: 1.6184 - val_accuracy: 0.5577 - val_loss: 1.5717 - f1_score: 0.2107 - recall: 0.2621
# Epoch 10/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 10: f1-score: 0.1972 - recall: 0.2491
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5466 - loss: 1.5048 - val_accuracy: 0.5522 - val_loss: 1.5244 - f1_score: 0.1972 - recall: 0.2491
# Epoch 11/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 11: f1-score: 0.2091 - recall: 0.2582
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5346 - loss: 1.5459 - val_accuracy: 0.5549 - val_loss: 1.4714 - f1_score: 0.2091 - recall: 0.2582
# Epoch 12/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 12: f1-score: 0.2208 - recall: 0.2622
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5393 - loss: 1.4975 - val_accuracy: 0.5604 - val_loss: 1.4160 - f1_score: 0.2208 - recall: 0.2622
# Epoch 13/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 13: f1-score: 0.2124 - recall: 0.2603
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5670 - loss: 1.3630 - val_accuracy: 0.5632 - val_loss: 1.3871 - f1_score: 0.2124 - recall: 0.2603
# Epoch 14/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 14: f1-score: 0.2312 - recall: 0.2770
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5736 - loss: 1.3739 - val_accuracy: 0.5824 - val_loss: 1.3472 - f1_score: 0.2312 - recall: 0.2770
# Epoch 15/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 15: f1-score: 0.2755 - recall: 0.3248
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5980 - loss: 1.3390 - val_accuracy: 0.6016 - val_loss: 1.3980 - f1_score: 0.2755 - recall: 0.3248
# Epoch 16/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 16: f1-score: 0.2669 - recall: 0.3103
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5839 - loss: 1.3356 - val_accuracy: 0.6016 - val_loss: 1.3080 - f1_score: 0.2669 - recall: 0.3103
# Epoch 17/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 17: f1-score: 0.2770 - recall: 0.3182
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5964 - loss: 1.2613 - val_accuracy: 0.6016 - val_loss: 1.2752 - f1_score: 0.2770 - recall: 0.3182
# Epoch 18/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 18: f1-score: 0.2727 - recall: 0.3114
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5488 - loss: 1.3409 - val_accuracy: 0.6236 - val_loss: 1.2390 - f1_score: 0.2727 - recall: 0.3114
# Epoch 19/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 19: f1-score: 0.2751 - recall: 0.3093
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5745 - loss: 1.2681 - val_accuracy: 0.6429 - val_loss: 1.2281 - f1_score: 0.2751 - recall: 0.3093
# Epoch 20/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 20: f1-score: 0.3169 - recall: 0.3447
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6111 - loss: 1.2464 - val_accuracy: 0.6401 - val_loss: 1.2131 - f1_score: 0.3169 - recall: 0.3447
# Epoch 21/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 21: f1-score: 0.3235 - recall: 0.3397
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6232 - loss: 1.2715 - val_accuracy: 0.6374 - val_loss: 1.2473 - f1_score: 0.3235 - recall: 0.3397
# Epoch 22/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 22: f1-score: 0.3107 - recall: 0.3408
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5837 - loss: 1.3195 - val_accuracy: 0.6676 - val_loss: 1.1761 - f1_score: 0.3107 - recall: 0.3408
# Epoch 23/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 23: f1-score: 0.3482 - recall: 0.3740
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5991 - loss: 1.2353 - val_accuracy: 0.6786 - val_loss: 1.1526 - f1_score: 0.3482 - recall: 0.3740
# Epoch 24/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 24: f1-score: 0.3214 - recall: 0.3582
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6852 - loss: 1.0700 - val_accuracy: 0.6429 - val_loss: 1.1937 - f1_score: 0.3214 - recall: 0.3582
# Epoch 25/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 25: f1-score: 0.3084 - recall: 0.3361
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6325 - loss: 1.1863 - val_accuracy: 0.6456 - val_loss: 1.1862 - f1_score: 0.3084 - recall: 0.3361
# Epoch 26/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 26: f1-score: 0.3397 - recall: 0.3682
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6116 - loss: 1.1791 - val_accuracy: 0.6731 - val_loss: 1.1274 - f1_score: 0.3397 - recall: 0.3682
# Epoch 27/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 27: f1-score: 0.3836 - recall: 0.4061
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6062 - loss: 1.1410 - val_accuracy: 0.6731 - val_loss: 1.1167 - f1_score: 0.3836 - recall: 0.4061
# Epoch 28/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 28: f1-score: 0.3678 - recall: 0.4026
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6394 - loss: 1.1870 - val_accuracy: 0.6758 - val_loss: 1.1102 - f1_score: 0.3678 - recall: 0.4026
# Epoch 29/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 29: f1-score: 0.3919 - recall: 0.4220
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6428 - loss: 1.1049 - val_accuracy: 0.6703 - val_loss: 1.0695 - f1_score: 0.3919 - recall: 0.4220
# Epoch 30/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 30: f1-score: 0.4265 - recall: 0.4304
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6532 - loss: 1.0345 - val_accuracy: 0.6786 - val_loss: 1.1106 - f1_score: 0.4265 - recall: 0.4304
# Epoch 31/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 31: f1-score: 0.4077 - recall: 0.4056
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6449 - loss: 1.0764 - val_accuracy: 0.7033 - val_loss: 1.0900 - f1_score: 0.4077 - recall: 0.4056
# Epoch 32/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 32: f1-score: 0.4009 - recall: 0.4180
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6713 - loss: 0.9755 - val_accuracy: 0.6511 - val_loss: 1.0988 - f1_score: 0.4009 - recall: 0.4180
# Epoch 33/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 33: f1-score: 0.3388 - recall: 0.4192
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6436 - loss: 1.1222 - val_accuracy: 0.6566 - val_loss: 1.1064 - f1_score: 0.3388 - recall: 0.4192
# Epoch 34/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 34: f1-score: 0.4450 - recall: 0.4597
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6794 - loss: 1.0804 - val_accuracy: 0.6978 - val_loss: 1.0257 - f1_score: 0.4450 - recall: 0.4597
# Epoch 35/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 35: f1-score: 0.4207 - recall: 0.4294
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6661 - loss: 1.0272 - val_accuracy: 0.6758 - val_loss: 1.0324 - f1_score: 0.4207 - recall: 0.4294
# Epoch 36/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 36: f1-score: 0.3410 - recall: 0.4200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6529 - loss: 1.0354 - val_accuracy: 0.6538 - val_loss: 1.1188 - f1_score: 0.3410 - recall: 0.4200
# Epoch 37/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 37: f1-score: 0.4016 - recall: 0.4870
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6491 - loss: 1.0137 - val_accuracy: 0.6676 - val_loss: 1.0770 - f1_score: 0.4016 - recall: 0.4870
# Epoch 38/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 38: f1-score: 0.4386 - recall: 0.4478
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6674 - loss: 0.9910 - val_accuracy: 0.7005 - val_loss: 1.0092 - f1_score: 0.4386 - recall: 0.4478
# Epoch 39/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 39: f1-score: 0.3939 - recall: 0.4717
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6747 - loss: 0.9941 - val_accuracy: 0.6566 - val_loss: 1.0431 - f1_score: 0.3939 - recall: 0.4717
# Epoch 40/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 40: f1-score: 0.4463 - recall: 0.4741
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6924 - loss: 0.9506 - val_accuracy: 0.7060 - val_loss: 0.9975 - f1_score: 0.4463 - recall: 0.4741
# Epoch 41/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 41: f1-score: 0.4115 - recall: 0.4209
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7188 - loss: 0.9007 - val_accuracy: 0.6593 - val_loss: 1.1470 - f1_score: 0.4115 - recall: 0.4209
# Epoch 42/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 42: f1-score: 0.4422 - recall: 0.4428
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6997 - loss: 0.9537 - val_accuracy: 0.6786 - val_loss: 1.0469 - f1_score: 0.4422 - recall: 0.4428
# Epoch 43/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 43: f1-score: 0.4449 - recall: 0.4487
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6925 - loss: 0.9264 - val_accuracy: 0.6593 - val_loss: 1.0824 - f1_score: 0.4449 - recall: 0.4487
# Epoch 44/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 44: f1-score: 0.4500 - recall: 0.5150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6840 - loss: 0.9509 - val_accuracy: 0.6951 - val_loss: 0.9999 - f1_score: 0.4500 - recall: 0.5150
# Epoch 45/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 45: f1-score: 0.4142 - recall: 0.4935
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6872 - loss: 0.9362 - val_accuracy: 0.6896 - val_loss: 1.0212 - f1_score: 0.4142 - recall: 0.4935
# Epoch 46/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 46: f1-score: 0.4172 - recall: 0.4475
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7224 - loss: 0.8289 - val_accuracy: 0.6621 - val_loss: 1.0676 - f1_score: 0.4172 - recall: 0.4475
# Epoch 47/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 47: f1-score: 0.4517 - recall: 0.4705
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7130 - loss: 0.8935 - val_accuracy: 0.6813 - val_loss: 0.9936 - f1_score: 0.4517 - recall: 0.4705
# Epoch 48/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 48: f1-score: 0.4358 - recall: 0.4449
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6893 - loss: 0.8808 - val_accuracy: 0.6868 - val_loss: 1.0316 - f1_score: 0.4358 - recall: 0.4449
# Epoch 49/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 49: f1-score: 0.4379 - recall: 0.5009
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7504 - loss: 0.7986 - val_accuracy: 0.6978 - val_loss: 0.9868 - f1_score: 0.4379 - recall: 0.5009
# Epoch 50/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 50: f1-score: 0.4111 - recall: 0.4791
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6871 - loss: 0.8973 - val_accuracy: 0.7143 - val_loss: 0.9722 - f1_score: 0.4111 - recall: 0.4791
# Epoch 51/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 51: f1-score: 0.4182 - recall: 0.4932
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7156 - loss: 0.8268 - val_accuracy: 0.7033 - val_loss: 1.0425 - f1_score: 0.4182 - recall: 0.4932
# Epoch 52/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 52: f1-score: 0.4661 - recall: 0.4796
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7166 - loss: 0.9377 - val_accuracy: 0.7060 - val_loss: 0.9940 - f1_score: 0.4661 - recall: 0.4796
# Epoch 53/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 53: f1-score: 0.4472 - recall: 0.5169
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6832 - loss: 0.9208 - val_accuracy: 0.7198 - val_loss: 0.9503 - f1_score: 0.4472 - recall: 0.5169
# Epoch 54/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 54: f1-score: 0.4545 - recall: 0.5212
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6935 - loss: 0.8421 - val_accuracy: 0.7225 - val_loss: 0.9547 - f1_score: 0.4545 - recall: 0.5212
# Epoch 55/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 55: f1-score: 0.4426 - recall: 0.5207
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7206 - loss: 0.7938 - val_accuracy: 0.7335 - val_loss: 0.9576 - f1_score: 0.4426 - recall: 0.5207
# Epoch 56/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 56: f1-score: 0.4320 - recall: 0.5023
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6874 - loss: 0.8352 - val_accuracy: 0.7225 - val_loss: 0.9855 - f1_score: 0.4320 - recall: 0.5023
# Epoch 57/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 57: f1-score: 0.4820 - recall: 0.4964
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7292 - loss: 0.8033 - val_accuracy: 0.7280 - val_loss: 0.9316 - f1_score: 0.4820 - recall: 0.4964
# Epoch 58/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 58: f1-score: 0.4316 - recall: 0.4955
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7138 - loss: 0.7808 - val_accuracy: 0.7225 - val_loss: 0.9481 - f1_score: 0.4316 - recall: 0.4955
# Epoch 59/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 59: f1-score: 0.4345 - recall: 0.5055
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7173 - loss: 0.7716 - val_accuracy: 0.7170 - val_loss: 1.0066 - f1_score: 0.4345 - recall: 0.5055
# Epoch 60/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 60: f1-score: 0.4855 - recall: 0.4897
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6906 - loss: 0.9270 - val_accuracy: 0.7143 - val_loss: 0.9414 - f1_score: 0.4855 - recall: 0.4897
# Epoch 61/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 61: f1-score: 0.4893 - recall: 0.4977
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7383 - loss: 0.7669 - val_accuracy: 0.7225 - val_loss: 0.9479 - f1_score: 0.4893 - recall: 0.4977
# Epoch 62/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 62: f1-score: 0.4833 - recall: 0.4825
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7419 - loss: 0.7760 - val_accuracy: 0.7033 - val_loss: 1.0047 - f1_score: 0.4833 - recall: 0.4825
# Epoch 63/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 63: f1-score: 0.4901 - recall: 0.4982
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7268 - loss: 0.7751 - val_accuracy: 0.7280 - val_loss: 0.9766 - f1_score: 0.4901 - recall: 0.4982
# Epoch 64/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 64: f1-score: 0.4893 - recall: 0.4963
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7634 - loss: 0.6816 - val_accuracy: 0.7170 - val_loss: 0.9987 - f1_score: 0.4893 - recall: 0.4963
# Epoch 65/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 65: f1-score: 0.4530 - recall: 0.5193
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7500 - loss: 0.7396 - val_accuracy: 0.7473 - val_loss: 0.9976 - f1_score: 0.4530 - recall: 0.5193
# Epoch 66/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 66: f1-score: 0.5028 - recall: 0.5020
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7978 - loss: 0.6241 - val_accuracy: 0.7253 - val_loss: 1.0034 - f1_score: 0.5028 - recall: 0.5020
# Epoch 67/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 67: f1-score: 0.4697 - recall: 0.5369
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7362 - loss: 0.7680 - val_accuracy: 0.7225 - val_loss: 1.0007 - f1_score: 0.4697 - recall: 0.5369
# Epoch 68/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 68: f1-score: 0.4976 - recall: 0.5577
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7455 - loss: 0.7401 - val_accuracy: 0.7335 - val_loss: 0.9260 - f1_score: 0.4976 - recall: 0.5577
# Epoch 69/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 69: f1-score: 0.4855 - recall: 0.4882
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7420 - loss: 0.7095 - val_accuracy: 0.7418 - val_loss: 0.9761 - f1_score: 0.4855 - recall: 0.4882
# Epoch 70/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 70: f1-score: 0.5209 - recall: 0.5158
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7450 - loss: 0.7586 - val_accuracy: 0.7363 - val_loss: 1.0042 - f1_score: 0.5209 - recall: 0.5158
# Epoch 71/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 71: f1-score: 0.4868 - recall: 0.5458
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7741 - loss: 0.6647 - val_accuracy: 0.7253 - val_loss: 0.9874 - f1_score: 0.4868 - recall: 0.5458
# Epoch 72/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 72: f1-score: 0.5061 - recall: 0.5101
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7736 - loss: 0.6611 - val_accuracy: 0.7555 - val_loss: 0.8933 - f1_score: 0.5061 - recall: 0.5101
# Epoch 73/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 73: f1-score: 0.5181 - recall: 0.5338
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7914 - loss: 0.7035 - val_accuracy: 0.7720 - val_loss: 0.9447 - f1_score: 0.5181 - recall: 0.5338
# Epoch 74/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 74: f1-score: 0.5422 - recall: 0.5581
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7719 - loss: 0.6306 - val_accuracy: 0.7637 - val_loss: 0.9096 - f1_score: 0.5422 - recall: 0.5581
# Epoch 75/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 75: f1-score: 0.4983 - recall: 0.5028
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8065 - loss: 0.6157 - val_accuracy: 0.7390 - val_loss: 1.0499 - f1_score: 0.4983 - recall: 0.5028
# Epoch 76/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 76: f1-score: 0.4892 - recall: 0.5589
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7755 - loss: 0.6322 - val_accuracy: 0.7637 - val_loss: 0.9273 - f1_score: 0.4892 - recall: 0.5589
# Epoch 77/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 77: f1-score: 0.4634 - recall: 0.5347
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7584 - loss: 0.6796 - val_accuracy: 0.7143 - val_loss: 0.9860 - f1_score: 0.4634 - recall: 0.5347
# Epoch 78/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 78: f1-score: 0.5272 - recall: 0.5972
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7423 - loss: 0.7839 - val_accuracy: 0.7637 - val_loss: 0.9122 - f1_score: 0.5272 - recall: 0.5972
# Epoch 79/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 79: f1-score: 0.5210 - recall: 0.5366
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7664 - loss: 0.6267 - val_accuracy: 0.7555 - val_loss: 0.9134 - f1_score: 0.5210 - recall: 0.5366
# Epoch 80/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 80: f1-score: 0.5333 - recall: 0.5590
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7753 - loss: 0.6604 - val_accuracy: 0.7527 - val_loss: 0.9169 - f1_score: 0.5333 - recall: 0.5590
# Epoch 81/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 81: f1-score: 0.5509 - recall: 0.5592
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8024 - loss: 0.6419 - val_accuracy: 0.7582 - val_loss: 0.8777 - f1_score: 0.5509 - recall: 0.5592
# Epoch 82/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 82: f1-score: 0.5196 - recall: 0.5876
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8021 - loss: 0.6260 - val_accuracy: 0.7692 - val_loss: 0.8966 - f1_score: 0.5196 - recall: 0.5876
# Epoch 83/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 83: f1-score: 0.5592 - recall: 0.5748
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7664 - loss: 0.6459 - val_accuracy: 0.7527 - val_loss: 0.8825 - f1_score: 0.5592 - recall: 0.5748
# Epoch 84/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 84: f1-score: 0.5655 - recall: 0.5689
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7584 - loss: 0.6716 - val_accuracy: 0.7527 - val_loss: 0.9989 - f1_score: 0.5655 - recall: 0.5689
# Epoch 85/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 85: f1-score: 0.5921 - recall: 0.5917
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7991 - loss: 0.5815 - val_accuracy: 0.7555 - val_loss: 0.9270 - f1_score: 0.5921 - recall: 0.5917
# Epoch 86/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 86: f1-score: 0.5310 - recall: 0.5943
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7921 - loss: 0.5962 - val_accuracy: 0.7692 - val_loss: 0.8854 - f1_score: 0.5310 - recall: 0.5943
# Epoch 87/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 87: f1-score: 0.5550 - recall: 0.5696
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8039 - loss: 0.5412 - val_accuracy: 0.7665 - val_loss: 0.9971 - f1_score: 0.5550 - recall: 0.5696
# Epoch 88/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 88: f1-score: 0.5750 - recall: 0.5838
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7701 - loss: 0.5771 - val_accuracy: 0.7747 - val_loss: 0.9491 - f1_score: 0.5750 - recall: 0.5838
# Epoch 89/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 89: f1-score: 0.5986 - recall: 0.6207
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8026 - loss: 0.5526 - val_accuracy: 0.7747 - val_loss: 0.8963 - f1_score: 0.5986 - recall: 0.6207
# Epoch 90/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 90: f1-score: 0.5481 - recall: 0.5562
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8058 - loss: 0.5344 - val_accuracy: 0.7912 - val_loss: 0.8542 - f1_score: 0.5481 - recall: 0.5562
# Epoch 91/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 91: f1-score: 0.5846 - recall: 0.6323
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7538 - loss: 0.6767 - val_accuracy: 0.7885 - val_loss: 0.8714 - f1_score: 0.5846 - recall: 0.6323
# Epoch 92/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 92: f1-score: 0.5659 - recall: 0.5729
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8078 - loss: 0.5367 - val_accuracy: 0.7967 - val_loss: 0.9092 - f1_score: 0.5659 - recall: 0.5729
# Epoch 93/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 93: f1-score: 0.5590 - recall: 0.5623
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7737 - loss: 0.7168 - val_accuracy: 0.7555 - val_loss: 1.0087 - f1_score: 0.5590 - recall: 0.5623
# Epoch 94/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 94: f1-score: 0.5528 - recall: 0.5718
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7904 - loss: 0.6310 - val_accuracy: 0.7967 - val_loss: 0.8638 - f1_score: 0.5528 - recall: 0.5718
# Epoch 95/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 95: f1-score: 0.6002 - recall: 0.6171
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8174 - loss: 0.5520 - val_accuracy: 0.7830 - val_loss: 0.8586 - f1_score: 0.6002 - recall: 0.6171
# Epoch 96/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 96: f1-score: 0.6036 - recall: 0.6152
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8388 - loss: 0.4886 - val_accuracy: 0.7830 - val_loss: 0.8598 - f1_score: 0.6036 - recall: 0.6152
# Epoch 97/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 97: f1-score: 0.6118 - recall: 0.6096
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8146 - loss: 0.4924 - val_accuracy: 0.7747 - val_loss: 0.9546 - f1_score: 0.6118 - recall: 0.6096
# Epoch 98/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 98: f1-score: 0.5426 - recall: 0.6137
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7955 - loss: 0.5780 - val_accuracy: 0.7527 - val_loss: 0.9218 - f1_score: 0.5426 - recall: 0.6137
# Epoch 99/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 99: f1-score: 0.6414 - recall: 0.6506
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7881 - loss: 0.5914 - val_accuracy: 0.7747 - val_loss: 0.9542 - f1_score: 0.6414 - recall: 0.6506
# Epoch 100/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 100: f1-score: 0.5970 - recall: 0.6654
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7938 - loss: 0.5658 - val_accuracy: 0.7830 - val_loss: 0.9363 - f1_score: 0.5970 - recall: 0.6654
# Epoch 101/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 101: f1-score: 0.6172 - recall: 0.6506
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8068 - loss: 0.5663 - val_accuracy: 0.7692 - val_loss: 0.9332 - f1_score: 0.6172 - recall: 0.6506
# Epoch 102/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 102: f1-score: 0.4886 - recall: 0.5187
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7248 - loss: 0.9183 - val_accuracy: 0.7445 - val_loss: 1.0249 - f1_score: 0.4886 - recall: 0.5187
# Epoch 103/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 103: f1-score: 0.5492 - recall: 0.5619
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8125 - loss: 0.5899 - val_accuracy: 0.7692 - val_loss: 0.9203 - f1_score: 0.5492 - recall: 0.5619
# Epoch 104/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 104: f1-score: 0.5561 - recall: 0.5745
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8175 - loss: 0.4784 - val_accuracy: 0.7885 - val_loss: 0.9505 - f1_score: 0.5561 - recall: 0.5745
# Epoch 105/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 105: f1-score: 0.5999 - recall: 0.6403
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8253 - loss: 0.5185 - val_accuracy: 0.7747 - val_loss: 0.8917 - f1_score: 0.5999 - recall: 0.6403
# Epoch 106/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 106: f1-score: 0.6031 - recall: 0.6305
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8007 - loss: 0.5231 - val_accuracy: 0.7995 - val_loss: 0.8418 - f1_score: 0.6031 - recall: 0.6305
# Epoch 107/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 107: f1-score: 0.5906 - recall: 0.6186
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8352 - loss: 0.4778 - val_accuracy: 0.7692 - val_loss: 0.8875 - f1_score: 0.5906 - recall: 0.6186
# Epoch 108/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 108: f1-score: 0.5856 - recall: 0.6518
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8333 - loss: 0.4867 - val_accuracy: 0.7940 - val_loss: 0.8863 - f1_score: 0.5856 - recall: 0.6518
# Epoch 109/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 109: f1-score: 0.5949 - recall: 0.6170
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8440 - loss: 0.4856 - val_accuracy: 0.7637 - val_loss: 0.9331 - f1_score: 0.5949 - recall: 0.6170
# Epoch 110/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 110: f1-score: 0.6296 - recall: 0.6494
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8239 - loss: 0.5016 - val_accuracy: 0.7720 - val_loss: 0.8975 - f1_score: 0.6296 - recall: 0.6494
# Epoch 111/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 111: f1-score: 0.6127 - recall: 0.6266
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8538 - loss: 0.4148 - val_accuracy: 0.7775 - val_loss: 0.9546 - f1_score: 0.6127 - recall: 0.6266
# Epoch 112/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 112: f1-score: 0.6322 - recall: 0.6543
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8478 - loss: 0.4367 - val_accuracy: 0.7940 - val_loss: 0.9377 - f1_score: 0.6322 - recall: 0.6543
# Epoch 113/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 113: f1-score: 0.6607 - recall: 0.6785
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8664 - loss: 0.4206 - val_accuracy: 0.7857 - val_loss: 0.9327 - f1_score: 0.6607 - recall: 0.6785
# Epoch 114/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 114: f1-score: 0.6181 - recall: 0.6509
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8391 - loss: 0.4620 - val_accuracy: 0.7940 - val_loss: 0.9366 - f1_score: 0.6181 - recall: 0.6509
# Epoch 115/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 115: f1-score: 0.6111 - recall: 0.6316
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8640 - loss: 0.4288 - val_accuracy: 0.7940 - val_loss: 0.9112 - f1_score: 0.6111 - recall: 0.6316
# Epoch 116/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 116: f1-score: 0.6474 - recall: 0.6737
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8277 - loss: 0.5019 - val_accuracy: 0.7857 - val_loss: 0.9051 - f1_score: 0.6474 - recall: 0.6737
# Epoch 117/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 117: f1-score: 0.6334 - recall: 0.6729
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8184 - loss: 0.4422 - val_accuracy: 0.7885 - val_loss: 0.9047 - f1_score: 0.6334 - recall: 0.6729
# Epoch 118/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 118: f1-score: 0.6423 - recall: 0.6717
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8637 - loss: 0.3305 - val_accuracy: 0.7967 - val_loss: 0.9307 - f1_score: 0.6423 - recall: 0.6717
# Epoch 119/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 119: f1-score: 0.6340 - recall: 0.6736
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8594 - loss: 0.3884 - val_accuracy: 0.7830 - val_loss: 0.9163 - f1_score: 0.6340 - recall: 0.6736
# Epoch 120/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 120: f1-score: 0.6083 - recall: 0.6482
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8533 - loss: 0.4481 - val_accuracy: 0.7802 - val_loss: 0.9616 - f1_score: 0.6083 - recall: 0.6482
# Epoch 121/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 121: f1-score: 0.6178 - recall: 0.6524
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8663 - loss: 0.3723 - val_accuracy: 0.7995 - val_loss: 0.8904 - f1_score: 0.6178 - recall: 0.6524
# Epoch 122/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 122: f1-score: 0.6351 - recall: 0.6786
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8194 - loss: 0.5025 - val_accuracy: 0.7802 - val_loss: 0.9120 - f1_score: 0.6351 - recall: 0.6786
# Epoch 123/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 123: f1-score: 0.6467 - recall: 0.6707
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8120 - loss: 0.5851 - val_accuracy: 0.7912 - val_loss: 0.9030 - f1_score: 0.6467 - recall: 0.6707
# Epoch 124/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 124: f1-score: 0.6675 - recall: 0.6872
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8491 - loss: 0.4309 - val_accuracy: 0.8132 - val_loss: 0.8830 - f1_score: 0.6675 - recall: 0.6872
# Epoch 125/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 125: f1-score: 0.6624 - recall: 0.6757
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8761 - loss: 0.3573 - val_accuracy: 0.8104 - val_loss: 0.8456 - f1_score: 0.6624 - recall: 0.6757
# Epoch 126/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 126: f1-score: 0.6440 - recall: 0.6551
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8370 - loss: 0.5051 - val_accuracy: 0.7940 - val_loss: 0.8821 - f1_score: 0.6440 - recall: 0.6551
# Epoch 127/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 127: f1-score: 0.6609 - recall: 0.6822
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8620 - loss: 0.4049 - val_accuracy: 0.8132 - val_loss: 0.8724 - f1_score: 0.6609 - recall: 0.6822
# Epoch 128/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 128: f1-score: 0.6193 - recall: 0.6951
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8937 - loss: 0.3520 - val_accuracy: 0.7912 - val_loss: 0.8491 - f1_score: 0.6193 - recall: 0.6951
# Epoch 129/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 129: f1-score: 0.6528 - recall: 0.6799
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8577 - loss: 0.3845 - val_accuracy: 0.8077 - val_loss: 0.8766 - f1_score: 0.6528 - recall: 0.6799
# Epoch 130/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 130: f1-score: 0.6471 - recall: 0.6695
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8659 - loss: 0.3821 - val_accuracy: 0.8022 - val_loss: 0.9054 - f1_score: 0.6471 - recall: 0.6695
# Epoch 131/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 131: f1-score: 0.5985 - recall: 0.6805
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8888 - loss: 0.4004 - val_accuracy: 0.7885 - val_loss: 0.8839 - f1_score: 0.5985 - recall: 0.6805
# Epoch 132/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 132: f1-score: 0.6518 - recall: 0.6627
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8617 - loss: 0.3777 - val_accuracy: 0.8104 - val_loss: 0.9029 - f1_score: 0.6518 - recall: 0.6627
# Epoch 133/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 133: f1-score: 0.6591 - recall: 0.6799
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8576 - loss: 0.3634 - val_accuracy: 0.7967 - val_loss: 0.9277 - f1_score: 0.6591 - recall: 0.6799
# Epoch 134/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 134: f1-score: 0.6760 - recall: 0.7019
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8918 - loss: 0.3628 - val_accuracy: 0.8159 - val_loss: 0.9299 - f1_score: 0.6760 - recall: 0.7019
# Epoch 135/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 135: f1-score: 0.6459 - recall: 0.6770
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8540 - loss: 0.3464 - val_accuracy: 0.8104 - val_loss: 0.9044 - f1_score: 0.6459 - recall: 0.6770
# Epoch 136/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 136: f1-score: 0.6330 - recall: 0.6483
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9106 - loss: 0.3178 - val_accuracy: 0.7967 - val_loss: 1.0602 - f1_score: 0.6330 - recall: 0.6483
# Epoch 137/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 137: f1-score: 0.5846 - recall: 0.6665
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7608 - loss: 0.9528 - val_accuracy: 0.7720 - val_loss: 1.0714 - f1_score: 0.5846 - recall: 0.6665
# Epoch 138/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 138: f1-score: 0.6175 - recall: 0.6699
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7991 - loss: 0.6284 - val_accuracy: 0.7912 - val_loss: 0.9111 - f1_score: 0.6175 - recall: 0.6699
# Epoch 139/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 139: f1-score: 0.6391 - recall: 0.6789
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8733 - loss: 0.3442 - val_accuracy: 0.8077 - val_loss: 0.8827 - f1_score: 0.6391 - recall: 0.6789
# Epoch 140/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 140: f1-score: 0.6399 - recall: 0.6818
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8913 - loss: 0.3410 - val_accuracy: 0.8077 - val_loss: 0.8897 - f1_score: 0.6399 - recall: 0.6818
# Epoch 141/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 141: f1-score: 0.6343 - recall: 0.6748
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8551 - loss: 0.3794 - val_accuracy: 0.8077 - val_loss: 0.9029 - f1_score: 0.6343 - recall: 0.6748
# Epoch 142/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 142: f1-score: 0.6439 - recall: 0.6746
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9053 - loss: 0.3290 - val_accuracy: 0.8077 - val_loss: 0.9203 - f1_score: 0.6439 - recall: 0.6746
# Epoch 143/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 143: f1-score: 0.6644 - recall: 0.6732
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8700 - loss: 0.3508 - val_accuracy: 0.8022 - val_loss: 0.9972 - f1_score: 0.6644 - recall: 0.6732
# Epoch 144/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 144: f1-score: 0.6452 - recall: 0.6782
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8392 - loss: 0.4464 - val_accuracy: 0.8104 - val_loss: 0.9858 - f1_score: 0.6452 - recall: 0.6782
# Epoch 145/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 145: f1-score: 0.6669 - recall: 0.6900
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8716 - loss: 0.3465 - val_accuracy: 0.8022 - val_loss: 0.9235 - f1_score: 0.6669 - recall: 0.6900
# Epoch 146/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 146: f1-score: 0.6584 - recall: 0.6953
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8699 - loss: 0.3250 - val_accuracy: 0.8297 - val_loss: 0.9317 - f1_score: 0.6584 - recall: 0.6953
# Epoch 147/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 147: f1-score: 0.6624 - recall: 0.6849
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9152 - loss: 0.2821 - val_accuracy: 0.8077 - val_loss: 0.9638 - f1_score: 0.6624 - recall: 0.6849
# Epoch 148/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 148: f1-score: 0.6470 - recall: 0.6702
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8619 - loss: 0.3755 - val_accuracy: 0.8132 - val_loss: 0.9763 - f1_score: 0.6470 - recall: 0.6702
# Epoch 149/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 149: f1-score: 0.6643 - recall: 0.6863
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8798 - loss: 0.3519 - val_accuracy: 0.8269 - val_loss: 0.9604 - f1_score: 0.6643 - recall: 0.6863
# Epoch 150/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 150: f1-score: 0.6435 - recall: 0.6767
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9029 - loss: 0.3101 - val_accuracy: 0.8214 - val_loss: 0.9498 - f1_score: 0.6435 - recall: 0.6767
# Epoch 151/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 151: f1-score: 0.6629 - recall: 0.6772
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8956 - loss: 0.3042 - val_accuracy: 0.8159 - val_loss: 0.9803 - f1_score: 0.6629 - recall: 0.6772
# Epoch 152/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 152: f1-score: 0.6440 - recall: 0.6731
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8475 - loss: 0.4119 - val_accuracy: 0.8269 - val_loss: 0.9534 - f1_score: 0.6440 - recall: 0.6731
# Epoch 153/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 153: f1-score: 0.6731 - recall: 0.6986
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8937 - loss: 0.3176 - val_accuracy: 0.8269 - val_loss: 0.9837 - f1_score: 0.6731 - recall: 0.6986
# Epoch 154/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 154: f1-score: 0.6540 - recall: 0.6860
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8855 - loss: 0.3142 - val_accuracy: 0.8159 - val_loss: 1.0178 - f1_score: 0.6540 - recall: 0.6860
# Epoch 155/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 155: f1-score: 0.6748 - recall: 0.6928
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8915 - loss: 0.3015 - val_accuracy: 0.8352 - val_loss: 0.9837 - f1_score: 0.6748 - recall: 0.6928
# Epoch 156/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 156: f1-score: 0.6240 - recall: 0.7069
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8758 - loss: 0.3452 - val_accuracy: 0.8269 - val_loss: 0.9988 - f1_score: 0.6240 - recall: 0.7069
# Epoch 157/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 157: f1-score: 0.6711 - recall: 0.6912
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8992 - loss: 0.2655 - val_accuracy: 0.8324 - val_loss: 0.9579 - f1_score: 0.6711 - recall: 0.6912
# Epoch 158/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 158: f1-score: 0.6628 - recall: 0.6908
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8996 - loss: 0.3032 - val_accuracy: 0.8077 - val_loss: 1.0219 - f1_score: 0.6628 - recall: 0.6908
# Epoch 159/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 159: f1-score: 0.6549 - recall: 0.6847
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9214 - loss: 0.2604 - val_accuracy: 0.8214 - val_loss: 0.9776 - f1_score: 0.6549 - recall: 0.6847
# Epoch 160/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 160: f1-score: 0.6706 - recall: 0.6872
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9271 - loss: 0.2449 - val_accuracy: 0.8187 - val_loss: 0.9543 - f1_score: 0.6706 - recall: 0.6872
# Epoch 161/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 161: f1-score: 0.6869 - recall: 0.7043
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8766 - loss: 0.3338 - val_accuracy: 0.8022 - val_loss: 0.9808 - f1_score: 0.6869 - recall: 0.7043
# Epoch 162/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 162: f1-score: 0.6750 - recall: 0.7003
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8920 - loss: 0.3187 - val_accuracy: 0.8077 - val_loss: 0.9639 - f1_score: 0.6750 - recall: 0.7003
# Epoch 163/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 163: f1-score: 0.6800 - recall: 0.7053
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9096 - loss: 0.2785 - val_accuracy: 0.8077 - val_loss: 0.9637 - f1_score: 0.6800 - recall: 0.7053
# Epoch 164/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 164: f1-score: 0.6675 - recall: 0.6955
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9175 - loss: 0.2883 - val_accuracy: 0.8352 - val_loss: 0.9642 - f1_score: 0.6675 - recall: 0.6955
# Epoch 165/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 165: f1-score: 0.6580 - recall: 0.6941
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8924 - loss: 0.2940 - val_accuracy: 0.8049 - val_loss: 1.0716 - f1_score: 0.6580 - recall: 0.6941
# Epoch 166/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 166: f1-score: 0.6622 - recall: 0.6728
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8952 - loss: 0.3065 - val_accuracy: 0.8132 - val_loss: 1.0032 - f1_score: 0.6622 - recall: 0.6728
# Epoch 167/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 167: f1-score: 0.6835 - recall: 0.7063
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9030 - loss: 0.2502 - val_accuracy: 0.8187 - val_loss: 1.0037 - f1_score: 0.6835 - recall: 0.7063
# Epoch 168/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 168: f1-score: 0.6704 - recall: 0.7042
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9154 - loss: 0.2067 - val_accuracy: 0.8407 - val_loss: 0.9842 - f1_score: 0.6704 - recall: 0.7042
# Epoch 169/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 169: f1-score: 0.6723 - recall: 0.7010
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9209 - loss: 0.2175 - val_accuracy: 0.8214 - val_loss: 1.0263 - f1_score: 0.6723 - recall: 0.7010
# Epoch 170/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 170: f1-score: 0.6761 - recall: 0.6971
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9314 - loss: 0.2280 - val_accuracy: 0.8269 - val_loss: 0.9643 - f1_score: 0.6761 - recall: 0.6971
# Epoch 171/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 171: f1-score: 0.6615 - recall: 0.6843
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8911 - loss: 0.2974 - val_accuracy: 0.8159 - val_loss: 1.0531 - f1_score: 0.6615 - recall: 0.6843
# Epoch 172/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 172: f1-score: 0.6822 - recall: 0.7080
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8993 - loss: 0.2539 - val_accuracy: 0.8269 - val_loss: 0.9388 - f1_score: 0.6822 - recall: 0.7080
# Epoch 173/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 173: f1-score: 0.6243 - recall: 0.7054
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9119 - loss: 0.2401 - val_accuracy: 0.8077 - val_loss: 1.0385 - f1_score: 0.6243 - recall: 0.7054
# Epoch 174/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 174: f1-score: 0.7047 - recall: 0.7166
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9110 - loss: 0.2554 - val_accuracy: 0.8077 - val_loss: 1.1497 - f1_score: 0.7047 - recall: 0.7166
# Epoch 175/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 175: f1-score: 0.7080 - recall: 0.7308
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8943 - loss: 0.2629 - val_accuracy: 0.8297 - val_loss: 1.0354 - f1_score: 0.7080 - recall: 0.7308
# Epoch 176/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 176: f1-score: 0.6573 - recall: 0.6575
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8368 - loss: 0.7039 - val_accuracy: 0.8077 - val_loss: 0.9628 - f1_score: 0.6573 - recall: 0.6575
# Epoch 177/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 177: f1-score: 0.6535 - recall: 0.6850
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8750 - loss: 0.3756 - val_accuracy: 0.8104 - val_loss: 0.9542 - f1_score: 0.6535 - recall: 0.6850
# Epoch 178/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 178: f1-score: 0.7052 - recall: 0.7076
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9032 - loss: 0.2870 - val_accuracy: 0.8132 - val_loss: 0.9601 - f1_score: 0.7052 - recall: 0.7076
# Epoch 179/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 179: f1-score: 0.6879 - recall: 0.7019
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9108 - loss: 0.2559 - val_accuracy: 0.8242 - val_loss: 0.8862 - f1_score: 0.6879 - recall: 0.7019
# Epoch 180/180
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 180: f1-score: 0.6668 - recall: 0.6898
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9125 - loss: 0.2330 - val_accuracy: 0.8379 - val_loss: 0.9463 - f1_score: 0.6668 - recall: 0.6898
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7929 - loss: 1.2159
# Test Loss: 1.1904935836791992, Test Accuracy: 0.7887789011001587

# %% [markdown]
# ### Matriz de Confusão

# %% [markdown]
# A matriz de confusão avalia o desempenho do modelo. Os eixos Y representa as classes verdadeiras (true label) e o eixo x representa as classes previstas (predicted label). Além de indicar a frequência, as cores na matriz representam a intensidade dos valores nas células, ajudando a visualizar a frequência das classificações corretas e incorretas. Quanto mais escuro, mais frequente.
#
# Cada célula na matriz indica o número de vezes que uma classe verdadeira foi prevista como classe específica. Já as células da diagonal principal indicam as instâncias onde o modelo previu corretamente.
#
# #### Interpretação
# * A célula (7, 7) tem 137 instâncias, indicando que 137 exemplos da classe 7 foram corretamente classificados como classe 7. Parece ser a classe mais corretamente classificada, com 142 instâncias corretas e poucas confusões com outras classes.
#
# * A célula (11, 11) tem 68 instâncias, indicando que 68 exemplos da classe 11 foram corretamente classificados como classe 11.
#
# * A célula (12, 3) mostra que 3 exemplos da classe 12 foram incorretamente classificados como classe 3.
#
# * A célula (10, 12) mostra que 2 exemplos da classe 10 foram incorretamente classificados como classe 12.
#
# É observado que a classe de índice 12, 16 e 10 mostra uma confusão e que o modelo trabalha bem com as classes 7 e 11. Conclui-se então que as células ao longo da diagonal principal indicam as instâncias onde o modelo previu corretamente a classe e por este motivo se destaca na matriz.

# %%
y_pred_classes = classifier.predict(X_test)

# Calcula a matriz de confusão
labels = np.unique(y_test)
cm = confusion_matrix(y_test, y_pred_classes, labels=labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(cmap=plt.cm.Blues)
plt.show()

classifier.generate_report(y_test, y_pred_classes)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 606
#               precision    recall  f1-score   support
#
#            0       0.38      0.32      0.34        19
#            1       0.57      0.57      0.57         7
#            2       0.64      0.78      0.70        27
#            3       0.56      0.50      0.53        10
#            4       0.48      0.76      0.59        21
#            5       0.53      0.56      0.55        16
#            6       0.92      0.93      0.92        83
#            7       0.92      0.94      0.93       154
#            8       0.40      1.00      0.57         2
#            9       0.84      0.99      0.91        70
#           10       0.80      0.83      0.82        24
#           11       0.60      0.55      0.57        11
#           12       0.76      0.58      0.66        43
#           14       0.59      0.40      0.48        25
#           15       0.81      0.68      0.74        19
#           16       0.84      0.76      0.79        41
#           17       0.77      0.59      0.67        34
#
#     accuracy                           0.79       606
#    macro avg       0.67      0.69      0.67       606
# weighted avg       0.79      0.79      0.78       606

# %% [markdown]
# ## Testes

# %% [markdown]
# Nesta seção, é abordado os testes unitários que simulam o modelo. O objetivo é verificar se a função de vetorização e se o treinamento do classificador funcionam corretamente.
#
# **fit**: Simula o comportamento do método fit do Keras, que é responsável por treinar a rede neural. Um histórico genérico e simulado é criado com valores de loss (perda), accuracy (acurácia), val_loss (perda na validação) e val_accuracy (acurácia na validação).
#
# **evaluate**: Simula a avaliação do modelo, retornando uma perda de 0.3 e uma acurácia de 0.9.
#
# **predict**: Simula a previsão do modelo, retornando probabilidades associadas às classes.
#
# * Verificações:
#   * Se o histórico de treino não é None.
#   * Se o histórico contém registros de perda (loss).
#   * Garante que os valores de perda não sejam NaN.
#   * Comparação dos valores simulados de loss e accuracy retornados pela função evaluate.
#
# * Teste da função de previsão (test_predict_function)
#   * Objetivo: garantir que a função de previsão funcione corretamente após o treinamento.
#   * Execução: a função train é chamada para treinar o modelo, seguida pela execução da função predict.
#   * Verificações:
#     Verifica se o número de previsões (y_pred_classes) corresponde ao número de amostras de teste (y_test).
#
# * Teste com dados inválidos (test_invalid_data)
#   * Objetivo: testar o funcionamento da função de treinamento quando tiver dados inválidos.
#   * Execução: chamar a função train com arrays vazios para os dados de entrada e saída.
#   * Verificação:
# verificar se o ValueError é levantado quando os dados de treino são inválidos.

# %% [markdown]
# ### Teste da Função de vetorização

# %%
def get_vector(model, word):
    try:
        return model.wv[word]
    except KeyError:
        return None  # Retorna None se a palavra não estiver no vocabulário

# %%
class TestWord2Vec(unittest.TestCase):

    @classmethod
    def setUpClass(cls):
        # Carregar o modelo Word2Vec apenas uma vez para todos os testes
        cls.model = model  # Supondo que o modelo já foi carregado em `model`

    def test_get_word_vector_present(self):
        word = 'dia'
        vector = get_vector(self.model, word)
        self.assertIsNotNone(vector, "O vetor para uma palavra presente deve ser diferente de None.")
        self.assertEqual(len(vector), 100, "O vetor deve ter 100 dimensões.")

    def test_get_no_word_vector(self):
        word = 'palavraInexistente'
        vector = get_vector(self.model, word)
        self.assertIsNone(vector, "O vetor para uma palavra ausente deve ser None.")

    def test_obter_vetor_input_invalido(self):
        word = 12345  # Um número em vez de uma string
        vector = get_vector(self.model, word)
        self.assertIsNone(vector, "O vetor para uma entrada inválida deve ser None.")

    def test_vetor_tamanho(self):
        word = 'bom'
        vector = get_vector(self.model, word)
        self.assertEqual(len(vector), 100, "O vetor deve ter 100 dimensões.")

# %% [markdown]
# ### Teste do classificador de intenções

# %%
class TestIntentClassifier(unittest.TestCase):

    @classmethod
    def setUpClass(cls):
        # Instanciando a classe `IntentClassifier`
        cls.classifier = IntentClassifier(epochs=20, batch_size=2)

        # Gerando dados fictícios para teste
        np.random.seed(42)
        cls.X_train = np.random.rand(10, 2, 300)  # samples, embeddings por sample, dimensão
        cls.y_train = np.random.randint(0, 3, size=(10,))  # 3 classes
        cls.X_test = np.random.rand(4, 2, 300)  # 4 samples de teste
        cls.y_test = np.random.randint(0, 3, size=(4,))

        # Simulação dos dados de `self.labels`
        cls.classifier.labels = cls.y_train  # Definição dos labels
        cls.classifier.build_model(input_shape=(2, 300))

    @patch('tensorflow.keras.Model.fit')
    @patch('tensorflow.keras.Model.evaluate')
    @patch('tensorflow.keras.Model.predict')
    def test_train_function(self, mock_predict, mock_evaluate, mock_fit):
        # Mockagem do método `fit` de treino
        mock_history = MagicMock()
        mock_history.history = {
            'loss': [0.5, 0.4, 0.3],
            'accuracy': [0.7, 0.8, 0.9],
            'val_loss': [0.6, 0.5, 0.4],
            'val_accuracy': [0.6, 0.7, 0.8]
        }
        mock_fit.return_value = mock_history

        # Mockagem do evaluate
        mock_evaluate.return_value = (0.3, 0.9)  # loss, accuracy

        # Mockagem do método`predict`
        mock_predict.return_value = np.array([[0.2, 0.8], [0.3, 0.7], [0.4, 0.6], [0.1, 0.9]])

        history = self.classifier.train(self.X_train, self.X_test, self.y_train, self.y_test)

        # Verificações
        self.assertIsNotNone(history, "O histórico de treino não pode ser None")
        self.assertTrue(len(history.history['loss']) > 0, "Deve ter logs de perda no histórico")
        self.assertFalse(any(np.isnan(history.history['loss'])), "O valor de perda não deve ser NaN")
        self.assertEqual(mock_evaluate.return_value[0], 0.3, "O loss deve ser 0.3")
        self.assertEqual(mock_evaluate.return_value[1], 0.9, "A acurácia deve ser 0.9")

    def test_predict_function(self):
        # Teste da previsão após o treinamento
        self.classifier.train(self.X_train, self.X_test, self.y_train, self.y_test)
        y_pred_classes = self.classifier.predict(self.X_test)
        self.assertEqual(len(y_pred_classes), len(self.y_test), "O número de previsões deve ser igual ao número de testes")

    def test_invalid_data(self):
        # Teste com dados inválidos
        with self.assertRaises(ValueError):
            self.classifier.train(np.array([]), np.array([]), np.array([]), np.array([]))

# %%
if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ bidirectional_1 (Bidirectional)      │ (None, 2, 256)              │         439,296 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 2, 256)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 64)                  │          82,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 2)                   │              66 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 527,778 (2.01 MB)
#  Trainable params: 527,778 (2.01 MB)
#  Non-trainable params: 0 (0.00 B)
# .
# Epoch 1/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# Epoch 1: f1-score: 0.2222 - recall: 0.3333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 343ms/step - accuracy: 0.3125 - loss: nan - val_accuracy: 0.5000 - val_loss: nan - f1_score: 0.2222 - recall: 0.3333
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Epoch 2: f1-score: 0.2222 - recall: 0.3333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7083 - loss: nan - val_accuracy: 0.5000 - val_loss: nan - f1_score: 0.2222 - recall: 0.3333
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Epoch 3: f1-score: 0.2222 - recall: 0.3333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5833 - loss: nan - val_accuracy: 0.5000 - val_loss: nan - f1_score: 0.2222 - recall: 0.3333
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Epoch 4: f1-score: 0.2222 - recall: 0.3333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6458 - loss: nan - val_accuracy: 0.5000 - val_loss: nan - f1_score: 0.2222 - recall: 0.3333
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Epoch 5: f1-score: 0.2222 - recall: 0.3333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7708 - loss: nan - val_accuracy: 0.5000 - val_loss: nan - f1_score: 0.2222 - recall: 0.3333
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Epoch 6: f1-score: 0.2222 - recall: 0.3333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7708 - loss: nan - val_accuracy: 0.5000 - val_loss: nan - f1_score: 0.2222 - recall: 0.3333
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Epoch 7: f1-score: 0.2222 - recall: 0.3333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8333 - loss: nan - val_accuracy: 0.5000 - val_loss: nan - f1_score: 0.2222 - recall: 0.3333
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Epoch 8: f1-score: 0.2222 - recall: 0.3333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6458 - loss: nan - val_accuracy: 0.5000 - val_loss: nan - f1_score: 0.2222 - recall: 0.3333
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Epoch 9: f1-score: 0.2222 - recall: 0.3333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6458 - loss: nan - val_accuracy: 0.5000 - val_loss: nan - f1_score: 0.2222 - recall: 0.3333
# Epoch 10/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Epoch 10: f1-score: 0.2222 - recall: 0.3333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5833 - loss: nan - val_accuracy: 0.5000 - val_loss: nan - f1_score: 0.2222 - recall: 0.3333
# Epoch 11/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Epoch 11: f1-score: 0.2222 - recall: 0.3333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6458 - loss: nan - val_accuracy: 0.5000 - val_loss: nan - f1_score: 0.2222 - recall: 0.3333
# Epoch 12/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Epoch 12: f1-score: 0.2222 - recall: 0.3333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6458 - loss: nan - val_accuracy: 0.5000 - val_loss: nan - f1_score: 0.2222 - recall: 0.3333
# Epoch 13/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Epoch 13: f1-score: 0.2222 - recall: 0.3333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5833 - loss: nan - val_accuracy: 0.5000 - val_loss: nan - f1_score: 0.2222 - recall: 0.3333
# Epoch 14/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Epoch 14: f1-score: 0.2222 - recall: 0.3333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5833 - loss: nan - val_accuracy: 0.5000 - val_loss: nan - f1_score: 0.2222 - recall: 0.3333
# Epoch 15/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Epoch 15: f1-score: 0.2222 - recall: 0.3333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7708 - loss: nan - val_accuracy: 0.5000 - val_loss: nan - f1_score: 0.2222 - recall: 0.3333
# Epoch 16/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Epoch 16: f1-score: 0.2222 - recall: 0.3333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6458 - loss: nan - val_accuracy: 0.5000 - val_loss: nan - f1_score: 0.2222 - recall: 0.3333
# Epoch 17/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Epoch 17: f1-score: 0.2222 - recall: 0.3333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5833 - loss: nan - val_accuracy: 0.5000 - val_loss: nan - f1_score: 0.2222 - recall: 0.3333
# Epoch 18/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Epoch 18: f1-score: 0.2222 - recall: 0.3333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7708 - loss: nan - val_accuracy: 0.5000 - val_loss: nan - f1_score: 0.2222 - recall: 0.3333
# Epoch 19/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Epoch 19: f1-score: 0.2222 - recall: 0.3333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7708 - loss: nan - val_accuracy: 0.5000 - val_loss: nan - f1_score: 0.2222 - recall: 0.3333
# Epoch 20/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Epoch 20: f1-score: 0.2222 - recall: 0.3333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8333 - loss: nan - val_accuracy: 0.5000 - val_loss: nan - f1_score: 0.2222 - recall: 0.3333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.5000 - loss: nan
# Test Loss: nan, Test Accuracy: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# ......
# ----------------------------------------------------------------------
# Ran 7 tests in 6.946s
#
# OK
# Test Loss: 0.3, Test Accuracy: 0.9
